# %%
import h5py
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

from math import sqrt
from sklearn.model_selection import KFold
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import TensorDataset, DataLoader, Subset
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with h5py.File('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/stock_data.h5', 'r') as f:
    # apple
    X_train_apple = torch.tensor(f['X_train_apple'][:], dtype=torch.float32)
    y_train_apple = torch.tensor(f['y_train_apple'][:], dtype=torch.float32)
    X_val_apple = torch.tensor(f['X_val_apple'][:], dtype=torch.float32)
    y_val_apple = torch.tensor(f['y_val_apple'][:], dtype=torch.float32)
    X_test_apple = torch.tensor(f['X_test_apple'][:], dtype=torch.float32)
    y_test_apple = torch.tensor(f['y_test_apple'][:], dtype=torch.float32)

    # google
    X_train_google = torch.tensor(f['X_train_google'][:], dtype=torch.float32)
    y_train_google = torch.tensor(f['y_train_google'][:], dtype=torch.float32)
    X_val_google = torch.tensor(f['X_val_google'][:], dtype=torch.float32)
    y_val_google = torch.tensor(f['y_val_google'][:], dtype=torch.float32)
    X_test_google = torch.tensor(f['X_test_google'][:], dtype=torch.float32)
    y_test_google = torch.tensor(f['y_test_google'][:], dtype=torch.float32)

    # tesla
    X_train_tesla = torch.tensor(f['X_train_tesla'][:], dtype=torch.float32)
    y_train_tesla = torch.tensor(f['y_train_tesla'][:], dtype=torch.float32)
    X_val_tesla = torch.tensor(f['X_val_tesla'][:], dtype=torch.float32)
    y_val_tesla = torch.tensor(f['y_val_tesla'][:], dtype=torch.float32)
    X_test_tesla = torch.tensor(f['X_test_tesla'][:], dtype=torch.float32)
    y_test_tesla = torch.tensor(f['y_test_tesla'][:], dtype=torch.float32)

# dataloader
train_loader_apple = DataLoader(TensorDataset(X_train_apple, y_train_apple), batch_size=64, shuffle=True)
val_loader_apple = DataLoader(TensorDataset(X_val_apple, y_val_apple), batch_size=64, shuffle=False)
test_loader_apple = DataLoader(TensorDataset(X_test_apple, y_test_apple), batch_size=64, shuffle=False)

train_loader_google = DataLoader(TensorDataset(X_train_google, y_train_google), batch_size=64, shuffle=True)
val_loader_google = DataLoader(TensorDataset(X_val_google, y_val_google), batch_size=64, shuffle=False)
test_loader_google = DataLoader(TensorDataset(X_test_google, y_test_google), batch_size=64, shuffle=False)

train_loader_tesla = DataLoader(TensorDataset(X_train_tesla, y_train_tesla), batch_size=64, shuffle=True)
val_loader_tesla = DataLoader(TensorDataset(X_val_tesla, y_val_tesla), batch_size=64, shuffle=False)
test_loader_tesla = DataLoader(TensorDataset(X_test_tesla, y_test_tesla), batch_size=64, shuffle=False)

# %%
class Attention(nn.Module):
    def __init__(self, hidden_layer_size):
        super(Attention, self).__init__()
        self.hidden_layer_size = hidden_layer_size
        self.attention = nn.Linear(self.hidden_layer_size, 1)

    def forward(self, x):
        attention_scores = self.attention(x)
        attention_weights = F.softmax(attention_scores, dim=1)
        context_vector = attention_weights * x
        context_vector = torch.sum(context_vector, dim=1)
        return context_vector, attention_weights

# %%
class StockPredictor(nn.Module):
    def __init__(self, input_size, hidden_layer_size, num_layers, output_size, dropout=0.2):
        super(StockPredictor, self).__init__()
        self.hidden_layer_size = hidden_layer_size
        self.num_layers = num_layers

        self.attention = Attention(hidden_layer_size)

        # Initialize LSTM with the dropout
        self.lstm = nn.LSTM(input_size, hidden_layer_size, num_layers,
                            batch_first=True, dropout=dropout if num_layers > 1 else 0)

        # Initialize Dense layer with He initialization
        self.linear = nn.Linear(hidden_layer_size * 2, output_size)
        nn.init.kaiming_normal_(self.linear.weight, mode='fan_out', nonlinearity='leaky_relu')

        # Leaky ReLU activation
        self.leaky_relu = nn.LeakyReLU(negative_slope=0.01)

    def forward(self, x):
      # Initialize hidden state and cell state
      h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_layer_size).to(x.device)
      c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_layer_size).to(x.device)

      # Forward propagate LSTM
      lstm_out, _ = self.lstm(x, (h0, c0))

      # Get the context vector from the attention layer
      context_vector, attention_weights = self.attention(lstm_out)
      out = lstm_out[:, -1, :]  # Get the last time step output from LSTM

      # Apply Leaky ReLU activation
      out = self.leaky_relu(out)

      # Pass through the linear layer
      combined_out = torch.cat((out, context_vector), 1)
      out = self.linear(combined_out)
      return out, attention_weights  # Make sure to return both output and attention weights

# %%
def cross_validate(model_class, dataset, k_folds, l2_penalties):
    # Initialise K-fold cross validation
    kf = KFold(n_splits=k_folds, shuffle=True)

    # Record the average validation loss for each regularisation parameter
    avg_val_losses = {}

    # For each L2 regularised intensity
    for l2_penalty in l2_penalties:
        print(f"Testing L2 penalty: {l2_penalty}")
        val_losses = []  # Save the validation losses for each fold

        # Perform k-fold cross validation
        for fold, (train_ids, val_ids) in enumerate(kf.split(dataset)):
            print(f"Folding {fold+1}/{k_folds}")
            # Split the data
            X_train_fold = dataset.tensors[0][train_ids]
            y_train_fold = dataset.tensors[1][train_ids]
            X_val_fold = dataset.tensors[0][val_ids]
            y_val_fold = dataset.tensors[1][val_ids]

            # Create the data loader
            train_loader = DataLoader(TensorDataset(X_train_fold, y_train_fold), batch_size=64, shuffle=True)
            val_loader = DataLoader(TensorDataset(X_val_fold, y_val_fold), batch_size=64, shuffle=False)

            # Initialise the model
            model = model_class(input_size, hidden_layer_size, num_layers, output_size)

            trained_model, train_losses, fold_val_losses = train_and_validate(
                model, train_loader, val_loader, num_epochs=10, weight_decay=l2_penalty)

            # Record the average validation loss for this fold
            avg_fold_val_loss = sum(fold_val_losses) / len(fold_val_losses)
            val_losses.append(avg_fold_val_loss)

        # Calculate the average validation loss for this L2 regularisation parameter
        avg_val_losses[l2_penalty] = sum(val_losses) / len(val_losses)

    # Return the L2 regularisation parameter with the lowest average validation loss
    best_l2_penalty = min(avg_val_losses, key=avg_val_losses.get)
    return best_l2_penalty, avg_val_losses

# %%
class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), 'checkpoint.pth')
        self.val_loss_min = val_loss

def train_and_validate(model, train_loader, val_loader, num_epochs=50, weight_decay=0.01):
    criterion = nn.MSELoss()

    optimizer = optim.SGD(model.parameters(), lr=0.001, weight_decay=weight_decay)
    # Learning rate scheduler
    scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5, min_lr=1e-5, verbose=True)
    # Early stop
    early_stopping = EarlyStopping(patience=50, verbose=True)

    train_losses = []
    val_losses = []

    for epoch in range(num_epochs):
        # Training modalities
        model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            outputs, attention_weights = model(X_batch)  # Get outputs and attention weights
            outputs = outputs  # Only use outputs for loss calculation

            loss = criterion(outputs, y_batch.view(y_batch.size(0), -1))
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        avg_train_loss = train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        #Evaluation model
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                outputs, attention_weights = model(X_batch)  # Get outputs and attention weights
                outputs = outputs  # Only use outputs for loss calculation

                loss = criterion(outputs, y_batch.view(y_batch.size(0), -1))
                val_loss += loss.item()

        avg_val_loss = val_loss / len(val_loader)
        val_losses.append(avg_val_loss)

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')

        # Updated early stop method and learning rate scheduler
        early_stopping(avg_val_loss, model)
        scheduler.step(avg_val_loss)

        if early_stopping.early_stop:
            print("Early Stop")
            break

    # Load optimal model weights
    model.load_state_dict(torch.load('checkpoint.pth'))

    return model, train_losses, val_losses

# %%
# Initialize the model, loss function and optimizer
input_size = X_train_apple.shape[2]
hidden_layer_size = 100
num_layers = 2
output_size = y_train_apple.shape[2] * y_train_apple.shape[1]

# %%
l2_penalties = [0.0001, 0.001, 0.01, 0.1, 1.0]
# Cross-validation of Apple's dataset
dataset_apple = TensorDataset(X_train_apple, y_train_apple)
best_penalty_apple, validation_results_apple = cross_validate(
    StockPredictor, dataset_apple, 5, l2_penalties)


# Cross-validation of Google Inc. datasets
dataset_google = TensorDataset(X_train_google, y_train_google)
best_penalty_google, validation_results_google = cross_validate(
    StockPredictor, dataset_google, 5, l2_penalties)


# Cross-validation of Tesla Inc. datasets
dataset_tesla = TensorDataset(X_train_tesla, y_train_tesla)
best_penalty_tesla, validation_results_tesla = cross_validate(
    StockPredictor, dataset_tesla, 5, l2_penalties)

print(f"Best L2 penalty for Apple: {best_penalty_apple}")
print(f"Best L2 penalty for Google: {best_penalty_google}")
print(f"Best L2 penalty for Tesla: {best_penalty_tesla}")
# Out:
# Testing L2 penalty: 0.0001
# Folding 1/5
# Epoch [1/10], Train Loss: 0.1703, Val Loss: 0.2716
# Validation loss decreased (inf --> 0.271637).  Saving model ...
# Epoch [2/10], Train Loss: 0.1441, Val Loss: 0.2350
# Validation loss decreased (0.271637 --> 0.235016).  Saving model ...
# Epoch [3/10], Train Loss: 0.1179, Val Loss: 0.2089
# Validation loss decreased (0.235016 --> 0.208879).  Saving model ...
# Epoch [4/10], Train Loss: 0.1048, Val Loss: 0.1891
# Validation loss decreased (0.208879 --> 0.189095).  Saving model ...
# Epoch [5/10], Train Loss: 0.0948, Val Loss: 0.1741
# Validation loss decreased (0.189095 --> 0.174121).  Saving model ...
# Epoch [6/10], Train Loss: 0.0870, Val Loss: 0.1629
# Validation loss decreased (0.174121 --> 0.162916).  Saving model ...
# Epoch [7/10], Train Loss: 0.0829, Val Loss: 0.1538
# Validation loss decreased (0.162916 --> 0.153784).  Saving model ...
# Epoch [8/10], Train Loss: 0.0802, Val Loss: 0.1464
# Validation loss decreased (0.153784 --> 0.146393).  Saving model ...
# Epoch [9/10], Train Loss: 0.0757, Val Loss: 0.1408
# Validation loss decreased (0.146393 --> 0.140787).  Saving model ...
# Epoch [10/10], Train Loss: 0.0738, Val Loss: 0.1360
# Validation loss decreased (0.140787 --> 0.135965).  Saving model ...
# Folding 2/5
# Epoch [1/10], Train Loss: 0.3057, Val Loss: 0.4244
# Validation loss decreased (inf --> 0.424389).  Saving model ...
# Epoch [2/10], Train Loss: 0.2567, Val Loss: 0.3738
# Validation loss decreased (0.424389 --> 0.373781).  Saving model ...
# Epoch [3/10], Train Loss: 0.2266, Val Loss: 0.3320
# Validation loss decreased (0.373781 --> 0.331995).  Saving model ...
# Epoch [4/10], Train Loss: 0.1978, Val Loss: 0.2977
# Validation loss decreased (0.331995 --> 0.297690).  Saving model ...
# Epoch [5/10], Train Loss: 0.1732, Val Loss: 0.2695
# Validation loss decreased (0.297690 --> 0.269540).  Saving model ...
# Epoch [6/10], Train Loss: 0.1553, Val Loss: 0.2464
# Validation loss decreased (0.269540 --> 0.246383).  Saving model ...
# Epoch [7/10], Train Loss: 0.1370, Val Loss: 0.2274
# Validation loss decreased (0.246383 --> 0.227423).  Saving model ...
# Epoch [8/10], Train Loss: 0.1267, Val Loss: 0.2116
# Validation loss decreased (0.227423 --> 0.211591).  Saving model ...
# Epoch [9/10], Train Loss: 0.1171, Val Loss: 0.1987
# Validation loss decreased (0.211591 --> 0.198700).  Saving model ...
# Epoch [10/10], Train Loss: 0.1098, Val Loss: 0.1879
# Validation loss decreased (0.198700 --> 0.187896).  Saving model ...
# Folding 3/5
# Epoch [1/10], Train Loss: 0.3135, Val Loss: 0.4721
# Validation loss decreased (inf --> 0.472121).  Saving model ...
# Epoch [2/10], Train Loss: 0.2670, Val Loss: 0.4126
# Validation loss decreased (0.472121 --> 0.412637).  Saving model ...
# Epoch [3/10], Train Loss: 0.2242, Val Loss: 0.3636
# Validation loss decreased (0.412637 --> 0.363598).  Saving model ...
# Epoch [4/10], Train Loss: 0.1953, Val Loss: 0.3233
# Validation loss decreased (0.363598 --> 0.323335).  Saving model ...
# Epoch [5/10], Train Loss: 0.1676, Val Loss: 0.2916
# Validation loss decreased (0.323335 --> 0.291640).  Saving model ...
# Epoch [6/10], Train Loss: 0.1497, Val Loss: 0.2653
# Validation loss decreased (0.291640 --> 0.265294).  Saving model ...
# Epoch [7/10], Train Loss: 0.1336, Val Loss: 0.2432
# Validation loss decreased (0.265294 --> 0.243174).  Saving model ...
# Epoch [8/10], Train Loss: 0.1201, Val Loss: 0.2246
# Validation loss decreased (0.243174 --> 0.224561).  Saving model ...
# Epoch [9/10], Train Loss: 0.1101, Val Loss: 0.2087
# Validation loss decreased (0.224561 --> 0.208733).  Saving model ...
# Epoch [10/10], Train Loss: 0.1006, Val Loss: 0.1953
# Validation loss decreased (0.208733 --> 0.195343).  Saving model ...
# Folding 4/5
# Epoch [1/10], Train Loss: 0.3291, Val Loss: 0.4317
# Validation loss decreased (inf --> 0.431695).  Saving model ...
# Epoch [2/10], Train Loss: 0.2632, Val Loss: 0.3603
# Validation loss decreased (0.431695 --> 0.360327).  Saving model ...
# Epoch [3/10], Train Loss: 0.2122, Val Loss: 0.3085
# Validation loss decreased (0.360327 --> 0.308495).  Saving model ...
# Epoch [4/10], Train Loss: 0.1787, Val Loss: 0.2687
# Validation loss decreased (0.308495 --> 0.268683).  Saving model ...
# Epoch [5/10], Train Loss: 0.1532, Val Loss: 0.2379
# Validation loss decreased (0.268683 --> 0.237906).  Saving model ...
# Epoch [6/10], Train Loss: 0.1339, Val Loss: 0.2139
# Validation loss decreased (0.237906 --> 0.213919).  Saving model ...
# Epoch [7/10], Train Loss: 0.1194, Val Loss: 0.1950
# Validation loss decreased (0.213919 --> 0.194967).  Saving model ...
# Epoch [8/10], Train Loss: 0.1102, Val Loss: 0.1797
# Validation loss decreased (0.194967 --> 0.179685).  Saving model ...
# Epoch [9/10], Train Loss: 0.1005, Val Loss: 0.1677
# Validation loss decreased (0.179685 --> 0.167742).  Saving model ...
# Epoch [10/10], Train Loss: 0.0937, Val Loss: 0.1581
# Validation loss decreased (0.167742 --> 0.158068).  Saving model ...
# Folding 5/5
# Epoch [1/10], Train Loss: 0.3017, Val Loss: 0.3862
# Validation loss decreased (inf --> 0.386162).  Saving model ...
# Epoch [2/10], Train Loss: 0.2486, Val Loss: 0.3353
# Validation loss decreased (0.386162 --> 0.335265).  Saving model ...
# Epoch [3/10], Train Loss: 0.2135, Val Loss: 0.2972
# Validation loss decreased (0.335265 --> 0.297219).  Saving model ...
# Epoch [4/10], Train Loss: 0.1847, Val Loss: 0.2674
# Validation loss decreased (0.297219 --> 0.267421).  Saving model ...
# Epoch [5/10], Train Loss: 0.1642, Val Loss: 0.2434
# Validation loss decreased (0.267421 --> 0.243373).  Saving model ...
# Epoch [6/10], Train Loss: 0.1459, Val Loss: 0.2238
# Validation loss decreased (0.243373 --> 0.223844).  Saving model ...
# Epoch [7/10], Train Loss: 0.1331, Val Loss: 0.2075
# Validation loss decreased (0.223844 --> 0.207514).  Saving model ...
# Epoch [8/10], Train Loss: 0.1207, Val Loss: 0.1939
# Validation loss decreased (0.207514 --> 0.193929).  Saving model ...
# Epoch [9/10], Train Loss: 0.1119, Val Loss: 0.1823
# Validation loss decreased (0.193929 --> 0.182317).  Saving model ...
# Epoch [10/10], Train Loss: 0.1058, Val Loss: 0.1723
# Validation loss decreased (0.182317 --> 0.172310).  Saving model ...
# Testing L2 penalty: 0.001
# Folding 1/5
# Epoch [1/10], Train Loss: 0.1306, Val Loss: 0.2430
# Validation loss decreased (inf --> 0.243045).  Saving model ...
# Epoch [2/10], Train Loss: 0.1233, Val Loss: 0.2295
# Validation loss decreased (0.243045 --> 0.229539).  Saving model ...
# Epoch [3/10], Train Loss: 0.1135, Val Loss: 0.2176
# Validation loss decreased (0.229539 --> 0.217609).  Saving model ...
# Epoch [4/10], Train Loss: 0.1059, Val Loss: 0.2070
# Validation loss decreased (0.217609 --> 0.207023).  Saving model ...
# Epoch [5/10], Train Loss: 0.1008, Val Loss: 0.1975
# Validation loss decreased (0.207023 --> 0.197507).  Saving model ...
# Epoch [6/10], Train Loss: 0.0970, Val Loss: 0.1890
# Validation loss decreased (0.197507 --> 0.188970).  Saving model ...
# Epoch [7/10], Train Loss: 0.0914, Val Loss: 0.1816
# Validation loss decreased (0.188970 --> 0.181558).  Saving model ...
# Epoch [8/10], Train Loss: 0.0902, Val Loss: 0.1748
# Validation loss decreased (0.181558 --> 0.174751).  Saving model ...
# Epoch [9/10], Train Loss: 0.0868, Val Loss: 0.1688
# Validation loss decreased (0.174751 --> 0.168777).  Saving model ...
# Epoch [10/10], Train Loss: 0.0828, Val Loss: 0.1636
# Validation loss decreased (0.168777 --> 0.163643).  Saving model ...
# Folding 2/5
# Epoch [1/10], Train Loss: 0.2796, Val Loss: 0.3755
# Validation loss decreased (inf --> 0.375512).  Saving model ...
# Epoch [2/10], Train Loss: 0.2154, Val Loss: 0.3128
# Validation loss decreased (0.375512 --> 0.312772).  Saving model ...
# Epoch [3/10], Train Loss: 0.1734, Val Loss: 0.2674
# Validation loss decreased (0.312772 --> 0.267435).  Saving model ...
# Epoch [4/10], Train Loss: 0.1474, Val Loss: 0.2342
# Validation loss decreased (0.267435 --> 0.234243).  Saving model ...
# Epoch [5/10], Train Loss: 0.1243, Val Loss: 0.2108
# Validation loss decreased (0.234243 --> 0.210758).  Saving model ...
# Epoch [6/10], Train Loss: 0.1110, Val Loss: 0.1929
# Validation loss decreased (0.210758 --> 0.192917).  Saving model ...
# Epoch [7/10], Train Loss: 0.1013, Val Loss: 0.1792
# Validation loss decreased (0.192917 --> 0.179248).  Saving model ...
# Epoch [8/10], Train Loss: 0.0940, Val Loss: 0.1686
# Validation loss decreased (0.179248 --> 0.168567).  Saving model ...
# Epoch [9/10], Train Loss: 0.0890, Val Loss: 0.1600
# Validation loss decreased (0.168567 --> 0.159995).  Saving model ...
# Epoch [10/10], Train Loss: 0.0849, Val Loss: 0.1531
# Validation loss decreased (0.159995 --> 0.153060).  Saving model ...
# Folding 3/5
# Epoch [1/10], Train Loss: 0.2207, Val Loss: 0.3294
# Validation loss decreased (inf --> 0.329423).  Saving model ...
# Epoch [2/10], Train Loss: 0.1893, Val Loss: 0.2935
# Validation loss decreased (0.329423 --> 0.293493).  Saving model ...
# Epoch [3/10], Train Loss: 0.1666, Val Loss: 0.2643
# Validation loss decreased (0.293493 --> 0.264261).  Saving model ...
# Epoch [4/10], Train Loss: 0.1478, Val Loss: 0.2408
# Validation loss decreased (0.264261 --> 0.240771).  Saving model ...
# Epoch [5/10], Train Loss: 0.1308, Val Loss: 0.2221
# Validation loss decreased (0.240771 --> 0.222064).  Saving model ...
# Epoch [6/10], Train Loss: 0.1169, Val Loss: 0.2068
# Validation loss decreased (0.222064 --> 0.206773).  Saving model ...
# Epoch [7/10], Train Loss: 0.1088, Val Loss: 0.1937
# Validation loss decreased (0.206773 --> 0.193674).  Saving model ...
# Epoch [8/10], Train Loss: 0.1012, Val Loss: 0.1828
# Validation loss decreased (0.193674 --> 0.182836).  Saving model ...
# Epoch [9/10], Train Loss: 0.0948, Val Loss: 0.1739
# Validation loss decreased (0.182836 --> 0.173861).  Saving model ...
# Epoch [10/10], Train Loss: 0.0890, Val Loss: 0.1661
# Validation loss decreased (0.173861 --> 0.166147).  Saving model ...
# Folding 4/5
# Epoch [1/10], Train Loss: 0.2646, Val Loss: 0.3720
# Validation loss decreased (inf --> 0.371974).  Saving model ...
# Epoch [2/10], Train Loss: 0.2201, Val Loss: 0.3255
# Validation loss decreased (0.371974 --> 0.325547).  Saving model ...
# Epoch [3/10], Train Loss: 0.1923, Val Loss: 0.2883
# Validation loss decreased (0.325547 --> 0.288317).  Saving model ...
# Epoch [4/10], Train Loss: 0.1662, Val Loss: 0.2587
# Validation loss decreased (0.288317 --> 0.258687).  Saving model ...
# Epoch [5/10], Train Loss: 0.1453, Val Loss: 0.2349
# Validation loss decreased (0.258687 --> 0.234880).  Saving model ...
# Epoch [6/10], Train Loss: 0.1341, Val Loss: 0.2145
# Validation loss decreased (0.234880 --> 0.214532).  Saving model ...
# Epoch [7/10], Train Loss: 0.1228, Val Loss: 0.1978
# Validation loss decreased (0.214532 --> 0.197755).  Saving model ...
# Epoch [8/10], Train Loss: 0.1122, Val Loss: 0.1841
# Validation loss decreased (0.197755 --> 0.184148).  Saving model ...
# Epoch [9/10], Train Loss: 0.1037, Val Loss: 0.1729
# Validation loss decreased (0.184148 --> 0.172936).  Saving model ...
# Epoch [10/10], Train Loss: 0.0986, Val Loss: 0.1634
# Validation loss decreased (0.172936 --> 0.163420).  Saving model ...
# Folding 5/5
# Epoch [1/10], Train Loss: 0.2551, Val Loss: 0.3147
# Validation loss decreased (inf --> 0.314713).  Saving model ...
# Epoch [2/10], Train Loss: 0.2121, Val Loss: 0.2727
# Validation loss decreased (0.314713 --> 0.272714).  Saving model ...
# Epoch [3/10], Train Loss: 0.1821, Val Loss: 0.2406
# Validation loss decreased (0.272714 --> 0.240641).  Saving model ...
# Epoch [4/10], Train Loss: 0.1583, Val Loss: 0.2159
# Validation loss decreased (0.240641 --> 0.215855).  Saving model ...
# Epoch [5/10], Train Loss: 0.1417, Val Loss: 0.1966
# Validation loss decreased (0.215855 --> 0.196605).  Saving model ...
# Epoch [6/10], Train Loss: 0.1253, Val Loss: 0.1815
# Validation loss decreased (0.196605 --> 0.181452).  Saving model ...
# Epoch [7/10], Train Loss: 0.1153, Val Loss: 0.1693
# Validation loss decreased (0.181452 --> 0.169320).  Saving model ...
# Epoch [8/10], Train Loss: 0.1075, Val Loss: 0.1596
# Validation loss decreased (0.169320 --> 0.159577).  Saving model ...
# Epoch [9/10], Train Loss: 0.1027, Val Loss: 0.1511
# Validation loss decreased (0.159577 --> 0.151071).  Saving model ...
# Epoch [10/10], Train Loss: 0.0947, Val Loss: 0.1442
# Validation loss decreased (0.151071 --> 0.144226).  Saving model ...
# Testing L2 penalty: 0.01
# Folding 1/5
# Epoch [1/10], Train Loss: 0.1637, Val Loss: 0.2531
# Validation loss decreased (inf --> 0.253069).  Saving model ...
# Epoch [2/10], Train Loss: 0.1441, Val Loss: 0.2304
# Validation loss decreased (0.253069 --> 0.230447).  Saving model ...
# Epoch [3/10], Train Loss: 0.1292, Val Loss: 0.2124
# Validation loss decreased (0.230447 --> 0.212361).  Saving model ...
# Epoch [4/10], Train Loss: 0.1216, Val Loss: 0.1972
# Validation loss decreased (0.212361 --> 0.197219).  Saving model ...
# Epoch [5/10], Train Loss: 0.1125, Val Loss: 0.1850
# Validation loss decreased (0.197219 --> 0.185021).  Saving model ...
# Epoch [6/10], Train Loss: 0.1046, Val Loss: 0.1752
# Validation loss decreased (0.185021 --> 0.175218).  Saving model ...
# Epoch [7/10], Train Loss: 0.0994, Val Loss: 0.1669
# Validation loss decreased (0.175218 --> 0.166901).  Saving model ...
# Epoch [8/10], Train Loss: 0.0942, Val Loss: 0.1601
# Validation loss decreased (0.166901 --> 0.160096).  Saving model ...
# Epoch [9/10], Train Loss: 0.0889, Val Loss: 0.1545
# Validation loss decreased (0.160096 --> 0.154539).  Saving model ...
# Epoch [10/10], Train Loss: 0.0875, Val Loss: 0.1496
# Validation loss decreased (0.154539 --> 0.149579).  Saving model ...
# Folding 2/5
# Epoch [1/10], Train Loss: 0.1478, Val Loss: 0.2151
# Validation loss decreased (inf --> 0.215072).  Saving model ...
# Epoch [2/10], Train Loss: 0.1269, Val Loss: 0.1958
# Validation loss decreased (0.215072 --> 0.195787).  Saving model ...
# Epoch [3/10], Train Loss: 0.1104, Val Loss: 0.1810
# Validation loss decreased (0.195787 --> 0.180982).  Saving model ...
# Epoch [4/10], Train Loss: 0.0997, Val Loss: 0.1691
# Validation loss decreased (0.180982 --> 0.169092).  Saving model ...
# Epoch [5/10], Train Loss: 0.0920, Val Loss: 0.1593
# Validation loss decreased (0.169092 --> 0.159312).  Saving model ...
# Epoch [6/10], Train Loss: 0.0836, Val Loss: 0.1514
# Validation loss decreased (0.159312 --> 0.151384).  Saving model ...
# Epoch [7/10], Train Loss: 0.0792, Val Loss: 0.1446
# Validation loss decreased (0.151384 --> 0.144603).  Saving model ...
# Epoch [8/10], Train Loss: 0.0753, Val Loss: 0.1388
# Validation loss decreased (0.144603 --> 0.138770).  Saving model ...
# Epoch [9/10], Train Loss: 0.0716, Val Loss: 0.1338
# Validation loss decreased (0.138770 --> 0.133836).  Saving model ...
# Epoch [10/10], Train Loss: 0.0677, Val Loss: 0.1297
# Validation loss decreased (0.133836 --> 0.129668).  Saving model ...
# Folding 3/5
# Epoch [1/10], Train Loss: 0.2345, Val Loss: 0.3218
# Validation loss decreased (inf --> 0.321803).  Saving model ...
# Epoch [2/10], Train Loss: 0.1954, Val Loss: 0.2783
# Validation loss decreased (0.321803 --> 0.278315).  Saving model ...
# Epoch [3/10], Train Loss: 0.1685, Val Loss: 0.2456
# Validation loss decreased (0.278315 --> 0.245623).  Saving model ...
# Epoch [4/10], Train Loss: 0.1434, Val Loss: 0.2209
# Validation loss decreased (0.245623 --> 0.220882).  Saving model ...
# Epoch [5/10], Train Loss: 0.1269, Val Loss: 0.2014
# Validation loss decreased (0.220882 --> 0.201424).  Saving model ...
# Epoch [6/10], Train Loss: 0.1143, Val Loss: 0.1858
# Validation loss decreased (0.201424 --> 0.185778).  Saving model ...
# Epoch [7/10], Train Loss: 0.1055, Val Loss: 0.1729
# Validation loss decreased (0.185778 --> 0.172869).  Saving model ...
# Epoch [8/10], Train Loss: 0.0970, Val Loss: 0.1625
# Validation loss decreased (0.172869 --> 0.162490).  Saving model ...
# Epoch [9/10], Train Loss: 0.0913, Val Loss: 0.1538
# Validation loss decreased (0.162490 --> 0.153803).  Saving model ...
# Epoch [10/10], Train Loss: 0.0863, Val Loss: 0.1466
# Validation loss decreased (0.153803 --> 0.146647).  Saving model ...
# Folding 4/5
# Epoch [1/10], Train Loss: 0.2623, Val Loss: 0.3641
# Validation loss decreased (inf --> 0.364117).  Saving model ...
# Epoch [2/10], Train Loss: 0.2194, Val Loss: 0.3195
# Validation loss decreased (0.364117 --> 0.319532).  Saving model ...
# Epoch [3/10], Train Loss: 0.1856, Val Loss: 0.2852
# Validation loss decreased (0.319532 --> 0.285167).  Saving model ...
# Epoch [4/10], Train Loss: 0.1636, Val Loss: 0.2586
# Validation loss decreased (0.285167 --> 0.258575).  Saving model ...
# Epoch [5/10], Train Loss: 0.1466, Val Loss: 0.2375
# Validation loss decreased (0.258575 --> 0.237516).  Saving model ...
# Epoch [6/10], Train Loss: 0.1327, Val Loss: 0.2206
# Validation loss decreased (0.237516 --> 0.220574).  Saving model ...
# Epoch [7/10], Train Loss: 0.1242, Val Loss: 0.2063
# Validation loss decreased (0.220574 --> 0.206297).  Saving model ...
# Epoch [8/10], Train Loss: 0.1138, Val Loss: 0.1945
# Validation loss decreased (0.206297 --> 0.194461).  Saving model ...
# Epoch [9/10], Train Loss: 0.1062, Val Loss: 0.1845
# Validation loss decreased (0.194461 --> 0.184487).  Saving model ...
# Epoch [10/10], Train Loss: 0.1009, Val Loss: 0.1759
# Validation loss decreased (0.184487 --> 0.175872).  Saving model ...
# Folding 5/5
# Epoch [1/10], Train Loss: 0.1920, Val Loss: 0.2995
# Validation loss decreased (inf --> 0.299478).  Saving model ...
# Epoch [2/10], Train Loss: 0.1680, Val Loss: 0.2669
# Validation loss decreased (0.299478 --> 0.266949).  Saving model ...
# Epoch [3/10], Train Loss: 0.1439, Val Loss: 0.2418
# Validation loss decreased (0.266949 --> 0.241836).  Saving model ...
# Epoch [4/10], Train Loss: 0.1292, Val Loss: 0.2215
# Validation loss decreased (0.241836 --> 0.221541).  Saving model ...
# Epoch [5/10], Train Loss: 0.1169, Val Loss: 0.2053
# Validation loss decreased (0.221541 --> 0.205348).  Saving model ...
# Epoch [6/10], Train Loss: 0.1078, Val Loss: 0.1922
# Validation loss decreased (0.205348 --> 0.192174).  Saving model ...
# Epoch [7/10], Train Loss: 0.1007, Val Loss: 0.1813
# Validation loss decreased (0.192174 --> 0.181280).  Saving model ...
# Epoch [8/10], Train Loss: 0.0937, Val Loss: 0.1724
# Validation loss decreased (0.181280 --> 0.172411).  Saving model ...
# Epoch [9/10], Train Loss: 0.0894, Val Loss: 0.1653
# Validation loss decreased (0.172411 --> 0.165273).  Saving model ...
# Epoch [10/10], Train Loss: 0.0873, Val Loss: 0.1591
# Validation loss decreased (0.165273 --> 0.159072).  Saving model ...
# Testing L2 penalty: 0.1
# Folding 1/5
# Epoch [1/10], Train Loss: 0.1893, Val Loss: 0.2384
# Validation loss decreased (inf --> 0.238374).  Saving model ...
# Epoch [2/10], Train Loss: 0.1610, Val Loss: 0.2116
# Validation loss decreased (0.238374 --> 0.211571).  Saving model ...
# Epoch [3/10], Train Loss: 0.1409, Val Loss: 0.1910
# Validation loss decreased (0.211571 --> 0.191015).  Saving model ...
# Epoch [4/10], Train Loss: 0.1264, Val Loss: 0.1749
# Validation loss decreased (0.191015 --> 0.174931).  Saving model ...
# Epoch [5/10], Train Loss: 0.1154, Val Loss: 0.1621
# Validation loss decreased (0.174931 --> 0.162099).  Saving model ...
# Epoch [6/10], Train Loss: 0.1080, Val Loss: 0.1516
# Validation loss decreased (0.162099 --> 0.151561).  Saving model ...
# Epoch [7/10], Train Loss: 0.1004, Val Loss: 0.1430
# Validation loss decreased (0.151561 --> 0.143000).  Saving model ...
# Epoch [8/10], Train Loss: 0.0935, Val Loss: 0.1361
# Validation loss decreased (0.143000 --> 0.136080).  Saving model ...
# Epoch [9/10], Train Loss: 0.0904, Val Loss: 0.1302
# Validation loss decreased (0.136080 --> 0.130209).  Saving model ...
# Epoch [10/10], Train Loss: 0.0864, Val Loss: 0.1253
# Validation loss decreased (0.130209 --> 0.125340).  Saving model ...
# Folding 2/5
# Epoch [1/10], Train Loss: 0.3632, Val Loss: 0.5118
# Validation loss decreased (inf --> 0.511792).  Saving model ...
# Epoch [2/10], Train Loss: 0.3007, Val Loss: 0.4390
# Validation loss decreased (0.511792 --> 0.439034).  Saving model ...
# Epoch [3/10], Train Loss: 0.2514, Val Loss: 0.3830
# Validation loss decreased (0.439034 --> 0.382952).  Saving model ...
# Epoch [4/10], Train Loss: 0.2127, Val Loss: 0.3385
# Validation loss decreased (0.382952 --> 0.338467).  Saving model ...
# Epoch [5/10], Train Loss: 0.1808, Val Loss: 0.3032
# Validation loss decreased (0.338467 --> 0.303205).  Saving model ...
# Epoch [6/10], Train Loss: 0.1636, Val Loss: 0.2738
# Validation loss decreased (0.303205 --> 0.273787).  Saving model ...
# Epoch [7/10], Train Loss: 0.1436, Val Loss: 0.2502
# Validation loss decreased (0.273787 --> 0.250201).  Saving model ...
# Epoch [8/10], Train Loss: 0.1313, Val Loss: 0.2305
# Validation loss decreased (0.250201 --> 0.230489).  Saving model ...
# Epoch [9/10], Train Loss: 0.1206, Val Loss: 0.2141
# Validation loss decreased (0.230489 --> 0.214109).  Saving model ...
# Epoch [10/10], Train Loss: 0.1097, Val Loss: 0.2005
# Validation loss decreased (0.214109 --> 0.200549).  Saving model ...
# Folding 3/5
# Epoch [1/10], Train Loss: 0.1899, Val Loss: 0.2922
# Validation loss decreased (inf --> 0.292241).  Saving model ...
# Epoch [2/10], Train Loss: 0.1699, Val Loss: 0.2681
# Validation loss decreased (0.292241 --> 0.268053).  Saving model ...
# Epoch [3/10], Train Loss: 0.1527, Val Loss: 0.2482
# Validation loss decreased (0.268053 --> 0.248197).  Saving model ...
# Epoch [4/10], Train Loss: 0.1424, Val Loss: 0.2310
# Validation loss decreased (0.248197 --> 0.231010).  Saving model ...
# Epoch [5/10], Train Loss: 0.1275, Val Loss: 0.2171
# Validation loss decreased (0.231010 --> 0.217100).  Saving model ...
# Epoch [6/10], Train Loss: 0.1205, Val Loss: 0.2050
# Validation loss decreased (0.217100 --> 0.205011).  Saving model ...
# Epoch [7/10], Train Loss: 0.1143, Val Loss: 0.1945
# Validation loss decreased (0.205011 --> 0.194451).  Saving model ...
# Epoch [8/10], Train Loss: 0.1053, Val Loss: 0.1857
# Validation loss decreased (0.194451 --> 0.185725).  Saving model ...
# Epoch [9/10], Train Loss: 0.1013, Val Loss: 0.1780
# Validation loss decreased (0.185725 --> 0.177989).  Saving model ...
# Epoch [10/10], Train Loss: 0.0974, Val Loss: 0.1713
# Validation loss decreased (0.177989 --> 0.171275).  Saving model ...
# Folding 4/5
# Epoch [1/10], Train Loss: 0.1823, Val Loss: 0.2740
# Validation loss decreased (inf --> 0.274043).  Saving model ...
# Epoch [2/10], Train Loss: 0.1535, Val Loss: 0.2413
# Validation loss decreased (0.274043 --> 0.241319).  Saving model ...
# Epoch [3/10], Train Loss: 0.1350, Val Loss: 0.2164
# Validation loss decreased (0.241319 --> 0.216390).  Saving model ...
# Epoch [4/10], Train Loss: 0.1214, Val Loss: 0.1970
# Validation loss decreased (0.216390 --> 0.197041).  Saving model ...
# Epoch [5/10], Train Loss: 0.1086, Val Loss: 0.1824
# Validation loss decreased (0.197041 --> 0.182406).  Saving model ...
# Epoch [6/10], Train Loss: 0.1028, Val Loss: 0.1706
# Validation loss decreased (0.182406 --> 0.170630).  Saving model ...
# Epoch [7/10], Train Loss: 0.0956, Val Loss: 0.1616
# Validation loss decreased (0.170630 --> 0.161640).  Saving model ...
# Epoch [8/10], Train Loss: 0.0918, Val Loss: 0.1544
# Validation loss decreased (0.161640 --> 0.154357).  Saving model ...
# Epoch [9/10], Train Loss: 0.0876, Val Loss: 0.1485
# Validation loss decreased (0.154357 --> 0.148508).  Saving model ...
# Epoch [10/10], Train Loss: 0.0835, Val Loss: 0.1440
# Validation loss decreased (0.148508 --> 0.144005).  Saving model ...
# Folding 5/5
# Epoch [1/10], Train Loss: 0.2256, Val Loss: 0.3650
# Validation loss decreased (inf --> 0.364993).  Saving model ...
# Epoch [2/10], Train Loss: 0.1863, Val Loss: 0.3183
# Validation loss decreased (0.364993 --> 0.318279).  Saving model ...
# Epoch [3/10], Train Loss: 0.1552, Val Loss: 0.2821
# Validation loss decreased (0.318279 --> 0.282142).  Saving model ...
# Epoch [4/10], Train Loss: 0.1339, Val Loss: 0.2543
# Validation loss decreased (0.282142 --> 0.254286).  Saving model ...
# Epoch [5/10], Train Loss: 0.1184, Val Loss: 0.2321
# Validation loss decreased (0.254286 --> 0.232132).  Saving model ...
# Epoch [6/10], Train Loss: 0.1056, Val Loss: 0.2147
# Validation loss decreased (0.232132 --> 0.214703).  Saving model ...
# Epoch [7/10], Train Loss: 0.0960, Val Loss: 0.2009
# Validation loss decreased (0.214703 --> 0.200880).  Saving model ...
# Epoch [8/10], Train Loss: 0.0888, Val Loss: 0.1899
# Validation loss decreased (0.200880 --> 0.189931).  Saving model ...
# Epoch [9/10], Train Loss: 0.0827, Val Loss: 0.1813
# Validation loss decreased (0.189931 --> 0.181271).  Saving model ...
# Epoch [10/10], Train Loss: 0.0799, Val Loss: 0.1739
# Validation loss decreased (0.181271 --> 0.173936).  Saving model ...
# Testing L2 penalty: 1.0
# Folding 1/5
# Epoch [1/10], Train Loss: 0.2185, Val Loss: 0.3148
# Validation loss decreased (inf --> 0.314764).  Saving model ...
# Epoch [2/10], Train Loss: 0.1864, Val Loss: 0.2822
# Validation loss decreased (0.314764 --> 0.282157).  Saving model ...
# Epoch [3/10], Train Loss: 0.1655, Val Loss: 0.2574
# Validation loss decreased (0.282157 --> 0.257426).  Saving model ...
# Epoch [4/10], Train Loss: 0.1498, Val Loss: 0.2383
# Validation loss decreased (0.257426 --> 0.238348).  Saving model ...
# Epoch [5/10], Train Loss: 0.1365, Val Loss: 0.2235
# Validation loss decreased (0.238348 --> 0.223518).  Saving model ...
# Epoch [6/10], Train Loss: 0.1265, Val Loss: 0.2118
# Validation loss decreased (0.223518 --> 0.211800).  Saving model ...
# Epoch [7/10], Train Loss: 0.1199, Val Loss: 0.2023
# Validation loss decreased (0.211800 --> 0.202287).  Saving model ...
# Epoch [8/10], Train Loss: 0.1126, Val Loss: 0.1947
# Validation loss decreased (0.202287 --> 0.194741).  Saving model ...
# Epoch [9/10], Train Loss: 0.1097, Val Loss: 0.1885
# Validation loss decreased (0.194741 --> 0.188502).  Saving model ...
# Epoch [10/10], Train Loss: 0.1057, Val Loss: 0.1835
# Validation loss decreased (0.188502 --> 0.183516).  Saving model ...
# Folding 2/5
# Epoch [1/10], Train Loss: 0.3104, Val Loss: 0.4502
# Validation loss decreased (inf --> 0.450168).  Saving model ...
# Epoch [2/10], Train Loss: 0.2549, Val Loss: 0.3897
# Validation loss decreased (0.450168 --> 0.389657).  Saving model ...
# Epoch [3/10], Train Loss: 0.2145, Val Loss: 0.3444
# Validation loss decreased (0.389657 --> 0.344351).  Saving model ...
# Epoch [4/10], Train Loss: 0.1875, Val Loss: 0.3096
# Validation loss decreased (0.344351 --> 0.309615).  Saving model ...
# Epoch [5/10], Train Loss: 0.1646, Val Loss: 0.2826
# Validation loss decreased (0.309615 --> 0.282593).  Saving model ...
# Epoch [6/10], Train Loss: 0.1519, Val Loss: 0.2608
# Validation loss decreased (0.282593 --> 0.260845).  Saving model ...
# Epoch [7/10], Train Loss: 0.1357, Val Loss: 0.2439
# Validation loss decreased (0.260845 --> 0.243890).  Saving model ...
# Epoch [8/10], Train Loss: 0.1304, Val Loss: 0.2298
# Validation loss decreased (0.243890 --> 0.229751).  Saving model ...
# Epoch [9/10], Train Loss: 0.1176, Val Loss: 0.2186
# Validation loss decreased (0.229751 --> 0.218628).  Saving model ...
# Epoch [10/10], Train Loss: 0.1131, Val Loss: 0.2096
# Validation loss decreased (0.218628 --> 0.209618).  Saving model ...
# Folding 3/5
# Epoch [1/10], Train Loss: 0.3943, Val Loss: 0.4596
# Validation loss decreased (inf --> 0.459633).  Saving model ...
# Epoch [2/10], Train Loss: 0.3135, Val Loss: 0.3836
# Validation loss decreased (0.459633 --> 0.383571).  Saving model ...
# Epoch [3/10], Train Loss: 0.2593, Val Loss: 0.3304
# Validation loss decreased (0.383571 --> 0.330445).  Saving model ...
# Epoch [4/10], Train Loss: 0.2258, Val Loss: 0.2917
# Validation loss decreased (0.330445 --> 0.291723).  Saving model ...
# Epoch [5/10], Train Loss: 0.1927, Val Loss: 0.2622
# Validation loss decreased (0.291723 --> 0.262214).  Saving model ...
# Epoch [6/10], Train Loss: 0.1720, Val Loss: 0.2386
# Validation loss decreased (0.262214 --> 0.238585).  Saving model ...
# Epoch [7/10], Train Loss: 0.1553, Val Loss: 0.2196
# Validation loss decreased (0.238585 --> 0.219613).  Saving model ...
# Epoch [8/10], Train Loss: 0.1410, Val Loss: 0.2045
# Validation loss decreased (0.219613 --> 0.204482).  Saving model ...
# Epoch [9/10], Train Loss: 0.1322, Val Loss: 0.1920
# Validation loss decreased (0.204482 --> 0.191957).  Saving model ...
# Epoch [10/10], Train Loss: 0.1193, Val Loss: 0.1821
# Validation loss decreased (0.191957 --> 0.182059).  Saving model ...
# Folding 4/5
# Epoch [1/10], Train Loss: 0.3180, Val Loss: 0.4234
# Validation loss decreased (inf --> 0.423429).  Saving model ...
# Epoch [2/10], Train Loss: 0.2505, Val Loss: 0.3546
# Validation loss decreased (0.423429 --> 0.354636).  Saving model ...
# Epoch [3/10], Train Loss: 0.2021, Val Loss: 0.3060
# Validation loss decreased (0.354636 --> 0.305966).  Saving model ...
# Epoch [4/10], Train Loss: 0.1721, Val Loss: 0.2704
# Validation loss decreased (0.305966 --> 0.270400).  Saving model ...
# Epoch [5/10], Train Loss: 0.1486, Val Loss: 0.2441
# Validation loss decreased (0.270400 --> 0.244130).  Saving model ...
# Epoch [6/10], Train Loss: 0.1330, Val Loss: 0.2244
# Validation loss decreased (0.244130 --> 0.224413).  Saving model ...
# Epoch [7/10], Train Loss: 0.1198, Val Loss: 0.2097
# Validation loss decreased (0.224413 --> 0.209713).  Saving model ...
# Epoch [8/10], Train Loss: 0.1107, Val Loss: 0.1984
# Validation loss decreased (0.209713 --> 0.198370).  Saving model ...
# Epoch [9/10], Train Loss: 0.1039, Val Loss: 0.1896
# Validation loss decreased (0.198370 --> 0.189554).  Saving model ...
# Epoch [10/10], Train Loss: 0.0997, Val Loss: 0.1827
# Validation loss decreased (0.189554 --> 0.182658).  Saving model ...
# Folding 5/5
# Epoch [1/10], Train Loss: 0.1641, Val Loss: 0.2828
# Validation loss decreased (inf --> 0.282806).  Saving model ...
# Epoch [2/10], Train Loss: 0.1384, Val Loss: 0.2522
# Validation loss decreased (0.282806 --> 0.252152).  Saving model ...
# Epoch [3/10], Train Loss: 0.1205, Val Loss: 0.2306
# Validation loss decreased (0.252152 --> 0.230627).  Saving model ...
# Epoch [4/10], Train Loss: 0.1079, Val Loss: 0.2151
# Validation loss decreased (0.230627 --> 0.215056).  Saving model ...
# Epoch [5/10], Train Loss: 0.0996, Val Loss: 0.2033
# Validation loss decreased (0.215056 --> 0.203326).  Saving model ...
# Epoch [6/10], Train Loss: 0.0935, Val Loss: 0.1946
# Validation loss decreased (0.203326 --> 0.194564).  Saving model ...
# Epoch [7/10], Train Loss: 0.0889, Val Loss: 0.1876
# Validation loss decreased (0.194564 --> 0.187645).  Saving model ...
# Epoch [8/10], Train Loss: 0.0855, Val Loss: 0.1823
# Validation loss decreased (0.187645 --> 0.182287).  Saving model ...
# Epoch [9/10], Train Loss: 0.0820, Val Loss: 0.1782
# Validation loss decreased (0.182287 --> 0.178191).  Saving model ...
# Epoch [10/10], Train Loss: 0.0793, Val Loss: 0.1752
# Validation loss decreased (0.178191 --> 0.175195).  Saving model ...
# Testing L2 penalty: 0.0001
# Folding 1/5
# Epoch [1/10], Train Loss: 0.1048, Val Loss: 0.1520
# Validation loss decreased (inf --> 0.152044).  Saving model ...
# Epoch [2/10], Train Loss: 0.0990, Val Loss: 0.1496
# Validation loss decreased (0.152044 --> 0.149582).  Saving model ...
# Epoch [3/10], Train Loss: 0.0938, Val Loss: 0.1478
# Validation loss decreased (0.149582 --> 0.147846).  Saving model ...
# Epoch [4/10], Train Loss: 0.0918, Val Loss: 0.1465
# Validation loss decreased (0.147846 --> 0.146512).  Saving model ...
# Epoch [5/10], Train Loss: 0.0896, Val Loss: 0.1454
# Validation loss decreased (0.146512 --> 0.145374).  Saving model ...
# Epoch [6/10], Train Loss: 0.0880, Val Loss: 0.1443
# Validation loss decreased (0.145374 --> 0.144308).  Saving model ...
# Epoch [7/10], Train Loss: 0.0847, Val Loss: 0.1434
# Validation loss decreased (0.144308 --> 0.143420).  Saving model ...
# Epoch [8/10], Train Loss: 0.0837, Val Loss: 0.1425
# Validation loss decreased (0.143420 --> 0.142549).  Saving model ...
# Epoch [9/10], Train Loss: 0.0817, Val Loss: 0.1419
# Validation loss decreased (0.142549 --> 0.141882).  Saving model ...
# Epoch [10/10], Train Loss: 0.0811, Val Loss: 0.1412
# Validation loss decreased (0.141882 --> 0.141247).  Saving model ...
# Folding 2/5
# Epoch [1/10], Train Loss: 0.2611, Val Loss: 0.4638
# Validation loss decreased (inf --> 0.463845).  Saving model ...
# Epoch [2/10], Train Loss: 0.2206, Val Loss: 0.4123
# Validation loss decreased (0.463845 --> 0.412264).  Saving model ...
# Epoch [3/10], Train Loss: 0.1847, Val Loss: 0.3716
# Validation loss decreased (0.412264 --> 0.371614).  Saving model ...
# Epoch [4/10], Train Loss: 0.1674, Val Loss: 0.3382
# Validation loss decreased (0.371614 --> 0.338201).  Saving model ...
# Epoch [5/10], Train Loss: 0.1450, Val Loss: 0.3115
# Validation loss decreased (0.338201 --> 0.311542).  Saving model ...
# Epoch [6/10], Train Loss: 0.1306, Val Loss: 0.2895
# Validation loss decreased (0.311542 --> 0.289492).  Saving model ...
# Epoch [7/10], Train Loss: 0.1170, Val Loss: 0.2715
# Validation loss decreased (0.289492 --> 0.271520).  Saving model ...
# Epoch [8/10], Train Loss: 0.1129, Val Loss: 0.2556
# Validation loss decreased (0.271520 --> 0.255640).  Saving model ...
# Epoch [9/10], Train Loss: 0.1020, Val Loss: 0.2425
# Validation loss decreased (0.255640 --> 0.242491).  Saving model ...
# Epoch [10/10], Train Loss: 0.0964, Val Loss: 0.2314
# Validation loss decreased (0.242491 --> 0.231432).  Saving model ...
# Folding 3/5
# Epoch [1/10], Train Loss: 0.1871, Val Loss: 0.3094
# Validation loss decreased (inf --> 0.309358).  Saving model ...
# Epoch [2/10], Train Loss: 0.1604, Val Loss: 0.2789
# Validation loss decreased (0.309358 --> 0.278894).  Saving model ...
# Epoch [3/10], Train Loss: 0.1407, Val Loss: 0.2559
# Validation loss decreased (0.278894 --> 0.255870).  Saving model ...
# Epoch [4/10], Train Loss: 0.1247, Val Loss: 0.2386
# Validation loss decreased (0.255870 --> 0.238649).  Saving model ...
# Epoch [5/10], Train Loss: 0.1158, Val Loss: 0.2251
# Validation loss decreased (0.238649 --> 0.225135).  Saving model ...
# Epoch [6/10], Train Loss: 0.1113, Val Loss: 0.2141
# Validation loss decreased (0.225135 --> 0.214142).  Saving model ...
# Epoch [7/10], Train Loss: 0.1066, Val Loss: 0.2051
# Validation loss decreased (0.214142 --> 0.205061).  Saving model ...
# Epoch [8/10], Train Loss: 0.1021, Val Loss: 0.1978
# Validation loss decreased (0.205061 --> 0.197760).  Saving model ...
# Epoch [9/10], Train Loss: 0.0984, Val Loss: 0.1918
# Validation loss decreased (0.197760 --> 0.191846).  Saving model ...
# Epoch [10/10], Train Loss: 0.0955, Val Loss: 0.1869
# Validation loss decreased (0.191846 --> 0.186913).  Saving model ...
# Folding 4/5
# Epoch [1/10], Train Loss: 0.2069, Val Loss: 0.3673
# Validation loss decreased (inf --> 0.367275).  Saving model ...
# Epoch [2/10], Train Loss: 0.1751, Val Loss: 0.3339
# Validation loss decreased (0.367275 --> 0.333867).  Saving model ...
# Epoch [3/10], Train Loss: 0.1552, Val Loss: 0.3068
# Validation loss decreased (0.333867 --> 0.306820).  Saving model ...
# Epoch [4/10], Train Loss: 0.1427, Val Loss: 0.2839
# Validation loss decreased (0.306820 --> 0.283884).  Saving model ...
# Epoch [5/10], Train Loss: 0.1290, Val Loss: 0.2647
# Validation loss decreased (0.283884 --> 0.264697).  Saving model ...
# Epoch [6/10], Train Loss: 0.1179, Val Loss: 0.2486
# Validation loss decreased (0.264697 --> 0.248577).  Saving model ...
# Epoch [7/10], Train Loss: 0.1078, Val Loss: 0.2350
# Validation loss decreased (0.248577 --> 0.235049).  Saving model ...
# Epoch [8/10], Train Loss: 0.1023, Val Loss: 0.2233
# Validation loss decreased (0.235049 --> 0.223302).  Saving model ...
# Epoch [9/10], Train Loss: 0.0959, Val Loss: 0.2134
# Validation loss decreased (0.223302 --> 0.213374).  Saving model ...
# Epoch [10/10], Train Loss: 0.0913, Val Loss: 0.2048
# Validation loss decreased (0.213374 --> 0.204758).  Saving model ...
# Folding 5/5
# Epoch [1/10], Train Loss: 0.1788, Val Loss: 0.2693
# Validation loss decreased (inf --> 0.269295).  Saving model ...
# Epoch [2/10], Train Loss: 0.1606, Val Loss: 0.2474
# Validation loss decreased (0.269295 --> 0.247375).  Saving model ...
# Epoch [3/10], Train Loss: 0.1460, Val Loss: 0.2290
# Validation loss decreased (0.247375 --> 0.229048).  Saving model ...
# Epoch [4/10], Train Loss: 0.1331, Val Loss: 0.2136
# Validation loss decreased (0.229048 --> 0.213557).  Saving model ...
# Epoch [5/10], Train Loss: 0.1243, Val Loss: 0.2005
# Validation loss decreased (0.213557 --> 0.200525).  Saving model ...
# Epoch [6/10], Train Loss: 0.1168, Val Loss: 0.1893
# Validation loss decreased (0.200525 --> 0.189297).  Saving model ...
# Epoch [7/10], Train Loss: 0.1084, Val Loss: 0.1798
# Validation loss decreased (0.189297 --> 0.179762).  Saving model ...
# Epoch [8/10], Train Loss: 0.1042, Val Loss: 0.1714
# Validation loss decreased (0.179762 --> 0.171439).  Saving model ...
# Epoch [9/10], Train Loss: 0.1005, Val Loss: 0.1640
# Validation loss decreased (0.171439 --> 0.163955).  Saving model ...
# Epoch [10/10], Train Loss: 0.0940, Val Loss: 0.1576
# Validation loss decreased (0.163955 --> 0.157596).  Saving model ...
# Testing L2 penalty: 0.001
# Folding 1/5
# Epoch [1/10], Train Loss: 0.2875, Val Loss: 0.3787
# Validation loss decreased (inf --> 0.378657).  Saving model ...
# Epoch [2/10], Train Loss: 0.2306, Val Loss: 0.3220
# Validation loss decreased (0.378657 --> 0.321996).  Saving model ...
# Epoch [3/10], Train Loss: 0.1921, Val Loss: 0.2795
# Validation loss decreased (0.321996 --> 0.279465).  Saving model ...
# Epoch [4/10], Train Loss: 0.1613, Val Loss: 0.2480
# Validation loss decreased (0.279465 --> 0.247960).  Saving model ...
# Epoch [5/10], Train Loss: 0.1391, Val Loss: 0.2245
# Validation loss decreased (0.247960 --> 0.224539).  Saving model ...
# Epoch [6/10], Train Loss: 0.1269, Val Loss: 0.2064
# Validation loss decreased (0.224539 --> 0.206367).  Saving model ...
# Epoch [7/10], Train Loss: 0.1139, Val Loss: 0.1928
# Validation loss decreased (0.206367 --> 0.192777).  Saving model ...
# Epoch [8/10], Train Loss: 0.1045, Val Loss: 0.1825
# Validation loss decreased (0.192777 --> 0.182483).  Saving model ...
# Epoch [9/10], Train Loss: 0.0970, Val Loss: 0.1746
# Validation loss decreased (0.182483 --> 0.174596).  Saving model ...
# Epoch [10/10], Train Loss: 0.0936, Val Loss: 0.1681
# Validation loss decreased (0.174596 --> 0.168123).  Saving model ...
# Folding 2/5
# Epoch [1/10], Train Loss: 0.3085, Val Loss: 0.4781
# Validation loss decreased (inf --> 0.478123).  Saving model ...
# Epoch [2/10], Train Loss: 0.2479, Val Loss: 0.4158
# Validation loss decreased (0.478123 --> 0.415785).  Saving model ...
# Epoch [3/10], Train Loss: 0.2092, Val Loss: 0.3683
# Validation loss decreased (0.415785 --> 0.368289).  Saving model ...
# Epoch [4/10], Train Loss: 0.1770, Val Loss: 0.3322
# Validation loss decreased (0.368289 --> 0.332210).  Saving model ...
# Epoch [5/10], Train Loss: 0.1536, Val Loss: 0.3041
# Validation loss decreased (0.332210 --> 0.304136).  Saving model ...
# Epoch [6/10], Train Loss: 0.1406, Val Loss: 0.2815
# Validation loss decreased (0.304136 --> 0.281451).  Saving model ...
# Epoch [7/10], Train Loss: 0.1260, Val Loss: 0.2632
# Validation loss decreased (0.281451 --> 0.263190).  Saving model ...
# Epoch [8/10], Train Loss: 0.1166, Val Loss: 0.2481
# Validation loss decreased (0.263190 --> 0.248093).  Saving model ...
# Epoch [9/10], Train Loss: 0.1120, Val Loss: 0.2353
# Validation loss decreased (0.248093 --> 0.235257).  Saving model ...
# Epoch [10/10], Train Loss: 0.1045, Val Loss: 0.2246
# Validation loss decreased (0.235257 --> 0.224591).  Saving model ...
# Folding 3/5
# Epoch [1/10], Train Loss: 0.2449, Val Loss: 0.3820
# Validation loss decreased (inf --> 0.382035).  Saving model ...
# Epoch [2/10], Train Loss: 0.2089, Val Loss: 0.3422
# Validation loss decreased (0.382035 --> 0.342164).  Saving model ...
# Epoch [3/10], Train Loss: 0.1873, Val Loss: 0.3093
# Validation loss decreased (0.342164 --> 0.309283).  Saving model ...
# Epoch [4/10], Train Loss: 0.1640, Val Loss: 0.2826
# Validation loss decreased (0.309283 --> 0.282622).  Saving model ...
# Epoch [5/10], Train Loss: 0.1448, Val Loss: 0.2608
# Validation loss decreased (0.282622 --> 0.260766).  Saving model ...
# Epoch [6/10], Train Loss: 0.1350, Val Loss: 0.2419
# Validation loss decreased (0.260766 --> 0.241903).  Saving model ...
# Epoch [7/10], Train Loss: 0.1238, Val Loss: 0.2259
# Validation loss decreased (0.241903 --> 0.225858).  Saving model ...
# Epoch [8/10], Train Loss: 0.1132, Val Loss: 0.2125
# Validation loss decreased (0.225858 --> 0.212461).  Saving model ...
# Epoch [9/10], Train Loss: 0.1047, Val Loss: 0.2011
# Validation loss decreased (0.212461 --> 0.201096).  Saving model ...
# Epoch [10/10], Train Loss: 0.0964, Val Loss: 0.1915
# Validation loss decreased (0.201096 --> 0.191523).  Saving model ...
# Folding 4/5
# Epoch [1/10], Train Loss: 0.1160, Val Loss: 0.2171
# Validation loss decreased (inf --> 0.217101).  Saving model ...
# Epoch [2/10], Train Loss: 0.1062, Val Loss: 0.2071
# Validation loss decreased (0.217101 --> 0.207090).  Saving model ...
# Epoch [3/10], Train Loss: 0.1027, Val Loss: 0.1983
# Validation loss decreased (0.207090 --> 0.198347).  Saving model ...
# Epoch [4/10], Train Loss: 0.0985, Val Loss: 0.1907
# Validation loss decreased (0.198347 --> 0.190724).  Saving model ...
# Epoch [5/10], Train Loss: 0.0945, Val Loss: 0.1842
# Validation loss decreased (0.190724 --> 0.184194).  Saving model ...
# Epoch [6/10], Train Loss: 0.0931, Val Loss: 0.1782
# Validation loss decreased (0.184194 --> 0.178230).  Saving model ...
# Epoch [7/10], Train Loss: 0.0896, Val Loss: 0.1731
# Validation loss decreased (0.178230 --> 0.173143).  Saving model ...
# Epoch [8/10], Train Loss: 0.0845, Val Loss: 0.1688
# Validation loss decreased (0.173143 --> 0.168762).  Saving model ...
# Epoch [9/10], Train Loss: 0.0844, Val Loss: 0.1647
# Validation loss decreased (0.168762 --> 0.164710).  Saving model ...
# Epoch [10/10], Train Loss: 0.0810, Val Loss: 0.1612
# Validation loss decreased (0.164710 --> 0.161155).  Saving model ...
# Folding 5/5
# Epoch [1/10], Train Loss: 0.2348, Val Loss: 0.3800
# Validation loss decreased (inf --> 0.379950).  Saving model ...
# Epoch [2/10], Train Loss: 0.2046, Val Loss: 0.3466
# Validation loss decreased (0.379950 --> 0.346601).  Saving model ...
# Epoch [3/10], Train Loss: 0.1850, Val Loss: 0.3189
# Validation loss decreased (0.346601 --> 0.318873).  Saving model ...
# Epoch [4/10], Train Loss: 0.1680, Val Loss: 0.2957
# Validation loss decreased (0.318873 --> 0.295685).  Saving model ...
# Epoch [5/10], Train Loss: 0.1507, Val Loss: 0.2762
# Validation loss decreased (0.295685 --> 0.276235).  Saving model ...
# Epoch [6/10], Train Loss: 0.1409, Val Loss: 0.2595
# Validation loss decreased (0.276235 --> 0.259538).  Saving model ...
# Epoch [7/10], Train Loss: 0.1287, Val Loss: 0.2455
# Validation loss decreased (0.259538 --> 0.245506).  Saving model ...
# Epoch [8/10], Train Loss: 0.1223, Val Loss: 0.2334
# Validation loss decreased (0.245506 --> 0.233436).  Saving model ...
# Epoch [9/10], Train Loss: 0.1162, Val Loss: 0.2229
# Validation loss decreased (0.233436 --> 0.222895).  Saving model ...
# Epoch [10/10], Train Loss: 0.1117, Val Loss: 0.2136
# Validation loss decreased (0.222895 --> 0.213647).  Saving model ...
# Testing L2 penalty: 0.01
# Folding 1/5
# Epoch [1/10], Train Loss: 0.1862, Val Loss: 0.3129
# Validation loss decreased (inf --> 0.312939).  Saving model ...
# Epoch [2/10], Train Loss: 0.1663, Val Loss: 0.2852
# Validation loss decreased (0.312939 --> 0.285172).  Saving model ...
# Epoch [3/10], Train Loss: 0.1473, Val Loss: 0.2633
# Validation loss decreased (0.285172 --> 0.263302).  Saving model ...
# Epoch [4/10], Train Loss: 0.1354, Val Loss: 0.2451
# Validation loss decreased (0.263302 --> 0.245147).  Saving model ...
# Epoch [5/10], Train Loss: 0.1215, Val Loss: 0.2311
# Validation loss decreased (0.245147 --> 0.231112).  Saving model ...
# Epoch [6/10], Train Loss: 0.1155, Val Loss: 0.2199
# Validation loss decreased (0.231112 --> 0.219858).  Saving model ...
# Epoch [7/10], Train Loss: 0.1094, Val Loss: 0.2106
# Validation loss decreased (0.219858 --> 0.210590).  Saving model ...
# Epoch [8/10], Train Loss: 0.1021, Val Loss: 0.2031
# Validation loss decreased (0.210590 --> 0.203079).  Saving model ...
# Epoch [9/10], Train Loss: 0.1004, Val Loss: 0.1963
# Validation loss decreased (0.203079 --> 0.196329).  Saving model ...
# Epoch [10/10], Train Loss: 0.0972, Val Loss: 0.1907
# Validation loss decreased (0.196329 --> 0.190657).  Saving model ...
# Folding 2/5
# Epoch [1/10], Train Loss: 0.3224, Val Loss: 0.5112
# Validation loss decreased (inf --> 0.511221).  Saving model ...
# Epoch [2/10], Train Loss: 0.2573, Val Loss: 0.4442
# Validation loss decreased (0.511221 --> 0.444178).  Saving model ...
# Epoch [3/10], Train Loss: 0.2128, Val Loss: 0.3935
# Validation loss decreased (0.444178 --> 0.393549).  Saving model ...
# Epoch [4/10], Train Loss: 0.1818, Val Loss: 0.3550
# Validation loss decreased (0.393549 --> 0.354950).  Saving model ...
# Epoch [5/10], Train Loss: 0.1570, Val Loss: 0.3253
# Validation loss decreased (0.354950 --> 0.325317).  Saving model ...
# Epoch [6/10], Train Loss: 0.1406, Val Loss: 0.3018
# Validation loss decreased (0.325317 --> 0.301795).  Saving model ...
# Epoch [7/10], Train Loss: 0.1232, Val Loss: 0.2833
# Validation loss decreased (0.301795 --> 0.283273).  Saving model ...
# Epoch [8/10], Train Loss: 0.1184, Val Loss: 0.2674
# Validation loss decreased (0.283273 --> 0.267429).  Saving model ...
# Epoch [9/10], Train Loss: 0.1074, Val Loss: 0.2548
# Validation loss decreased (0.267429 --> 0.254787).  Saving model ...
# Epoch [10/10], Train Loss: 0.1027, Val Loss: 0.2440
# Validation loss decreased (0.254787 --> 0.244040).  Saving model ...
# Folding 3/5
# Epoch [1/10], Train Loss: 0.4271, Val Loss: 0.5386
# Validation loss decreased (inf --> 0.538557).  Saving model ...
# Epoch [2/10], Train Loss: 0.3325, Val Loss: 0.4478
# Validation loss decreased (0.538557 --> 0.447774).  Saving model ...
# Epoch [3/10], Train Loss: 0.2703, Val Loss: 0.3792
# Validation loss decreased (0.447774 --> 0.379153).  Saving model ...
# Epoch [4/10], Train Loss: 0.2199, Val Loss: 0.3273
# Validation loss decreased (0.379153 --> 0.327332).  Saving model ...
# Epoch [5/10], Train Loss: 0.1824, Val Loss: 0.2876
# Validation loss decreased (0.327332 --> 0.287575).  Saving model ...
# Epoch [6/10], Train Loss: 0.1590, Val Loss: 0.2561
# Validation loss decreased (0.287575 --> 0.256121).  Saving model ...
# Epoch [7/10], Train Loss: 0.1349, Val Loss: 0.2319
# Validation loss decreased (0.256121 --> 0.231880).  Saving model ...
# Epoch [8/10], Train Loss: 0.1203, Val Loss: 0.2128
# Validation loss decreased (0.231880 --> 0.212836).  Saving model ...
# Epoch [9/10], Train Loss: 0.1086, Val Loss: 0.1979
# Validation loss decreased (0.212836 --> 0.197867).  Saving model ...
# Epoch [10/10], Train Loss: 0.1014, Val Loss: 0.1856
# Validation loss decreased (0.197867 --> 0.185622).  Saving model ...
# Folding 4/5
# Epoch [1/10], Train Loss: 0.3202, Val Loss: 0.4734
# Validation loss decreased (inf --> 0.473439).  Saving model ...
# Epoch [2/10], Train Loss: 0.2728, Val Loss: 0.4199
# Validation loss decreased (0.473439 --> 0.419920).  Saving model ...
# Epoch [3/10], Train Loss: 0.2369, Val Loss: 0.3760
# Validation loss decreased (0.419920 --> 0.375985).  Saving model ...
# Epoch [4/10], Train Loss: 0.2087, Val Loss: 0.3394
# Validation loss decreased (0.375985 --> 0.339353).  Saving model ...
# Epoch [5/10], Train Loss: 0.1818, Val Loss: 0.3091
# Validation loss decreased (0.339353 --> 0.309076).  Saving model ...
# Epoch [6/10], Train Loss: 0.1632, Val Loss: 0.2836
# Validation loss decreased (0.309076 --> 0.283604).  Saving model ...
# Epoch [7/10], Train Loss: 0.1482, Val Loss: 0.2622
# Validation loss decreased (0.283604 --> 0.262170).  Saving model ...
# Epoch [8/10], Train Loss: 0.1353, Val Loss: 0.2442
# Validation loss decreased (0.262170 --> 0.244241).  Saving model ...
# Epoch [9/10], Train Loss: 0.1235, Val Loss: 0.2289
# Validation loss decreased (0.244241 --> 0.228853).  Saving model ...
# Epoch [10/10], Train Loss: 0.1137, Val Loss: 0.2157
# Validation loss decreased (0.228853 --> 0.215741).  Saving model ...
# Folding 5/5
# Epoch [1/10], Train Loss: 0.2119, Val Loss: 0.3194
# Validation loss decreased (inf --> 0.319351).  Saving model ...
# Epoch [2/10], Train Loss: 0.1818, Val Loss: 0.2837
# Validation loss decreased (0.319351 --> 0.283691).  Saving model ...
# Epoch [3/10], Train Loss: 0.1598, Val Loss: 0.2558
# Validation loss decreased (0.283691 --> 0.255839).  Saving model ...
# Epoch [4/10], Train Loss: 0.1467, Val Loss: 0.2337
# Validation loss decreased (0.255839 --> 0.233693).  Saving model ...
# Epoch [5/10], Train Loss: 0.1324, Val Loss: 0.2162
# Validation loss decreased (0.233693 --> 0.216183).  Saving model ...
# Epoch [6/10], Train Loss: 0.1226, Val Loss: 0.2020
# ...
# Epoch [10/10], Train Loss: 0.0895, Val Loss: 0.1780
# Validation loss decreased (0.186044 --> 0.177952).  Saving model ...
# Folding 3/5
# Epoch [1/10], Train Loss: 0.1643, Val Loss: 0.2788
# Validation loss decreased (inf --> 0.278839).  Saving model ...
# Epoch [2/10], Train Loss: 0.1443, Val Loss: 0.2544
# Validation loss decreased (0.278839 --> 0.254353).  Saving model ...
# Epoch [3/10], Train Loss: 0.1313, Val Loss: 0.2338
# Validation loss decreased (0.254353 --> 0.233842).  Saving model ...
# Epoch [4/10], Train Loss: 0.1166, Val Loss: 0.2170
# Validation loss decreased (0.233842 --> 0.216981).  Saving model ...
# Epoch [5/10], Train Loss: 0.1079, Val Loss: 0.2027
# Validation loss decreased (0.216981 --> 0.202719).  Saving model ...
# Epoch [6/10], Train Loss: 0.0975, Val Loss: 0.1910
# Validation loss decreased (0.202719 --> 0.190985).  Saving model ...
# Epoch [7/10], Train Loss: 0.0913, Val Loss: 0.1810
# Validation loss decreased (0.190985 --> 0.180978).  Saving model ...
# Epoch [8/10], Train Loss: 0.0855, Val Loss: 0.1724
# Validation loss decreased (0.180978 --> 0.172424).  Saving model ...
# Epoch [9/10], Train Loss: 0.0822, Val Loss: 0.1649
# Validation loss decreased (0.172424 --> 0.164855).  Saving model ...
# Epoch [10/10], Train Loss: 0.0781, Val Loss: 0.1586
# Validation loss decreased (0.164855 --> 0.158606).  Saving model ...
# Folding 4/5
# Epoch [1/10], Train Loss: 0.1127, Val Loss: 0.2149
# Validation loss decreased (inf --> 0.214909).  Saving model ...
# Epoch [2/10], Train Loss: 0.1017, Val Loss: 0.1965
# Validation loss decreased (0.214909 --> 0.196503).  Saving model ...
# Epoch [3/10], Train Loss: 0.0902, Val Loss: 0.1834
# Validation loss decreased (0.196503 --> 0.183429).  Saving model ...
# Epoch [4/10], Train Loss: 0.0850, Val Loss: 0.1735
# Validation loss decreased (0.183429 --> 0.173496).  Saving model ...
# Epoch [5/10], Train Loss: 0.0802, Val Loss: 0.1657
# Validation loss decreased (0.173496 --> 0.165749).  Saving model ...
# Epoch [6/10], Train Loss: 0.0794, Val Loss: 0.1593
# Validation loss decreased (0.165749 --> 0.159307).  Saving model ...
# Epoch [7/10], Train Loss: 0.0738, Val Loss: 0.1546
# Validation loss decreased (0.159307 --> 0.154554).  Saving model ...
# Epoch [8/10], Train Loss: 0.0744, Val Loss: 0.1503
# Validation loss decreased (0.154554 --> 0.150312).  Saving model ...
# Epoch [9/10], Train Loss: 0.0708, Val Loss: 0.1471
# Validation loss decreased (0.150312 --> 0.147070).  Saving model ...
# Epoch [10/10], Train Loss: 0.0711, Val Loss: 0.1440
# Validation loss decreased (0.147070 --> 0.144039).  Saving model ...
# Folding 5/5
# Epoch [1/10], Train Loss: 0.2444, Val Loss: 0.3871
# Validation loss decreased (inf --> 0.387123).  Saving model ...
# Epoch [2/10], Train Loss: 0.2008, Val Loss: 0.3402
# Validation loss decreased (0.387123 --> 0.340177).  Saving model ...
# Epoch [3/10], Train Loss: 0.1674, Val Loss: 0.3042
# Validation loss decreased (0.340177 --> 0.304216).  Saving model ...
# Epoch [4/10], Train Loss: 0.1455, Val Loss: 0.2761
# Validation loss decreased (0.304216 --> 0.276110).  Saving model ...
# Epoch [5/10], Train Loss: 0.1289, Val Loss: 0.2539
# Validation loss decreased (0.276110 --> 0.253852).  Saving model ...
# Epoch [6/10], Train Loss: 0.1172, Val Loss: 0.2359
# Validation loss decreased (0.253852 --> 0.235950).  Saving model ...
# Epoch [7/10], Train Loss: 0.1071, Val Loss: 0.2217
# Validation loss decreased (0.235950 --> 0.221678).  Saving model ...
# Epoch [8/10], Train Loss: 0.0965, Val Loss: 0.2105
# Validation loss decreased (0.221678 --> 0.210480).  Saving model ...
# Epoch [9/10], Train Loss: 0.0933, Val Loss: 0.2009
# Validation loss decreased (0.210480 --> 0.200865).  Saving model ...
# Epoch [10/10], Train Loss: 0.0871, Val Loss: 0.1931
# Validation loss decreased (0.200865 --> 0.193100).  Saving model ...
# Testing L2 penalty: 0.1
# Folding 1/5
# Epoch [1/10], Train Loss: 0.2373, Val Loss: 0.2918
# Validation loss decreased (inf --> 0.291848).  Saving model ...
# Epoch [2/10], Train Loss: 0.1911, Val Loss: 0.2472
# Validation loss decreased (0.291848 --> 0.247203).  Saving model ...
# Epoch [3/10], Train Loss: 0.1593, Val Loss: 0.2138
# Validation loss decreased (0.247203 --> 0.213773).  Saving model ...
# Epoch [4/10], Train Loss: 0.1373, Val Loss: 0.1892
# Validation loss decreased (0.213773 --> 0.189241).  Saving model ...
# Epoch [5/10], Train Loss: 0.1223, Val Loss: 0.1710
# Validation loss decreased (0.189241 --> 0.170950).  Saving model ...
# Epoch [6/10], Train Loss: 0.1058, Val Loss: 0.1574
# Validation loss decreased (0.170950 --> 0.157373).  Saving model ...
# Epoch [7/10], Train Loss: 0.0974, Val Loss: 0.1468
# Validation loss decreased (0.157373 --> 0.146808).  Saving model ...
# Epoch [8/10], Train Loss: 0.0902, Val Loss: 0.1385
# Validation loss decreased (0.146808 --> 0.138529).  Saving model ...
# Epoch [9/10], Train Loss: 0.0849, Val Loss: 0.1319
# Validation loss decreased (0.138529 --> 0.131918).  Saving model ...
# Epoch [10/10], Train Loss: 0.0798, Val Loss: 0.1266
# Validation loss decreased (0.131918 --> 0.126573).  Saving model ...
# Folding 2/5
# Epoch [1/10], Train Loss: 0.3315, Val Loss: 0.4960
# Validation loss decreased (inf --> 0.496033).  Saving model ...
# Epoch [2/10], Train Loss: 0.2731, Val Loss: 0.4311
# Validation loss decreased (0.496033 --> 0.431113).  Saving model ...
# Epoch [3/10], Train Loss: 0.2316, Val Loss: 0.3791
# Validation loss decreased (0.431113 --> 0.379075).  Saving model ...
# Epoch [4/10], Train Loss: 0.1934, Val Loss: 0.3398
# Validation loss decreased (0.379075 --> 0.339788).  Saving model ...
# Epoch [5/10], Train Loss: 0.1689, Val Loss: 0.3093
# Validation loss decreased (0.339788 --> 0.309269).  Saving model ...
# Epoch [6/10], Train Loss: 0.1508, Val Loss: 0.2845
# Validation loss decreased (0.309269 --> 0.284537).  Saving model ...
# Epoch [7/10], Train Loss: 0.1333, Val Loss: 0.2646
# Validation loss decreased (0.284537 --> 0.264615).  Saving model ...
# Epoch [8/10], Train Loss: 0.1187, Val Loss: 0.2482
# Validation loss decreased (0.264615 --> 0.248204).  Saving model ...
# Epoch [9/10], Train Loss: 0.1125, Val Loss: 0.2340
# Validation loss decreased (0.248204 --> 0.234037).  Saving model ...
# Epoch [10/10], Train Loss: 0.1005, Val Loss: 0.2225
# Validation loss decreased (0.234037 --> 0.222459).  Saving model ...
# Folding 3/5
# Epoch [1/10], Train Loss: 0.3119, Val Loss: 0.4698
# Validation loss decreased (inf --> 0.469774).  Saving model ...
# Epoch [2/10], Train Loss: 0.2576, Val Loss: 0.4132
# Validation loss decreased (0.469774 --> 0.413213).  Saving model ...
# Epoch [3/10], Train Loss: 0.2179, Val Loss: 0.3681
# Validation loss decreased (0.413213 --> 0.368145).  Saving model ...
# Epoch [4/10], Train Loss: 0.1883, Val Loss: 0.3316
# Validation loss decreased (0.368145 --> 0.331620).  Saving model ...
# Epoch [5/10], Train Loss: 0.1635, Val Loss: 0.3012
# Validation loss decreased (0.331620 --> 0.301219).  Saving model ...
# Epoch [6/10], Train Loss: 0.1457, Val Loss: 0.2754
# Validation loss decreased (0.301219 --> 0.275360).  Saving model ...
# Epoch [7/10], Train Loss: 0.1318, Val Loss: 0.2538
# Validation loss decreased (0.275360 --> 0.253808).  Saving model ...
# Epoch [8/10], Train Loss: 0.1187, Val Loss: 0.2362
# Validation loss decreased (0.253808 --> 0.236218).  Saving model ...
# Epoch [9/10], Train Loss: 0.1110, Val Loss: 0.2215
# Validation loss decreased (0.236218 --> 0.221478).  Saving model ...
# Epoch [10/10], Train Loss: 0.0999, Val Loss: 0.2095
# Validation loss decreased (0.221478 --> 0.209490).  Saving model ...
# Folding 4/5
# Epoch [1/10], Train Loss: 0.2215, Val Loss: 0.3446
# Validation loss decreased (inf --> 0.344622).  Saving model ...
# Epoch [2/10], Train Loss: 0.1858, Val Loss: 0.3027
# Validation loss decreased (0.344622 --> 0.302699).  Saving model ...
# Epoch [3/10], Train Loss: 0.1565, Val Loss: 0.2699
# Validation loss decreased (0.302699 --> 0.269912).  Saving model ...
# Epoch [4/10], Train Loss: 0.1359, Val Loss: 0.2438
# Validation loss decreased (0.269912 --> 0.243779).  Saving model ...
# Epoch [5/10], Train Loss: 0.1174, Val Loss: 0.2235
# Validation loss decreased (0.243779 --> 0.223483).  Saving model ...
# Epoch [6/10], Train Loss: 0.1053, Val Loss: 0.2072
# Validation loss decreased (0.223483 --> 0.207157).  Saving model ...
# Epoch [7/10], Train Loss: 0.0987, Val Loss: 0.1937
# Validation loss decreased (0.207157 --> 0.193670).  Saving model ...
# Epoch [8/10], Train Loss: 0.0912, Val Loss: 0.1827
# Validation loss decreased (0.193670 --> 0.182659).  Saving model ...
# Epoch [9/10], Train Loss: 0.0863, Val Loss: 0.1733
# Validation loss decreased (0.182659 --> 0.173345).  Saving model ...
# Epoch [10/10], Train Loss: 0.0792, Val Loss: 0.1660
# Validation loss decreased (0.173345 --> 0.165971).  Saving model ...
# Folding 5/5
# Epoch [1/10], Train Loss: 0.1933, Val Loss: 0.2934
# Validation loss decreased (inf --> 0.293369).  Saving model ...
# Epoch [2/10], Train Loss: 0.1613, Val Loss: 0.2650
# Validation loss decreased (0.293369 --> 0.264971).  Saving model ...
# Epoch [3/10], Train Loss: 0.1401, Val Loss: 0.2428
# Validation loss decreased (0.264971 --> 0.242791).  Saving model ...
# Epoch [4/10], Train Loss: 0.1239, Val Loss: 0.2250
# Validation loss decreased (0.242791 --> 0.224954).  Saving model ...
# Epoch [5/10], Train Loss: 0.1128, Val Loss: 0.2100
# Validation loss decreased (0.224954 --> 0.210005).  Saving model ...
# Epoch [6/10], Train Loss: 0.1050, Val Loss: 0.1975
# Validation loss decreased (0.210005 --> 0.197502).  Saving model ...
# Epoch [7/10], Train Loss: 0.0969, Val Loss: 0.1872
# Validation loss decreased (0.197502 --> 0.187243).  Saving model ...
# Epoch [8/10], Train Loss: 0.0901, Val Loss: 0.1786
# Validation loss decreased (0.187243 --> 0.178641).  Saving model ...
# Epoch [9/10], Train Loss: 0.0850, Val Loss: 0.1712
# Validation loss decreased (0.178641 --> 0.171212).  Saving model ...
# Epoch [10/10], Train Loss: 0.0796, Val Loss: 0.1651
# Validation loss decreased (0.171212 --> 0.165089).  Saving model ...
# Testing L2 penalty: 1.0
# Folding 1/5
# Epoch [1/10], Train Loss: 0.1178, Val Loss: 0.1825
# Validation loss decreased (inf --> 0.182491).  Saving model ...
# Epoch [2/10], Train Loss: 0.1066, Val Loss: 0.1725
# Validation loss decreased (0.182491 --> 0.172540).  Saving model ...
# Epoch [3/10], Train Loss: 0.0970, Val Loss: 0.1650
# Validation loss decreased (0.172540 --> 0.165016).  Saving model ...
# Epoch [4/10], Train Loss: 0.0911, Val Loss: 0.1591
# Validation loss decreased (0.165016 --> 0.159065).  Saving model ...
# Epoch [5/10], Train Loss: 0.0856, Val Loss: 0.1545
# Validation loss decreased (0.159065 --> 0.154488).  Saving model ...
# Epoch [6/10], Train Loss: 0.0837, Val Loss: 0.1506
# Validation loss decreased (0.154488 --> 0.150631).  Saving model ...
# Epoch [7/10], Train Loss: 0.0791, Val Loss: 0.1478
# Validation loss decreased (0.150631 --> 0.147844).  Saving model ...
# Epoch [8/10], Train Loss: 0.0773, Val Loss: 0.1456
# Validation loss decreased (0.147844 --> 0.145563).  Saving model ...
# Epoch [9/10], Train Loss: 0.0758, Val Loss: 0.1437
# Validation loss decreased (0.145563 --> 0.143734).  Saving model ...
# Epoch [10/10], Train Loss: 0.0745, Val Loss: 0.1423
# Validation loss decreased (0.143734 --> 0.142336).  Saving model ...
# Folding 2/5
# Epoch [1/10], Train Loss: 0.1341, Val Loss: 0.2373
# Validation loss decreased (inf --> 0.237272).  Saving model ...
# Epoch [2/10], Train Loss: 0.1214, Val Loss: 0.2210
# Validation loss decreased (0.237272 --> 0.220969).  Saving model ...
# Epoch [3/10], Train Loss: 0.1085, Val Loss: 0.2086
# Validation loss decreased (0.220969 --> 0.208573).  Saving model ...
# Epoch [4/10], Train Loss: 0.1014, Val Loss: 0.1989
# Validation loss decreased (0.208573 --> 0.198878).  Saving model ...
# Epoch [5/10], Train Loss: 0.0944, Val Loss: 0.1914
# Validation loss decreased (0.198878 --> 0.191435).  Saving model ...
# Epoch [6/10], Train Loss: 0.0891, Val Loss: 0.1856
# Validation loss decreased (0.191435 --> 0.185559).  Saving model ...
# Epoch [7/10], Train Loss: 0.0874, Val Loss: 0.1807
# Validation loss decreased (0.185559 --> 0.180659).  Saving model ...
# Epoch [8/10], Train Loss: 0.0834, Val Loss: 0.1768
# Validation loss decreased (0.180659 --> 0.176797).  Saving model ...
# Epoch [9/10], Train Loss: 0.0790, Val Loss: 0.1738
# Validation loss decreased (0.176797 --> 0.173848).  Saving model ...
# Epoch [10/10], Train Loss: 0.0791, Val Loss: 0.1713
# Validation loss decreased (0.173848 --> 0.171305).  Saving model ...
# Folding 3/5
# Epoch [1/10], Train Loss: 0.1351, Val Loss: 0.2482
# Validation loss decreased (inf --> 0.248151).  Saving model ...
# Epoch [2/10], Train Loss: 0.1163, Val Loss: 0.2306
# Validation loss decreased (0.248151 --> 0.230579).  Saving model ...
# Epoch [3/10], Train Loss: 0.1068, Val Loss: 0.2172
# Validation loss decreased (0.230579 --> 0.217209).  Saving model ...
# Epoch [4/10], Train Loss: 0.1004, Val Loss: 0.2069
# Validation loss decreased (0.217209 --> 0.206941).  Saving model ...
# Epoch [5/10], Train Loss: 0.0936, Val Loss: 0.1991
# Validation loss decreased (0.206941 --> 0.199094).  Saving model ...
# Epoch [6/10], Train Loss: 0.0893, Val Loss: 0.1929
# Validation loss decreased (0.199094 --> 0.192896).  Saving model ...
# Epoch [7/10], Train Loss: 0.0859, Val Loss: 0.1882
# Validation loss decreased (0.192896 --> 0.188151).  Saving model ...
# Epoch [8/10], Train Loss: 0.0824, Val Loss: 0.1844
# Validation loss decreased (0.188151 --> 0.184424).  Saving model ...
# Epoch [9/10], Train Loss: 0.0818, Val Loss: 0.1813
# Validation loss decreased (0.184424 --> 0.181308).  Saving model ...
# Epoch [10/10], Train Loss: 0.0820, Val Loss: 0.1787
# Validation loss decreased (0.181308 --> 0.178683).  Saving model ...
# Folding 4/5
# Epoch [1/10], Train Loss: 0.1338, Val Loss: 0.2332
# Validation loss decreased (inf --> 0.233213).  Saving model ...
# Epoch [2/10], Train Loss: 0.1200, Val Loss: 0.2153
# Validation loss decreased (0.233213 --> 0.215259).  Saving model ...
# Epoch [3/10], Train Loss: 0.1088, Val Loss: 0.2013
# Validation loss decreased (0.215259 --> 0.201316).  Saving model ...
# Epoch [4/10], Train Loss: 0.0986, Val Loss: 0.1906
# Validation loss decreased (0.201316 --> 0.190608).  Saving model ...
# Epoch [5/10], Train Loss: 0.0921, Val Loss: 0.1821
# Validation loss decreased (0.190608 --> 0.182127).  Saving model ...
# Epoch [6/10], Train Loss: 0.0872, Val Loss: 0.1756
# Validation loss decreased (0.182127 --> 0.175556).  Saving model ...
# Epoch [7/10], Train Loss: 0.0829, Val Loss: 0.1703
# Validation loss decreased (0.175556 --> 0.170328).  Saving model ...
# Epoch [8/10], Train Loss: 0.0793, Val Loss: 0.1664
# Validation loss decreased (0.170328 --> 0.166365).  Saving model ...
# Epoch [9/10], Train Loss: 0.0785, Val Loss: 0.1630
# Validation loss decreased (0.166365 --> 0.163003).  Saving model ...
# Epoch [10/10], Train Loss: 0.0771, Val Loss: 0.1603
# Validation loss decreased (0.163003 --> 0.160347).  Saving model ...
# Folding 5/5
# Epoch [1/10], Train Loss: 0.1578, Val Loss: 0.2825
# Validation loss decreased (inf --> 0.282497).  Saving model ...
# Epoch [2/10], Train Loss: 0.1374, Val Loss: 0.2553
# Validation loss decreased (0.282497 --> 0.255271).  Saving model ...
# Epoch [3/10], Train Loss: 0.1223, Val Loss: 0.2347
# Validation loss decreased (0.255271 --> 0.234718).  Saving model ...
# Epoch [4/10], Train Loss: 0.1078, Val Loss: 0.2192
# Validation loss decreased (0.234718 --> 0.219165).  Saving model ...
# Epoch [5/10], Train Loss: 0.1009, Val Loss: 0.2069
# Validation loss decreased (0.219165 --> 0.206885).  Saving model ...
# Epoch [6/10], Train Loss: 0.0924, Val Loss: 0.1974
# Validation loss decreased (0.206885 --> 0.197428).  Saving model ...
# Epoch [7/10], Train Loss: 0.0903, Val Loss: 0.1897
# Validation loss decreased (0.197428 --> 0.189662).  Saving model ...
# Epoch [8/10], Train Loss: 0.0858, Val Loss: 0.1837
# Validation loss decreased (0.189662 --> 0.183681).  Saving model ...
# Epoch [9/10], Train Loss: 0.0819, Val Loss: 0.1790
# Validation loss decreased (0.183681 --> 0.179043).  Saving model ...
# Epoch [10/10], Train Loss: 0.0808, Val Loss: 0.1752
# Validation loss decreased (0.179043 --> 0.175169).  Saving model ...
# Best L2 penalty for Apple: 0.01
# Best L2 penalty for Google: 0.0001
# Best L2 penalty for Tesla: 1.0

# %%
# Train and save the model for Apple
model_apple = StockPredictor(input_size, hidden_layer_size, num_layers, output_size)
model_apple, train_losses_apple, val_losses_apple = train_and_validate(
    model_apple, train_loader_apple, val_loader_apple, num_epochs=500, weight_decay=best_penalty_apple)
torch.save(model_apple.state_dict(), '/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_2/model_apple.pth')

# Train and save the model for Google
model_google = StockPredictor(input_size, hidden_layer_size, num_layers, output_size)
model_google, train_losses_google, val_losses_google = train_and_validate(
    model_google, train_loader_google, val_loader_google, num_epochs=500, weight_decay=best_penalty_google)
torch.save(model_google.state_dict(), '/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_2/model_google.pth')

# Train and save the model for Tesla
model_tesla = StockPredictor(input_size, hidden_layer_size, num_layers, output_size)
model_tesla, train_losses_tesla, val_losses_tesla = train_and_validate(
    model_tesla, train_loader_tesla, val_loader_tesla, num_epochs=500, weight_decay=0.001)
torch.save(model_tesla.state_dict(), '/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_2/model_tesla.pth')

# Saving training and validation losses
with h5py.File('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_2/training_losses.h5', 'w') as f:
    f.create_dataset('train_losses_apple', data=np.array(train_losses_apple))
    f.create_dataset('val_losses_apple', data=np.array(val_losses_apple))
    f.create_dataset('train_losses_google', data=np.array(train_losses_google))
    f.create_dataset('val_losses_google', data=np.array(val_losses_google))
    f.create_dataset('train_losses_tesla', data=np.array(train_losses_tesla))
    f.create_dataset('val_losses_tesla', data=np.array(val_losses_tesla))
# Out:
# Epoch [1/500], Train Loss: 0.2856, Val Loss: 0.8030
# Validation loss decreased (inf --> 0.802952).  Saving model ...
# Epoch [2/500], Train Loss: 0.2164, Val Loss: 0.6764
# Validation loss decreased (0.802952 --> 0.676416).  Saving model ...
# Epoch [3/500], Train Loss: 0.1693, Val Loss: 0.5794
# Validation loss decreased (0.676416 --> 0.579447).  Saving model ...
# Epoch [4/500], Train Loss: 0.1368, Val Loss: 0.5057
# Validation loss decreased (0.579447 --> 0.505654).  Saving model ...
# Epoch [5/500], Train Loss: 0.1150, Val Loss: 0.4464
# Validation loss decreased (0.505654 --> 0.446379).  Saving model ...
# Epoch [6/500], Train Loss: 0.0990, Val Loss: 0.4007
# Validation loss decreased (0.446379 --> 0.400651).  Saving model ...
# Epoch [7/500], Train Loss: 0.0894, Val Loss: 0.3649
# Validation loss decreased (0.400651 --> 0.364861).  Saving model ...
# Epoch [8/500], Train Loss: 0.0817, Val Loss: 0.3361
# Validation loss decreased (0.364861 --> 0.336087).  Saving model ...
# Epoch [9/500], Train Loss: 0.0763, Val Loss: 0.3130
# Validation loss decreased (0.336087 --> 0.313006).  Saving model ...
# Epoch [10/500], Train Loss: 0.0720, Val Loss: 0.2938
# Validation loss decreased (0.313006 --> 0.293781).  Saving model ...
# Epoch [11/500], Train Loss: 0.0696, Val Loss: 0.2778
# Validation loss decreased (0.293781 --> 0.277824).  Saving model ...
# Epoch [12/500], Train Loss: 0.0671, Val Loss: 0.2646
# Validation loss decreased (0.277824 --> 0.264595).  Saving model ...
# Epoch [13/500], Train Loss: 0.0660, Val Loss: 0.2533
# Validation loss decreased (0.264595 --> 0.253276).  Saving model ...
# Epoch [14/500], Train Loss: 0.0638, Val Loss: 0.2443
# Validation loss decreased (0.253276 --> 0.244259).  Saving model ...
# Epoch [15/500], Train Loss: 0.0623, Val Loss: 0.2363
# Validation loss decreased (0.244259 --> 0.236349).  Saving model ...
# Epoch [16/500], Train Loss: 0.0610, Val Loss: 0.2296
# Validation loss decreased (0.236349 --> 0.229606).  Saving model ...
# Epoch [17/500], Train Loss: 0.0607, Val Loss: 0.2236
# Validation loss decreased (0.229606 --> 0.223561).  Saving model ...
# Epoch [18/500], Train Loss: 0.0600, Val Loss: 0.2180
# Validation loss decreased (0.223561 --> 0.217972).  Saving model ...
# Epoch [19/500], Train Loss: 0.0594, Val Loss: 0.2129
# Validation loss decreased (0.217972 --> 0.212885).  Saving model ...
# Epoch [20/500], Train Loss: 0.0582, Val Loss: 0.2088
# Validation loss decreased (0.212885 --> 0.208752).  Saving model ...
# Epoch [21/500], Train Loss: 0.0574, Val Loss: 0.2047
# Validation loss decreased (0.208752 --> 0.204677).  Saving model ...
# Epoch [22/500], Train Loss: 0.0568, Val Loss: 0.2013
# Validation loss decreased (0.204677 --> 0.201348).  Saving model ...
# Epoch [23/500], Train Loss: 0.0564, Val Loss: 0.1983
# Validation loss decreased (0.201348 --> 0.198285).  Saving model ...
# Epoch [24/500], Train Loss: 0.0557, Val Loss: 0.1953
# Validation loss decreased (0.198285 --> 0.195311).  Saving model ...
# Epoch [25/500], Train Loss: 0.0553, Val Loss: 0.1927
# Validation loss decreased (0.195311 --> 0.192708).  Saving model ...
# Epoch [26/500], Train Loss: 0.0543, Val Loss: 0.1903
# Validation loss decreased (0.192708 --> 0.190310).  Saving model ...
# Epoch [27/500], Train Loss: 0.0541, Val Loss: 0.1877
# Validation loss decreased (0.190310 --> 0.187676).  Saving model ...
# Epoch [28/500], Train Loss: 0.0534, Val Loss: 0.1854
# Validation loss decreased (0.187676 --> 0.185360).  Saving model ...
# Epoch [29/500], Train Loss: 0.0530, Val Loss: 0.1829
# Validation loss decreased (0.185360 --> 0.182909).  Saving model ...
# Epoch [30/500], Train Loss: 0.0520, Val Loss: 0.1810
# Validation loss decreased (0.182909 --> 0.180968).  Saving model ...
# Epoch [31/500], Train Loss: 0.0521, Val Loss: 0.1784
# Validation loss decreased (0.180968 --> 0.178434).  Saving model ...
# Epoch [32/500], Train Loss: 0.0507, Val Loss: 0.1767
# Validation loss decreased (0.178434 --> 0.176705).  Saving model ...
# Epoch [33/500], Train Loss: 0.0504, Val Loss: 0.1751
# Validation loss decreased (0.176705 --> 0.175069).  Saving model ...
# Epoch [34/500], Train Loss: 0.0499, Val Loss: 0.1733
# Validation loss decreased (0.175069 --> 0.173271).  Saving model ...
# Epoch [35/500], Train Loss: 0.0499, Val Loss: 0.1711
# Validation loss decreased (0.173271 --> 0.171143).  Saving model ...
# Epoch [36/500], Train Loss: 0.0490, Val Loss: 0.1694
# Validation loss decreased (0.171143 --> 0.169365).  Saving model ...
# Epoch [37/500], Train Loss: 0.0486, Val Loss: 0.1673
# Validation loss decreased (0.169365 --> 0.167294).  Saving model ...
# Epoch [38/500], Train Loss: 0.0485, Val Loss: 0.1655
# Validation loss decreased (0.167294 --> 0.165497).  Saving model ...
# Epoch [39/500], Train Loss: 0.0478, Val Loss: 0.1639
# Validation loss decreased (0.165497 --> 0.163885).  Saving model ...
# Epoch [40/500], Train Loss: 0.0476, Val Loss: 0.1620
# Validation loss decreased (0.163885 --> 0.162025).  Saving model ...
# Epoch [41/500], Train Loss: 0.0469, Val Loss: 0.1604
# Validation loss decreased (0.162025 --> 0.160382).  Saving model ...
# Epoch [42/500], Train Loss: 0.0465, Val Loss: 0.1582
# Validation loss decreased (0.160382 --> 0.158232).  Saving model ...
# Epoch [43/500], Train Loss: 0.0459, Val Loss: 0.1563
# Validation loss decreased (0.158232 --> 0.156340).  Saving model ...
# Epoch [44/500], Train Loss: 0.0458, Val Loss: 0.1546
# Validation loss decreased (0.156340 --> 0.154602).  Saving model ...
# Epoch [45/500], Train Loss: 0.0448, Val Loss: 0.1531
# Validation loss decreased (0.154602 --> 0.153115).  Saving model ...
# Epoch [46/500], Train Loss: 0.0446, Val Loss: 0.1516
# Validation loss decreased (0.153115 --> 0.151552).  Saving model ...
# Epoch [47/500], Train Loss: 0.0437, Val Loss: 0.1501
# Validation loss decreased (0.151552 --> 0.150084).  Saving model ...
# Epoch [48/500], Train Loss: 0.0437, Val Loss: 0.1485
# Validation loss decreased (0.150084 --> 0.148536).  Saving model ...
# Epoch [49/500], Train Loss: 0.0436, Val Loss: 0.1468
# Validation loss decreased (0.148536 --> 0.146826).  Saving model ...
# Epoch [50/500], Train Loss: 0.0429, Val Loss: 0.1450
# Validation loss decreased (0.146826 --> 0.145004).  Saving model ...
# Epoch [51/500], Train Loss: 0.0427, Val Loss: 0.1437
# Validation loss decreased (0.145004 --> 0.143685).  Saving model ...
# Epoch [52/500], Train Loss: 0.0419, Val Loss: 0.1421
# Validation loss decreased (0.143685 --> 0.142134).  Saving model ...
# Epoch [53/500], Train Loss: 0.0416, Val Loss: 0.1408
# Validation loss decreased (0.142134 --> 0.140773).  Saving model ...
# Epoch [54/500], Train Loss: 0.0412, Val Loss: 0.1391
# Validation loss decreased (0.140773 --> 0.139101).  Saving model ...
# Epoch [55/500], Train Loss: 0.0411, Val Loss: 0.1375
# Validation loss decreased (0.139101 --> 0.137465).  Saving model ...
# Epoch [56/500], Train Loss: 0.0408, Val Loss: 0.1358
# Validation loss decreased (0.137465 --> 0.135780).  Saving model ...
# Epoch [57/500], Train Loss: 0.0402, Val Loss: 0.1343
# Validation loss decreased (0.135780 --> 0.134265).  Saving model ...
# Epoch [58/500], Train Loss: 0.0396, Val Loss: 0.1329
# Validation loss decreased (0.134265 --> 0.132880).  Saving model ...
# Epoch [59/500], Train Loss: 0.0396, Val Loss: 0.1310
# Validation loss decreased (0.132880 --> 0.131015).  Saving model ...
# Epoch [60/500], Train Loss: 0.0387, Val Loss: 0.1296
# Validation loss decreased (0.131015 --> 0.129647).  Saving model ...
# Epoch [61/500], Train Loss: 0.0382, Val Loss: 0.1281
# Validation loss decreased (0.129647 --> 0.128139).  Saving model ...
# Epoch [62/500], Train Loss: 0.0380, Val Loss: 0.1269
# Validation loss decreased (0.128139 --> 0.126880).  Saving model ...
# Epoch [63/500], Train Loss: 0.0375, Val Loss: 0.1258
# Validation loss decreased (0.126880 --> 0.125838).  Saving model ...
# Epoch [64/500], Train Loss: 0.0374, Val Loss: 0.1241
# Validation loss decreased (0.125838 --> 0.124146).  Saving model ...
# Epoch [65/500], Train Loss: 0.0367, Val Loss: 0.1229
# Validation loss decreased (0.124146 --> 0.122933).  Saving model ...
# Epoch [66/500], Train Loss: 0.0364, Val Loss: 0.1217
# Validation loss decreased (0.122933 --> 0.121673).  Saving model ...
# Epoch [67/500], Train Loss: 0.0362, Val Loss: 0.1204
# Validation loss decreased (0.121673 --> 0.120369).  Saving model ...
# Epoch [68/500], Train Loss: 0.0359, Val Loss: 0.1191
# Validation loss decreased (0.120369 --> 0.119141).  Saving model ...
# Epoch [69/500], Train Loss: 0.0352, Val Loss: 0.1180
# Validation loss decreased (0.119141 --> 0.118036).  Saving model ...
# Epoch [70/500], Train Loss: 0.0351, Val Loss: 0.1167
# Validation loss decreased (0.118036 --> 0.116652).  Saving model ...
# Epoch [71/500], Train Loss: 0.0348, Val Loss: 0.1152
# Validation loss decreased (0.116652 --> 0.115238).  Saving model ...
# Epoch [72/500], Train Loss: 0.0344, Val Loss: 0.1140
# Validation loss decreased (0.115238 --> 0.113991).  Saving model ...
# Epoch [73/500], Train Loss: 0.0341, Val Loss: 0.1127
# Validation loss decreased (0.113991 --> 0.112667).  Saving model ...
# Epoch [74/500], Train Loss: 0.0336, Val Loss: 0.1111
# Validation loss decreased (0.112667 --> 0.111106).  Saving model ...
# Epoch [75/500], Train Loss: 0.0334, Val Loss: 0.1097
# Validation loss decreased (0.111106 --> 0.109749).  Saving model ...
# Epoch [76/500], Train Loss: 0.0328, Val Loss: 0.1088
# Validation loss decreased (0.109749 --> 0.108789).  Saving model ...
# Epoch [77/500], Train Loss: 0.0325, Val Loss: 0.1078
# Validation loss decreased (0.108789 --> 0.107795).  Saving model ...
# Epoch [78/500], Train Loss: 0.0324, Val Loss: 0.1066
# Validation loss decreased (0.107795 --> 0.106565).  Saving model ...
# Epoch [79/500], Train Loss: 0.0321, Val Loss: 0.1055
# Validation loss decreased (0.106565 --> 0.105460).  Saving model ...
# Epoch [80/500], Train Loss: 0.0316, Val Loss: 0.1042
# Validation loss decreased (0.105460 --> 0.104163).  Saving model ...
# Epoch [81/500], Train Loss: 0.0313, Val Loss: 0.1029
# Validation loss decreased (0.104163 --> 0.102876).  Saving model ...
# Epoch [82/500], Train Loss: 0.0313, Val Loss: 0.1016
# Validation loss decreased (0.102876 --> 0.101558).  Saving model ...
# Epoch [83/500], Train Loss: 0.0302, Val Loss: 0.1007
# Validation loss decreased (0.101558 --> 0.100746).  Saving model ...
# Epoch [84/500], Train Loss: 0.0305, Val Loss: 0.0997
# Validation loss decreased (0.100746 --> 0.099655).  Saving model ...
# Epoch [85/500], Train Loss: 0.0298, Val Loss: 0.0984
# Validation loss decreased (0.099655 --> 0.098432).  Saving model ...
# Epoch [86/500], Train Loss: 0.0298, Val Loss: 0.0971
# Validation loss decreased (0.098432 --> 0.097134).  Saving model ...
# Epoch [87/500], Train Loss: 0.0297, Val Loss: 0.0961
# Validation loss decreased (0.097134 --> 0.096147).  Saving model ...
# Epoch [88/500], Train Loss: 0.0293, Val Loss: 0.0950
# Validation loss decreased (0.096147 --> 0.095039).  Saving model ...
# Epoch [89/500], Train Loss: 0.0284, Val Loss: 0.0939
# Validation loss decreased (0.095039 --> 0.093861).  Saving model ...
# Epoch [90/500], Train Loss: 0.0283, Val Loss: 0.0929
# Validation loss decreased (0.093861 --> 0.092862).  Saving model ...
# Epoch [91/500], Train Loss: 0.0280, Val Loss: 0.0918
# Validation loss decreased (0.092862 --> 0.091824).  Saving model ...
# Epoch [92/500], Train Loss: 0.0280, Val Loss: 0.0909
# Validation loss decreased (0.091824 --> 0.090876).  Saving model ...
# Epoch [93/500], Train Loss: 0.0274, Val Loss: 0.0900
# Validation loss decreased (0.090876 --> 0.089959).  Saving model ...
# Epoch [94/500], Train Loss: 0.0273, Val Loss: 0.0890
# Validation loss decreased (0.089959 --> 0.088952).  Saving model ...
# Epoch [95/500], Train Loss: 0.0271, Val Loss: 0.0879
# Validation loss decreased (0.088952 --> 0.087897).  Saving model ...
# Epoch [96/500], Train Loss: 0.0268, Val Loss: 0.0870
# Validation loss decreased (0.087897 --> 0.087050).  Saving model ...
# Epoch [97/500], Train Loss: 0.0266, Val Loss: 0.0860
# Validation loss decreased (0.087050 --> 0.085976).  Saving model ...
# Epoch [98/500], Train Loss: 0.0264, Val Loss: 0.0849
# Validation loss decreased (0.085976 --> 0.084876).  Saving model ...
# Epoch [99/500], Train Loss: 0.0262, Val Loss: 0.0839
# Validation loss decreased (0.084876 --> 0.083850).  Saving model ...
# Epoch [100/500], Train Loss: 0.0256, Val Loss: 0.0829
# Validation loss decreased (0.083850 --> 0.082858).  Saving model ...
# Epoch [101/500], Train Loss: 0.0252, Val Loss: 0.0821
# Validation loss decreased (0.082858 --> 0.082130).  Saving model ...
# Epoch [102/500], Train Loss: 0.0252, Val Loss: 0.0813
# Validation loss decreased (0.082130 --> 0.081259).  Saving model ...
# Epoch [103/500], Train Loss: 0.0250, Val Loss: 0.0802
# Validation loss decreased (0.081259 --> 0.080174).  Saving model ...
# Epoch [104/500], Train Loss: 0.0246, Val Loss: 0.0793
# Validation loss decreased (0.080174 --> 0.079272).  Saving model ...
# Epoch [105/500], Train Loss: 0.0244, Val Loss: 0.0786
# Validation loss decreased (0.079272 --> 0.078619).  Saving model ...
# Epoch [106/500], Train Loss: 0.0239, Val Loss: 0.0777
# Validation loss decreased (0.078619 --> 0.077728).  Saving model ...
# Epoch [107/500], Train Loss: 0.0236, Val Loss: 0.0770
# Validation loss decreased (0.077728 --> 0.076998).  Saving model ...
# Epoch [108/500], Train Loss: 0.0237, Val Loss: 0.0761
# Validation loss decreased (0.076998 --> 0.076069).  Saving model ...
# Epoch [109/500], Train Loss: 0.0233, Val Loss: 0.0753
# Validation loss decreased (0.076069 --> 0.075342).  Saving model ...
# Epoch [110/500], Train Loss: 0.0231, Val Loss: 0.0744
# Validation loss decreased (0.075342 --> 0.074426).  Saving model ...
# Epoch [111/500], Train Loss: 0.0228, Val Loss: 0.0736
# Validation loss decreased (0.074426 --> 0.073592).  Saving model ...
# Epoch [112/500], Train Loss: 0.0225, Val Loss: 0.0727
# Validation loss decreased (0.073592 --> 0.072681).  Saving model ...
# Epoch [113/500], Train Loss: 0.0225, Val Loss: 0.0717
# Validation loss decreased (0.072681 --> 0.071703).  Saving model ...
# Epoch [114/500], Train Loss: 0.0220, Val Loss: 0.0710
# Validation loss decreased (0.071703 --> 0.070980).  Saving model ...
# Epoch [115/500], Train Loss: 0.0221, Val Loss: 0.0703
# Validation loss decreased (0.070980 --> 0.070261).  Saving model ...
# Epoch [116/500], Train Loss: 0.0217, Val Loss: 0.0694
# Validation loss decreased (0.070261 --> 0.069375).  Saving model ...
# Epoch [117/500], Train Loss: 0.0212, Val Loss: 0.0687
# Validation loss decreased (0.069375 --> 0.068654).  Saving model ...
# Epoch [118/500], Train Loss: 0.0213, Val Loss: 0.0678
# Validation loss decreased (0.068654 --> 0.067774).  Saving model ...
# Epoch [119/500], Train Loss: 0.0210, Val Loss: 0.0671
# Validation loss decreased (0.067774 --> 0.067116).  Saving model ...
# Epoch [120/500], Train Loss: 0.0205, Val Loss: 0.0664
# Validation loss decreased (0.067116 --> 0.066379).  Saving model ...
# Epoch [121/500], Train Loss: 0.0207, Val Loss: 0.0655
# Validation loss decreased (0.066379 --> 0.065492).  Saving model ...
# Epoch [122/500], Train Loss: 0.0203, Val Loss: 0.0646
# Validation loss decreased (0.065492 --> 0.064638).  Saving model ...
# Epoch [123/500], Train Loss: 0.0200, Val Loss: 0.0641
# Validation loss decreased (0.064638 --> 0.064079).  Saving model ...
# Epoch [124/500], Train Loss: 0.0198, Val Loss: 0.0634
# Validation loss decreased (0.064079 --> 0.063356).  Saving model ...
# Epoch [125/500], Train Loss: 0.0196, Val Loss: 0.0627
# Validation loss decreased (0.063356 --> 0.062683).  Saving model ...
# Epoch [126/500], Train Loss: 0.0195, Val Loss: 0.0619
# Validation loss decreased (0.062683 --> 0.061894).  Saving model ...
# Epoch [127/500], Train Loss: 0.0193, Val Loss: 0.0611
# Validation loss decreased (0.061894 --> 0.061091).  Saving model ...
# Epoch [128/500], Train Loss: 0.0191, Val Loss: 0.0604
# Validation loss decreased (0.061091 --> 0.060439).  Saving model ...
# Epoch [129/500], Train Loss: 0.0187, Val Loss: 0.0598
# Validation loss decreased (0.060439 --> 0.059822).  Saving model ...
# Epoch [130/500], Train Loss: 0.0185, Val Loss: 0.0591
# Validation loss decreased (0.059822 --> 0.059075).  Saving model ...
# Epoch [131/500], Train Loss: 0.0183, Val Loss: 0.0584
# Validation loss decreased (0.059075 --> 0.058354).  Saving model ...
# Epoch [132/500], Train Loss: 0.0183, Val Loss: 0.0577
# Validation loss decreased (0.058354 --> 0.057666).  Saving model ...
# Epoch [133/500], Train Loss: 0.0180, Val Loss: 0.0571
# Validation loss decreased (0.057666 --> 0.057104).  Saving model ...
# Epoch [134/500], Train Loss: 0.0176, Val Loss: 0.0564
# Validation loss decreased (0.057104 --> 0.056446).  Saving model ...
# Epoch [135/500], Train Loss: 0.0177, Val Loss: 0.0558
# Validation loss decreased (0.056446 --> 0.055837).  Saving model ...
# Epoch [136/500], Train Loss: 0.0175, Val Loss: 0.0552
# Validation loss decreased (0.055837 --> 0.055151).  Saving model ...
# Epoch [137/500], Train Loss: 0.0170, Val Loss: 0.0545
# Validation loss decreased (0.055151 --> 0.054451).  Saving model ...
# Epoch [138/500], Train Loss: 0.0170, Val Loss: 0.0538
# Validation loss decreased (0.054451 --> 0.053794).  Saving model ...
# Epoch [139/500], Train Loss: 0.0168, Val Loss: 0.0531
# Validation loss decreased (0.053794 --> 0.053136).  Saving model ...
# Epoch [140/500], Train Loss: 0.0166, Val Loss: 0.0526
# Validation loss decreased (0.053136 --> 0.052593).  Saving model ...
# Epoch [141/500], Train Loss: 0.0166, Val Loss: 0.0520
# Validation loss decreased (0.052593 --> 0.052001).  Saving model ...
# Epoch [142/500], Train Loss: 0.0163, Val Loss: 0.0514
# Validation loss decreased (0.052001 --> 0.051354).  Saving model ...
# Epoch [143/500], Train Loss: 0.0162, Val Loss: 0.0507
# Validation loss decreased (0.051354 --> 0.050680).  Saving model ...
# Epoch [144/500], Train Loss: 0.0158, Val Loss: 0.0503
# Validation loss decreased (0.050680 --> 0.050295).  Saving model ...
# Epoch [145/500], Train Loss: 0.0158, Val Loss: 0.0498
# Validation loss decreased (0.050295 --> 0.049809).  Saving model ...
# Epoch [146/500], Train Loss: 0.0154, Val Loss: 0.0492
# Validation loss decreased (0.049809 --> 0.049204).  Saving model ...
# Epoch [147/500], Train Loss: 0.0156, Val Loss: 0.0487
# Validation loss decreased (0.049204 --> 0.048654).  Saving model ...
# Epoch [148/500], Train Loss: 0.0155, Val Loss: 0.0481
# Validation loss decreased (0.048654 --> 0.048085).  Saving model ...
# Epoch [149/500], Train Loss: 0.0151, Val Loss: 0.0475
# Validation loss decreased (0.048085 --> 0.047514).  Saving model ...
# Epoch [150/500], Train Loss: 0.0150, Val Loss: 0.0469
# Validation loss decreased (0.047514 --> 0.046924).  Saving model ...
# Epoch [151/500], Train Loss: 0.0149, Val Loss: 0.0463
# Validation loss decreased (0.046924 --> 0.046339).  Saving model ...
# Epoch [152/500], Train Loss: 0.0146, Val Loss: 0.0458
# Validation loss decreased (0.046339 --> 0.045772).  Saving model ...
# Epoch [153/500], Train Loss: 0.0146, Val Loss: 0.0451
# Validation loss decreased (0.045772 --> 0.045137).  Saving model ...
# Epoch [154/500], Train Loss: 0.0143, Val Loss: 0.0447
# Validation loss decreased (0.045137 --> 0.044674).  Saving model ...
# Epoch [155/500], Train Loss: 0.0142, Val Loss: 0.0441
# Validation loss decreased (0.044674 --> 0.044140).  Saving model ...
# Epoch [156/500], Train Loss: 0.0141, Val Loss: 0.0436
# Validation loss decreased (0.044140 --> 0.043605).  Saving model ...
# Epoch [157/500], Train Loss: 0.0138, Val Loss: 0.0431
# Validation loss decreased (0.043605 --> 0.043091).  Saving model ...
# Epoch [158/500], Train Loss: 0.0137, Val Loss: 0.0425
# Validation loss decreased (0.043091 --> 0.042548).  Saving model ...
# Epoch [159/500], Train Loss: 0.0133, Val Loss: 0.0421
# Validation loss decreased (0.042548 --> 0.042082).  Saving model ...
# Epoch [160/500], Train Loss: 0.0135, Val Loss: 0.0416
# Validation loss decreased (0.042082 --> 0.041600).  Saving model ...
# Epoch [161/500], Train Loss: 0.0131, Val Loss: 0.0413
# Validation loss decreased (0.041600 --> 0.041275).  Saving model ...
# Epoch [162/500], Train Loss: 0.0132, Val Loss: 0.0407
# Validation loss decreased (0.041275 --> 0.040733).  Saving model ...
# Epoch [163/500], Train Loss: 0.0128, Val Loss: 0.0403
# Validation loss decreased (0.040733 --> 0.040262).  Saving model ...
# Epoch [164/500], Train Loss: 0.0128, Val Loss: 0.0398
# Validation loss decreased (0.040262 --> 0.039820).  Saving model ...
# Epoch [165/500], Train Loss: 0.0127, Val Loss: 0.0394
# Validation loss decreased (0.039820 --> 0.039373).  Saving model ...
# Epoch [166/500], Train Loss: 0.0126, Val Loss: 0.0389
# Validation loss decreased (0.039373 --> 0.038855).  Saving model ...
# Epoch [167/500], Train Loss: 0.0124, Val Loss: 0.0384
# Validation loss decreased (0.038855 --> 0.038364).  Saving model ...
# Epoch [168/500], Train Loss: 0.0123, Val Loss: 0.0379
# Validation loss decreased (0.038364 --> 0.037866).  Saving model ...
# Epoch [169/500], Train Loss: 0.0121, Val Loss: 0.0374
# Validation loss decreased (0.037866 --> 0.037433).  Saving model ...
# Epoch [170/500], Train Loss: 0.0120, Val Loss: 0.0370
# Validation loss decreased (0.037433 --> 0.036990).  Saving model ...
# Epoch [171/500], Train Loss: 0.0119, Val Loss: 0.0366
# Validation loss decreased (0.036990 --> 0.036551).  Saving model ...
# Epoch [172/500], Train Loss: 0.0118, Val Loss: 0.0362
# Validation loss decreased (0.036551 --> 0.036177).  Saving model ...
# Epoch [173/500], Train Loss: 0.0116, Val Loss: 0.0357
# Validation loss decreased (0.036177 --> 0.035733).  Saving model ...
# Epoch [174/500], Train Loss: 0.0119, Val Loss: 0.0353
# Validation loss decreased (0.035733 --> 0.035289).  Saving model ...
# Epoch [175/500], Train Loss: 0.0114, Val Loss: 0.0349
# Validation loss decreased (0.035289 --> 0.034900).  Saving model ...
# Epoch [176/500], Train Loss: 0.0114, Val Loss: 0.0345
# Validation loss decreased (0.034900 --> 0.034503).  Saving model ...
# Epoch [177/500], Train Loss: 0.0111, Val Loss: 0.0341
# Validation loss decreased (0.034503 --> 0.034085).  Saving model ...
# Epoch [178/500], Train Loss: 0.0110, Val Loss: 0.0336
# Validation loss decreased (0.034085 --> 0.033639).  Saving model ...
# Epoch [179/500], Train Loss: 0.0110, Val Loss: 0.0332
# Validation loss decreased (0.033639 --> 0.033165).  Saving model ...
# Epoch [180/500], Train Loss: 0.0108, Val Loss: 0.0328
# Validation loss decreased (0.033165 --> 0.032842).  Saving model ...
# Epoch [181/500], Train Loss: 0.0106, Val Loss: 0.0325
# Validation loss decreased (0.032842 --> 0.032493).  Saving model ...
# Epoch [182/500], Train Loss: 0.0106, Val Loss: 0.0321
# Validation loss decreased (0.032493 --> 0.032136).  Saving model ...
# Epoch [183/500], Train Loss: 0.0104, Val Loss: 0.0318
# Validation loss decreased (0.032136 --> 0.031757).  Saving model ...
# Epoch [184/500], Train Loss: 0.0104, Val Loss: 0.0314
# Validation loss decreased (0.031757 --> 0.031399).  Saving model ...
# Epoch [185/500], Train Loss: 0.0103, Val Loss: 0.0311
# Validation loss decreased (0.031399 --> 0.031073).  Saving model ...
# Epoch [186/500], Train Loss: 0.0102, Val Loss: 0.0307
# Validation loss decreased (0.031073 --> 0.030700).  Saving model ...
# Epoch [187/500], Train Loss: 0.0101, Val Loss: 0.0303
# Validation loss decreased (0.030700 --> 0.030306).  Saving model ...
# Epoch [188/500], Train Loss: 0.0099, Val Loss: 0.0300
# Validation loss decreased (0.030306 --> 0.029986).  Saving model ...
# Epoch [189/500], Train Loss: 0.0099, Val Loss: 0.0297
# Validation loss decreased (0.029986 --> 0.029660).  Saving model ...
# Epoch [190/500], Train Loss: 0.0096, Val Loss: 0.0293
# Validation loss decreased (0.029660 --> 0.029321).  Saving model ...
# Epoch [191/500], Train Loss: 0.0095, Val Loss: 0.0290
# Validation loss decreased (0.029321 --> 0.029013).  Saving model ...
# Epoch [192/500], Train Loss: 0.0097, Val Loss: 0.0287
# Validation loss decreased (0.029013 --> 0.028704).  Saving model ...
# Epoch [193/500], Train Loss: 0.0095, Val Loss: 0.0284
# Validation loss decreased (0.028704 --> 0.028398).  Saving model ...
# Epoch [194/500], Train Loss: 0.0094, Val Loss: 0.0280
# Validation loss decreased (0.028398 --> 0.027994).  Saving model ...
# Epoch [195/500], Train Loss: 0.0093, Val Loss: 0.0277
# Validation loss decreased (0.027994 --> 0.027701).  Saving model ...
# Epoch [196/500], Train Loss: 0.0091, Val Loss: 0.0274
# Validation loss decreased (0.027701 --> 0.027394).  Saving model ...
# Epoch [197/500], Train Loss: 0.0090, Val Loss: 0.0271
# Validation loss decreased (0.027394 --> 0.027086).  Saving model ...
# Epoch [198/500], Train Loss: 0.0090, Val Loss: 0.0268
# Validation loss decreased (0.027086 --> 0.026793).  Saving model ...
# Epoch [199/500], Train Loss: 0.0088, Val Loss: 0.0265
# Validation loss decreased (0.026793 --> 0.026485).  Saving model ...
# Epoch [200/500], Train Loss: 0.0087, Val Loss: 0.0262
# Validation loss decreased (0.026485 --> 0.026207).  Saving model ...
# Epoch [201/500], Train Loss: 0.0087, Val Loss: 0.0259
# Validation loss decreased (0.026207 --> 0.025875).  Saving model ...
# Epoch [202/500], Train Loss: 0.0084, Val Loss: 0.0256
# Validation loss decreased (0.025875 --> 0.025619).  Saving model ...
# Epoch [203/500], Train Loss: 0.0085, Val Loss: 0.0253
# Validation loss decreased (0.025619 --> 0.025308).  Saving model ...
# Epoch [204/500], Train Loss: 0.0085, Val Loss: 0.0250
# Validation loss decreased (0.025308 --> 0.025023).  Saving model ...
# Epoch [205/500], Train Loss: 0.0082, Val Loss: 0.0247
# Validation loss decreased (0.025023 --> 0.024750).  Saving model ...
# Epoch [206/500], Train Loss: 0.0085, Val Loss: 0.0245
# Validation loss decreased (0.024750 --> 0.024462).  Saving model ...
# Epoch [207/500], Train Loss: 0.0083, Val Loss: 0.0242
# Validation loss decreased (0.024462 --> 0.024150).  Saving model ...
# Epoch [208/500], Train Loss: 0.0079, Val Loss: 0.0239
# Validation loss decreased (0.024150 --> 0.023898).  Saving model ...
# Epoch [209/500], Train Loss: 0.0080, Val Loss: 0.0237
# Validation loss decreased (0.023898 --> 0.023705).  Saving model ...
# Epoch [210/500], Train Loss: 0.0078, Val Loss: 0.0234
# Validation loss decreased (0.023705 --> 0.023436).  Saving model ...
# Epoch [211/500], Train Loss: 0.0078, Val Loss: 0.0232
# Validation loss decreased (0.023436 --> 0.023151).  Saving model ...
# Epoch [212/500], Train Loss: 0.0079, Val Loss: 0.0229
# Validation loss decreased (0.023151 --> 0.022877).  Saving model ...
# Epoch [213/500], Train Loss: 0.0076, Val Loss: 0.0226
# Validation loss decreased (0.022877 --> 0.022635).  Saving model ...
# Epoch [214/500], Train Loss: 0.0075, Val Loss: 0.0224
# Validation loss decreased (0.022635 --> 0.022440).  Saving model ...
# Epoch [215/500], Train Loss: 0.0075, Val Loss: 0.0222
# Validation loss decreased (0.022440 --> 0.022188).  Saving model ...
# Epoch [216/500], Train Loss: 0.0074, Val Loss: 0.0220
# Validation loss decreased (0.022188 --> 0.021955).  Saving model ...
# Epoch [217/500], Train Loss: 0.0076, Val Loss: 0.0217
# Validation loss decreased (0.021955 --> 0.021706).  Saving model ...
# Epoch [218/500], Train Loss: 0.0073, Val Loss: 0.0215
# Validation loss decreased (0.021706 --> 0.021493).  Saving model ...
# Epoch [219/500], Train Loss: 0.0072, Val Loss: 0.0212
# Validation loss decreased (0.021493 --> 0.021246).  Saving model ...
# Epoch [220/500], Train Loss: 0.0072, Val Loss: 0.0210
# Validation loss decreased (0.021246 --> 0.020979).  Saving model ...
# Epoch [221/500], Train Loss: 0.0071, Val Loss: 0.0207
# Validation loss decreased (0.020979 --> 0.020745).  Saving model ...
# Epoch [222/500], Train Loss: 0.0069, Val Loss: 0.0205
# Validation loss decreased (0.020745 --> 0.020502).  Saving model ...
# Epoch [223/500], Train Loss: 0.0069, Val Loss: 0.0203
# Validation loss decreased (0.020502 --> 0.020281).  Saving model ...
# Epoch [224/500], Train Loss: 0.0069, Val Loss: 0.0201
# Validation loss decreased (0.020281 --> 0.020064).  Saving model ...
# Epoch [225/500], Train Loss: 0.0068, Val Loss: 0.0199
# Validation loss decreased (0.020064 --> 0.019862).  Saving model ...
# Epoch [226/500], Train Loss: 0.0068, Val Loss: 0.0196
# Validation loss decreased (0.019862 --> 0.019618).  Saving model ...
# Epoch [227/500], Train Loss: 0.0067, Val Loss: 0.0194
# Validation loss decreased (0.019618 --> 0.019380).  Saving model ...
# Epoch [228/500], Train Loss: 0.0066, Val Loss: 0.0192
# Validation loss decreased (0.019380 --> 0.019196).  Saving model ...
# Epoch [229/500], Train Loss: 0.0065, Val Loss: 0.0190
# Validation loss decreased (0.019196 --> 0.018979).  Saving model ...
# Epoch [230/500], Train Loss: 0.0064, Val Loss: 0.0188
# Validation loss decreased (0.018979 --> 0.018785).  Saving model ...
# Epoch [231/500], Train Loss: 0.0064, Val Loss: 0.0186
# Validation loss decreased (0.018785 --> 0.018587).  Saving model ...
# Epoch [232/500], Train Loss: 0.0065, Val Loss: 0.0184
# Validation loss decreased (0.018587 --> 0.018351).  Saving model ...
# Epoch [233/500], Train Loss: 0.0063, Val Loss: 0.0181
# Validation loss decreased (0.018351 --> 0.018145).  Saving model ...
# Epoch [234/500], Train Loss: 0.0062, Val Loss: 0.0180
# Validation loss decreased (0.018145 --> 0.017959).  Saving model ...
# Epoch [235/500], Train Loss: 0.0063, Val Loss: 0.0177
# Validation loss decreased (0.017959 --> 0.017733).  Saving model ...
# Epoch [236/500], Train Loss: 0.0062, Val Loss: 0.0175
# Validation loss decreased (0.017733 --> 0.017530).  Saving model ...
# Epoch [237/500], Train Loss: 0.0061, Val Loss: 0.0174
# Validation loss decreased (0.017530 --> 0.017368).  Saving model ...
# Epoch [238/500], Train Loss: 0.0060, Val Loss: 0.0172
# Validation loss decreased (0.017368 --> 0.017158).  Saving model ...
# Epoch [239/500], Train Loss: 0.0059, Val Loss: 0.0170
# Validation loss decreased (0.017158 --> 0.017000).  Saving model ...
# Epoch [240/500], Train Loss: 0.0059, Val Loss: 0.0168
# Validation loss decreased (0.017000 --> 0.016847).  Saving model ...
# Epoch [241/500], Train Loss: 0.0057, Val Loss: 0.0167
# Validation loss decreased (0.016847 --> 0.016708).  Saving model ...
# Epoch [242/500], Train Loss: 0.0057, Val Loss: 0.0165
# Validation loss decreased (0.016708 --> 0.016523).  Saving model ...
# Epoch [243/500], Train Loss: 0.0058, Val Loss: 0.0164
# Validation loss decreased (0.016523 --> 0.016361).  Saving model ...
# Epoch [244/500], Train Loss: 0.0056, Val Loss: 0.0162
# Validation loss decreased (0.016361 --> 0.016175).  Saving model ...
# Epoch [245/500], Train Loss: 0.0056, Val Loss: 0.0160
# Validation loss decreased (0.016175 --> 0.016015).  Saving model ...
# Epoch [246/500], Train Loss: 0.0057, Val Loss: 0.0158
# Validation loss decreased (0.016015 --> 0.015837).  Saving model ...
# Epoch [247/500], Train Loss: 0.0054, Val Loss: 0.0157
# Validation loss decreased (0.015837 --> 0.015718).  Saving model ...
# Epoch [248/500], Train Loss: 0.0054, Val Loss: 0.0156
# Validation loss decreased (0.015718 --> 0.015564).  Saving model ...
# Epoch [249/500], Train Loss: 0.0054, Val Loss: 0.0154
# Validation loss decreased (0.015564 --> 0.015397).  Saving model ...
# Epoch [250/500], Train Loss: 0.0053, Val Loss: 0.0153
# Validation loss decreased (0.015397 --> 0.015292).  Saving model ...
# Epoch [251/500], Train Loss: 0.0054, Val Loss: 0.0151
# Validation loss decreased (0.015292 --> 0.015117).  Saving model ...
# Epoch [252/500], Train Loss: 0.0052, Val Loss: 0.0150
# Validation loss decreased (0.015117 --> 0.014960).  Saving model ...
# Epoch [253/500], Train Loss: 0.0052, Val Loss: 0.0149
# Validation loss decreased (0.014960 --> 0.014857).  Saving model ...
# Epoch [254/500], Train Loss: 0.0053, Val Loss: 0.0147
# Validation loss decreased (0.014857 --> 0.014676).  Saving model ...
# Epoch [255/500], Train Loss: 0.0052, Val Loss: 0.0145
# Validation loss decreased (0.014676 --> 0.014483).  Saving model ...
# Epoch [256/500], Train Loss: 0.0051, Val Loss: 0.0143
# Validation loss decreased (0.014483 --> 0.014318).  Saving model ...
# Epoch [257/500], Train Loss: 0.0051, Val Loss: 0.0141
# Validation loss decreased (0.014318 --> 0.014139).  Saving model ...
# Epoch [258/500], Train Loss: 0.0050, Val Loss: 0.0140
# Validation loss decreased (0.014139 --> 0.014012).  Saving model ...
# Epoch [259/500], Train Loss: 0.0050, Val Loss: 0.0139
# Validation loss decreased (0.014012 --> 0.013883).  Saving model ...
# Epoch [260/500], Train Loss: 0.0049, Val Loss: 0.0137
# Validation loss decreased (0.013883 --> 0.013745).  Saving model ...
# Epoch [261/500], Train Loss: 0.0048, Val Loss: 0.0137
# Validation loss decreased (0.013745 --> 0.013666).  Saving model ...
# Epoch [262/500], Train Loss: 0.0048, Val Loss: 0.0135
# Validation loss decreased (0.013666 --> 0.013532).  Saving model ...
# Epoch [263/500], Train Loss: 0.0048, Val Loss: 0.0134
# Validation loss decreased (0.013532 --> 0.013401).  Saving model ...
# Epoch [264/500], Train Loss: 0.0049, Val Loss: 0.0132
# Validation loss decreased (0.013401 --> 0.013217).  Saving model ...
# Epoch [265/500], Train Loss: 0.0048, Val Loss: 0.0131
# Validation loss decreased (0.013217 --> 0.013078).  Saving model ...
# Epoch [266/500], Train Loss: 0.0047, Val Loss: 0.0130
# Validation loss decreased (0.013078 --> 0.012955).  Saving model ...
# Epoch [267/500], Train Loss: 0.0046, Val Loss: 0.0128
# Validation loss decreased (0.012955 --> 0.012847).  Saving model ...
# Epoch [268/500], Train Loss: 0.0046, Val Loss: 0.0127
# Validation loss decreased (0.012847 --> 0.012723).  Saving model ...
# Epoch [269/500], Train Loss: 0.0045, Val Loss: 0.0126
# Validation loss decreased (0.012723 --> 0.012602).  Saving model ...
# Epoch [270/500], Train Loss: 0.0045, Val Loss: 0.0125
# Validation loss decreased (0.012602 --> 0.012489).  Saving model ...
# Epoch [271/500], Train Loss: 0.0044, Val Loss: 0.0124
# Validation loss decreased (0.012489 --> 0.012402).  Saving model ...
# Epoch [272/500], Train Loss: 0.0045, Val Loss: 0.0123
# Validation loss decreased (0.012402 --> 0.012289).  Saving model ...
# Epoch [273/500], Train Loss: 0.0043, Val Loss: 0.0122
# Validation loss decreased (0.012289 --> 0.012162).  Saving model ...
# Epoch [274/500], Train Loss: 0.0044, Val Loss: 0.0120
# Validation loss decreased (0.012162 --> 0.012014).  Saving model ...
# Epoch [275/500], Train Loss: 0.0044, Val Loss: 0.0119
# Validation loss decreased (0.012014 --> 0.011918).  Saving model ...
# Epoch [276/500], Train Loss: 0.0043, Val Loss: 0.0118
# Validation loss decreased (0.011918 --> 0.011815).  Saving model ...
# Epoch [277/500], Train Loss: 0.0044, Val Loss: 0.0117
# Validation loss decreased (0.011815 --> 0.011665).  Saving model ...
# Epoch [278/500], Train Loss: 0.0043, Val Loss: 0.0116
# Validation loss decreased (0.011665 --> 0.011565).  Saving model ...
# Epoch [279/500], Train Loss: 0.0042, Val Loss: 0.0115
# Validation loss decreased (0.011565 --> 0.011457).  Saving model ...
# Epoch [280/500], Train Loss: 0.0044, Val Loss: 0.0113
# Validation loss decreased (0.011457 --> 0.011319).  Saving model ...
# Epoch [281/500], Train Loss: 0.0040, Val Loss: 0.0113
# Validation loss decreased (0.011319 --> 0.011252).  Saving model ...
# Epoch [282/500], Train Loss: 0.0041, Val Loss: 0.0111
# Validation loss decreased (0.011252 --> 0.011146).  Saving model ...
# Epoch [283/500], Train Loss: 0.0040, Val Loss: 0.0111
# Validation loss decreased (0.011146 --> 0.011057).  Saving model ...
# Epoch [284/500], Train Loss: 0.0041, Val Loss: 0.0110
# Validation loss decreased (0.011057 --> 0.010984).  Saving model ...
# Epoch [285/500], Train Loss: 0.0040, Val Loss: 0.0109
# Validation loss decreased (0.010984 --> 0.010881).  Saving model ...
# Epoch [286/500], Train Loss: 0.0040, Val Loss: 0.0108
# Validation loss decreased (0.010881 --> 0.010779).  Saving model ...
# Epoch [287/500], Train Loss: 0.0039, Val Loss: 0.0107
# Validation loss decreased (0.010779 --> 0.010673).  Saving model ...
# Epoch [288/500], Train Loss: 0.0039, Val Loss: 0.0106
# Validation loss decreased (0.010673 --> 0.010590).  Saving model ...
# Epoch [289/500], Train Loss: 0.0039, Val Loss: 0.0105
# Validation loss decreased (0.010590 --> 0.010466).  Saving model ...
# Epoch [290/500], Train Loss: 0.0039, Val Loss: 0.0104
# Validation loss decreased (0.010466 --> 0.010371).  Saving model ...
# Epoch [291/500], Train Loss: 0.0037, Val Loss: 0.0103
# Validation loss decreased (0.010371 --> 0.010308).  Saving model ...
# Epoch [292/500], Train Loss: 0.0038, Val Loss: 0.0102
# Validation loss decreased (0.010308 --> 0.010219).  Saving model ...
# Epoch [293/500], Train Loss: 0.0038, Val Loss: 0.0101
# Validation loss decreased (0.010219 --> 0.010111).  Saving model ...
# Epoch [294/500], Train Loss: 0.0038, Val Loss: 0.0100
# Validation loss decreased (0.010111 --> 0.010032).  Saving model ...
# Epoch [295/500], Train Loss: 0.0037, Val Loss: 0.0099
# Validation loss decreased (0.010032 --> 0.009937).  Saving model ...
# Epoch [296/500], Train Loss: 0.0038, Val Loss: 0.0099
# Validation loss decreased (0.009937 --> 0.009856).  Saving model ...
# Epoch [297/500], Train Loss: 0.0036, Val Loss: 0.0098
# Validation loss decreased (0.009856 --> 0.009794).  Saving model ...
# Epoch [298/500], Train Loss: 0.0037, Val Loss: 0.0097
# Validation loss decreased (0.009794 --> 0.009694).  Saving model ...
# Epoch [299/500], Train Loss: 0.0036, Val Loss: 0.0096
# Validation loss decreased (0.009694 --> 0.009635).  Saving model ...
# Epoch [300/500], Train Loss: 0.0037, Val Loss: 0.0095
# Validation loss decreased (0.009635 --> 0.009533).  Saving model ...
# Epoch [301/500], Train Loss: 0.0036, Val Loss: 0.0095
# Validation loss decreased (0.009533 --> 0.009454).  Saving model ...
# Epoch [302/500], Train Loss: 0.0036, Val Loss: 0.0094
# Validation loss decreased (0.009454 --> 0.009373).  Saving model ...
# Epoch [303/500], Train Loss: 0.0036, Val Loss: 0.0093
# Validation loss decreased (0.009373 --> 0.009302).  Saving model ...
# Epoch [304/500], Train Loss: 0.0034, Val Loss: 0.0092
# Validation loss decreased (0.009302 --> 0.009230).  Saving model ...
# Epoch [305/500], Train Loss: 0.0035, Val Loss: 0.0092
# Validation loss decreased (0.009230 --> 0.009155).  Saving model ...
# Epoch [306/500], Train Loss: 0.0033, Val Loss: 0.0091
# Validation loss decreased (0.009155 --> 0.009102).  Saving model ...
# Epoch [307/500], Train Loss: 0.0035, Val Loss: 0.0090
# Validation loss decreased (0.009102 --> 0.009004).  Saving model ...
# Epoch [308/500], Train Loss: 0.0035, Val Loss: 0.0089
# Validation loss decreased (0.009004 --> 0.008918).  Saving model ...
# Epoch [309/500], Train Loss: 0.0035, Val Loss: 0.0089
# Validation loss decreased (0.008918 --> 0.008858).  Saving model ...
# Epoch [310/500], Train Loss: 0.0033, Val Loss: 0.0088
# Validation loss decreased (0.008858 --> 0.008777).  Saving model ...
# Epoch [311/500], Train Loss: 0.0033, Val Loss: 0.0087
# Validation loss decreased (0.008777 --> 0.008722).  Saving model ...
# Epoch [312/500], Train Loss: 0.0033, Val Loss: 0.0086
# Validation loss decreased (0.008722 --> 0.008636).  Saving model ...
# Epoch [313/500], Train Loss: 0.0033, Val Loss: 0.0086
# Validation loss decreased (0.008636 --> 0.008568).  Saving model ...
# Epoch [314/500], Train Loss: 0.0033, Val Loss: 0.0085
# Validation loss decreased (0.008568 --> 0.008509).  Saving model ...
# Epoch [315/500], Train Loss: 0.0032, Val Loss: 0.0085
# Validation loss decreased (0.008509 --> 0.008456).  Saving model ...
# Epoch [316/500], Train Loss: 0.0032, Val Loss: 0.0084
# Validation loss decreased (0.008456 --> 0.008390).  Saving model ...
# Epoch [317/500], Train Loss: 0.0032, Val Loss: 0.0083
# Validation loss decreased (0.008390 --> 0.008318).  Saving model ...
# Epoch [318/500], Train Loss: 0.0033, Val Loss: 0.0083
# Validation loss decreased (0.008318 --> 0.008265).  Saving model ...
# Epoch [319/500], Train Loss: 0.0032, Val Loss: 0.0082
# Validation loss decreased (0.008265 --> 0.008182).  Saving model ...
# Epoch [320/500], Train Loss: 0.0032, Val Loss: 0.0081
# Validation loss decreased (0.008182 --> 0.008111).  Saving model ...
# Epoch [321/500], Train Loss: 0.0031, Val Loss: 0.0081
# Validation loss decreased (0.008111 --> 0.008071).  Saving model ...
# Epoch [322/500], Train Loss: 0.0031, Val Loss: 0.0080
# Validation loss decreased (0.008071 --> 0.008003).  Saving model ...
# Epoch [323/500], Train Loss: 0.0032, Val Loss: 0.0079
# Validation loss decreased (0.008003 --> 0.007924).  Saving model ...
# Epoch [324/500], Train Loss: 0.0031, Val Loss: 0.0079
# Validation loss decreased (0.007924 --> 0.007869).  Saving model ...
# Epoch [325/500], Train Loss: 0.0030, Val Loss: 0.0078
# Validation loss decreased (0.007869 --> 0.007816).  Saving model ...
# Epoch [326/500], Train Loss: 0.0029, Val Loss: 0.0078
# Validation loss decreased (0.007816 --> 0.007778).  Saving model ...
# Epoch [327/500], Train Loss: 0.0030, Val Loss: 0.0077
# Validation loss decreased (0.007778 --> 0.007729).  Saving model ...
# Epoch [328/500], Train Loss: 0.0030, Val Loss: 0.0077
# Validation loss decreased (0.007729 --> 0.007670).  Saving model ...
# Epoch [329/500], Train Loss: 0.0030, Val Loss: 0.0076
# Validation loss decreased (0.007670 --> 0.007609).  Saving model ...
# Epoch [330/500], Train Loss: 0.0029, Val Loss: 0.0076
# Validation loss decreased (0.007609 --> 0.007565).  Saving model ...
# Epoch [331/500], Train Loss: 0.0030, Val Loss: 0.0075
# Validation loss decreased (0.007565 --> 0.007509).  Saving model ...
# Epoch [332/500], Train Loss: 0.0029, Val Loss: 0.0075
# Validation loss decreased (0.007509 --> 0.007457).  Saving model ...
# Epoch [333/500], Train Loss: 0.0029, Val Loss: 0.0074
# Validation loss decreased (0.007457 --> 0.007409).  Saving model ...
# Epoch [334/500], Train Loss: 0.0030, Val Loss: 0.0074
# Validation loss decreased (0.007409 --> 0.007350).  Saving model ...
# Epoch [335/500], Train Loss: 0.0029, Val Loss: 0.0073
# Validation loss decreased (0.007350 --> 0.007292).  Saving model ...
# Epoch [336/500], Train Loss: 0.0029, Val Loss: 0.0072
# Validation loss decreased (0.007292 --> 0.007235).  Saving model ...
# Epoch [337/500], Train Loss: 0.0028, Val Loss: 0.0072
# Validation loss decreased (0.007235 --> 0.007189).  Saving model ...
# Epoch [338/500], Train Loss: 0.0029, Val Loss: 0.0071
# Validation loss decreased (0.007189 --> 0.007130).  Saving model ...
# Epoch [339/500], Train Loss: 0.0028, Val Loss: 0.0071
# Validation loss decreased (0.007130 --> 0.007085).  Saving model ...
# Epoch [340/500], Train Loss: 0.0028, Val Loss: 0.0070
# Validation loss decreased (0.007085 --> 0.007042).  Saving model ...
# Epoch [341/500], Train Loss: 0.0029, Val Loss: 0.0070
# Validation loss decreased (0.007042 --> 0.006986).  Saving model ...
# Epoch [342/500], Train Loss: 0.0029, Val Loss: 0.0069
# Validation loss decreased (0.006986 --> 0.006915).  Saving model ...
# Epoch [343/500], Train Loss: 0.0028, Val Loss: 0.0069
# Validation loss decreased (0.006915 --> 0.006874).  Saving model ...
# Epoch [344/500], Train Loss: 0.0028, Val Loss: 0.0068
# Validation loss decreased (0.006874 --> 0.006836).  Saving model ...
# Epoch [345/500], Train Loss: 0.0026, Val Loss: 0.0068
# Validation loss decreased (0.006836 --> 0.006778).  Saving model ...
# Epoch [346/500], Train Loss: 0.0028, Val Loss: 0.0067
# Validation loss decreased (0.006778 --> 0.006738).  Saving model ...
# Epoch [347/500], Train Loss: 0.0026, Val Loss: 0.0067
# Validation loss decreased (0.006738 --> 0.006700).  Saving model ...
# Epoch [348/500], Train Loss: 0.0027, Val Loss: 0.0067
# Validation loss decreased (0.006700 --> 0.006665).  Saving model ...
# Epoch [349/500], Train Loss: 0.0027, Val Loss: 0.0066
# Validation loss decreased (0.006665 --> 0.006614).  Saving model ...
# Epoch [350/500], Train Loss: 0.0027, Val Loss: 0.0066
# Validation loss decreased (0.006614 --> 0.006557).  Saving model ...
# Epoch [351/500], Train Loss: 0.0026, Val Loss: 0.0065
# Validation loss decreased (0.006557 --> 0.006523).  Saving model ...
# Epoch [352/500], Train Loss: 0.0026, Val Loss: 0.0065
# Validation loss decreased (0.006523 --> 0.006485).  Saving model ...
# Epoch [353/500], Train Loss: 0.0026, Val Loss: 0.0065
# Validation loss decreased (0.006485 --> 0.006454).  Saving model ...
# Epoch [354/500], Train Loss: 0.0026, Val Loss: 0.0064
# Validation loss decreased (0.006454 --> 0.006402).  Saving model ...
# Epoch [355/500], Train Loss: 0.0026, Val Loss: 0.0064
# Validation loss decreased (0.006402 --> 0.006353).  Saving model ...
# Epoch [356/500], Train Loss: 0.0026, Val Loss: 0.0063
# Validation loss decreased (0.006353 --> 0.006331).  Saving model ...
# Epoch [357/500], Train Loss: 0.0026, Val Loss: 0.0063
# Validation loss decreased (0.006331 --> 0.006285).  Saving model ...
# Epoch [358/500], Train Loss: 0.0025, Val Loss: 0.0062
# Validation loss decreased (0.006285 --> 0.006247).  Saving model ...
# Epoch [359/500], Train Loss: 0.0026, Val Loss: 0.0062
# Validation loss decreased (0.006247 --> 0.006214).  Saving model ...
# Epoch [360/500], Train Loss: 0.0025, Val Loss: 0.0062
# Validation loss decreased (0.006214 --> 0.006179).  Saving model ...
# Epoch [361/500], Train Loss: 0.0026, Val Loss: 0.0061
# Validation loss decreased (0.006179 --> 0.006142).  Saving model ...
# Epoch [362/500], Train Loss: 0.0024, Val Loss: 0.0061
# Validation loss decreased (0.006142 --> 0.006117).  Saving model ...
# Epoch [363/500], Train Loss: 0.0025, Val Loss: 0.0061
# Validation loss decreased (0.006117 --> 0.006073).  Saving model ...
# Epoch [364/500], Train Loss: 0.0025, Val Loss: 0.0060
# Validation loss decreased (0.006073 --> 0.006029).  Saving model ...
# Epoch [365/500], Train Loss: 0.0024, Val Loss: 0.0060
# Validation loss decreased (0.006029 --> 0.005981).  Saving model ...
# Epoch [366/500], Train Loss: 0.0025, Val Loss: 0.0059
# Validation loss decreased (0.005981 --> 0.005946).  Saving model ...
# Epoch [367/500], Train Loss: 0.0024, Val Loss: 0.0059
# Validation loss decreased (0.005946 --> 0.005903).  Saving model ...
# Epoch [368/500], Train Loss: 0.0024, Val Loss: 0.0059
# Validation loss decreased (0.005903 --> 0.005870).  Saving model ...
# Epoch [369/500], Train Loss: 0.0024, Val Loss: 0.0058
# Validation loss decreased (0.005870 --> 0.005836).  Saving model ...
# Epoch [370/500], Train Loss: 0.0023, Val Loss: 0.0058
# Validation loss decreased (0.005836 --> 0.005798).  Saving model ...
# Epoch [371/500], Train Loss: 0.0024, Val Loss: 0.0058
# Validation loss decreased (0.005798 --> 0.005771).  Saving model ...
# Epoch [372/500], Train Loss: 0.0024, Val Loss: 0.0058
# Validation loss decreased (0.005771 --> 0.005751).  Saving model ...
# Epoch [373/500], Train Loss: 0.0024, Val Loss: 0.0057
# Validation loss decreased (0.005751 --> 0.005730).  Saving model ...
# Epoch [374/500], Train Loss: 0.0023, Val Loss: 0.0057
# Validation loss decreased (0.005730 --> 0.005704).  Saving model ...
# Epoch [375/500], Train Loss: 0.0024, Val Loss: 0.0057
# Validation loss decreased (0.005704 --> 0.005669).  Saving model ...
# Epoch [376/500], Train Loss: 0.0023, Val Loss: 0.0056
# Validation loss decreased (0.005669 --> 0.005638).  Saving model ...
# Epoch [377/500], Train Loss: 0.0024, Val Loss: 0.0056
# Validation loss decreased (0.005638 --> 0.005598).  Saving model ...
# Epoch [378/500], Train Loss: 0.0024, Val Loss: 0.0056
# Validation loss decreased (0.005598 --> 0.005561).  Saving model ...
# Epoch [379/500], Train Loss: 0.0023, Val Loss: 0.0055
# Validation loss decreased (0.005561 --> 0.005531).  Saving model ...
# Epoch [380/500], Train Loss: 0.0023, Val Loss: 0.0055
# Validation loss decreased (0.005531 --> 0.005497).  Saving model ...
# Epoch [381/500], Train Loss: 0.0023, Val Loss: 0.0055
# Validation loss decreased (0.005497 --> 0.005480).  Saving model ...
# Epoch [382/500], Train Loss: 0.0024, Val Loss: 0.0054
# Validation loss decreased (0.005480 --> 0.005437).  Saving model ...
# Epoch [383/500], Train Loss: 0.0022, Val Loss: 0.0054
# Validation loss decreased (0.005437 --> 0.005418).  Saving model ...
# Epoch [384/500], Train Loss: 0.0023, Val Loss: 0.0054
# Validation loss decreased (0.005418 --> 0.005384).  Saving model ...
# Epoch [385/500], Train Loss: 0.0023, Val Loss: 0.0054
# Validation loss decreased (0.005384 --> 0.005370).  Saving model ...
# Epoch [386/500], Train Loss: 0.0022, Val Loss: 0.0054
# Validation loss decreased (0.005370 --> 0.005359).  Saving model ...
# Epoch [387/500], Train Loss: 0.0022, Val Loss: 0.0053
# Validation loss decreased (0.005359 --> 0.005339).  Saving model ...
# Epoch [388/500], Train Loss: 0.0022, Val Loss: 0.0053
# Validation loss decreased (0.005339 --> 0.005306).  Saving model ...
# Epoch [389/500], Train Loss: 0.0023, Val Loss: 0.0053
# Validation loss decreased (0.005306 --> 0.005257).  Saving model ...
# Epoch [390/500], Train Loss: 0.0022, Val Loss: 0.0052
# Validation loss decreased (0.005257 --> 0.005233).  Saving model ...
# Epoch [391/500], Train Loss: 0.0022, Val Loss: 0.0052
# Validation loss decreased (0.005233 --> 0.005200).  Saving model ...
# ...
# Epoch [371/500], Train Loss: 0.0038, Val Loss: 0.0102
# Validation loss decreased (0.010286 --> 0.010218).  Saving model ...
# Epoch [372/500], Train Loss: 0.0039, Val Loss: 0.0101
# Validation loss decreased (0.010218 --> 0.010132).  Saving model ...
# Epoch [373/500], Train Loss: 0.0039, Val Loss: 0.0101
# Validation loss decreased (0.010132 --> 0.010063).  Saving model ...
# Epoch [374/500], Train Loss: 0.0039, Val Loss: 0.0100
# Validation loss decreased (0.010063 --> 0.009984).  Saving model ...
# Epoch [375/500], Train Loss: 0.0038, Val Loss: 0.0099
# Validation loss decreased (0.009984 --> 0.009928).  Saving model ...
# Epoch [376/500], Train Loss: 0.0038, Val Loss: 0.0098
# Validation loss decreased (0.009928 --> 0.009849).  Saving model ...
# Epoch [377/500], Train Loss: 0.0037, Val Loss: 0.0098
# Validation loss decreased (0.009849 --> 0.009788).  Saving model ...
# Epoch [378/500], Train Loss: 0.0037, Val Loss: 0.0097
# Validation loss decreased (0.009788 --> 0.009715).  Saving model ...
# Epoch [379/500], Train Loss: 0.0037, Val Loss: 0.0096
# Validation loss decreased (0.009715 --> 0.009632).  Saving model ...
# Epoch [380/500], Train Loss: 0.0037, Val Loss: 0.0096
# Validation loss decreased (0.009632 --> 0.009577).  Saving model ...
# Epoch [381/500], Train Loss: 0.0036, Val Loss: 0.0095
# Validation loss decreased (0.009577 --> 0.009511).  Saving model ...
# Epoch [382/500], Train Loss: 0.0037, Val Loss: 0.0094
# Validation loss decreased (0.009511 --> 0.009450).  Saving model ...
# Epoch [383/500], Train Loss: 0.0036, Val Loss: 0.0094
# Validation loss decreased (0.009450 --> 0.009406).  Saving model ...
# Epoch [384/500], Train Loss: 0.0036, Val Loss: 0.0093
# Validation loss decreased (0.009406 --> 0.009350).  Saving model ...
# Epoch [385/500], Train Loss: 0.0036, Val Loss: 0.0093
# Validation loss decreased (0.009350 --> 0.009286).  Saving model ...
# Epoch [386/500], Train Loss: 0.0037, Val Loss: 0.0092
# Validation loss decreased (0.009286 --> 0.009209).  Saving model ...
# Epoch [387/500], Train Loss: 0.0036, Val Loss: 0.0091
# Validation loss decreased (0.009209 --> 0.009143).  Saving model ...
# Epoch [388/500], Train Loss: 0.0036, Val Loss: 0.0091
# Validation loss decreased (0.009143 --> 0.009089).  Saving model ...
# Epoch [389/500], Train Loss: 0.0034, Val Loss: 0.0090
# Validation loss decreased (0.009089 --> 0.009028).  Saving model ...
# Epoch [390/500], Train Loss: 0.0034, Val Loss: 0.0090
# Validation loss decreased (0.009028 --> 0.008985).  Saving model ...
# Epoch [391/500], Train Loss: 0.0035, Val Loss: 0.0089
# Validation loss decreased (0.008985 --> 0.008916).  Saving model ...
# Epoch [392/500], Train Loss: 0.0034, Val Loss: 0.0089
# Validation loss decreased (0.008916 --> 0.008858).  Saving model ...
# Epoch [393/500], Train Loss: 0.0035, Val Loss: 0.0088
# Validation loss decreased (0.008858 --> 0.008798).  Saving model ...
# Epoch [394/500], Train Loss: 0.0034, Val Loss: 0.0087
# Validation loss decreased (0.008798 --> 0.008740).  Saving model ...
# Epoch [395/500], Train Loss: 0.0033, Val Loss: 0.0087
# Validation loss decreased (0.008740 --> 0.008686).  Saving model ...
# Epoch [396/500], Train Loss: 0.0032, Val Loss: 0.0086
# Validation loss decreased (0.008686 --> 0.008646).  Saving model ...
# Epoch [397/500], Train Loss: 0.0032, Val Loss: 0.0086
# Validation loss decreased (0.008646 --> 0.008600).  Saving model ...
# Epoch [398/500], Train Loss: 0.0032, Val Loss: 0.0085
# Validation loss decreased (0.008600 --> 0.008543).  Saving model ...
# Epoch [399/500], Train Loss: 0.0034, Val Loss: 0.0085
# Validation loss decreased (0.008543 --> 0.008484).  Saving model ...
# Epoch [400/500], Train Loss: 0.0032, Val Loss: 0.0084
# Validation loss decreased (0.008484 --> 0.008442).  Saving model ...
# Epoch [401/500], Train Loss: 0.0032, Val Loss: 0.0084
# Validation loss decreased (0.008442 --> 0.008388).  Saving model ...
# Epoch [402/500], Train Loss: 0.0032, Val Loss: 0.0083
# Validation loss decreased (0.008388 --> 0.008341).  Saving model ...
# Epoch [403/500], Train Loss: 0.0032, Val Loss: 0.0083
# Validation loss decreased (0.008341 --> 0.008291).  Saving model ...
# Epoch [404/500], Train Loss: 0.0031, Val Loss: 0.0083
# Validation loss decreased (0.008291 --> 0.008253).  Saving model ...
# Epoch [405/500], Train Loss: 0.0031, Val Loss: 0.0082
# Validation loss decreased (0.008253 --> 0.008205).  Saving model ...
# Epoch [406/500], Train Loss: 0.0031, Val Loss: 0.0082
# Validation loss decreased (0.008205 --> 0.008156).  Saving model ...
# Epoch [407/500], Train Loss: 0.0032, Val Loss: 0.0081
# Validation loss decreased (0.008156 --> 0.008113).  Saving model ...
# Epoch [408/500], Train Loss: 0.0031, Val Loss: 0.0081
# Validation loss decreased (0.008113 --> 0.008066).  Saving model ...
# Epoch [409/500], Train Loss: 0.0031, Val Loss: 0.0080
# Validation loss decreased (0.008066 --> 0.008022).  Saving model ...
# Epoch [410/500], Train Loss: 0.0030, Val Loss: 0.0080
# Validation loss decreased (0.008022 --> 0.007977).  Saving model ...
# Epoch [411/500], Train Loss: 0.0029, Val Loss: 0.0079
# Validation loss decreased (0.007977 --> 0.007933).  Saving model ...
# Epoch [412/500], Train Loss: 0.0030, Val Loss: 0.0079
# Validation loss decreased (0.007933 --> 0.007886).  Saving model ...
# Epoch [413/500], Train Loss: 0.0029, Val Loss: 0.0078
# Validation loss decreased (0.007886 --> 0.007833).  Saving model ...
# Epoch [414/500], Train Loss: 0.0030, Val Loss: 0.0078
# Validation loss decreased (0.007833 --> 0.007788).  Saving model ...
# Epoch [415/500], Train Loss: 0.0029, Val Loss: 0.0077
# Validation loss decreased (0.007788 --> 0.007741).  Saving model ...
# Epoch [416/500], Train Loss: 0.0029, Val Loss: 0.0077
# Validation loss decreased (0.007741 --> 0.007700).  Saving model ...
# Epoch [417/500], Train Loss: 0.0030, Val Loss: 0.0077
# Validation loss decreased (0.007700 --> 0.007654).  Saving model ...
# Epoch [418/500], Train Loss: 0.0030, Val Loss: 0.0076
# Validation loss decreased (0.007654 --> 0.007622).  Saving model ...
# Epoch [419/500], Train Loss: 0.0030, Val Loss: 0.0076
# Validation loss decreased (0.007622 --> 0.007577).  Saving model ...
# Epoch [420/500], Train Loss: 0.0029, Val Loss: 0.0075
# Validation loss decreased (0.007577 --> 0.007536).  Saving model ...
# Epoch [421/500], Train Loss: 0.0030, Val Loss: 0.0075
# Validation loss decreased (0.007536 --> 0.007501).  Saving model ...
# Epoch [422/500], Train Loss: 0.0029, Val Loss: 0.0075
# Validation loss decreased (0.007501 --> 0.007460).  Saving model ...
# Epoch [423/500], Train Loss: 0.0029, Val Loss: 0.0074
# Validation loss decreased (0.007460 --> 0.007417).  Saving model ...
# Epoch [424/500], Train Loss: 0.0028, Val Loss: 0.0074
# Validation loss decreased (0.007417 --> 0.007385).  Saving model ...
# Epoch [425/500], Train Loss: 0.0029, Val Loss: 0.0074
# Validation loss decreased (0.007385 --> 0.007352).  Saving model ...
# Epoch [426/500], Train Loss: 0.0028, Val Loss: 0.0073
# Validation loss decreased (0.007352 --> 0.007314).  Saving model ...
# Epoch [427/500], Train Loss: 0.0028, Val Loss: 0.0073
# Validation loss decreased (0.007314 --> 0.007273).  Saving model ...
# Epoch [428/500], Train Loss: 0.0028, Val Loss: 0.0072
# Validation loss decreased (0.007273 --> 0.007242).  Saving model ...
# Epoch [429/500], Train Loss: 0.0027, Val Loss: 0.0072
# Validation loss decreased (0.007242 --> 0.007211).  Saving model ...
# Epoch [430/500], Train Loss: 0.0028, Val Loss: 0.0072
# Validation loss decreased (0.007211 --> 0.007174).  Saving model ...
# Epoch [431/500], Train Loss: 0.0028, Val Loss: 0.0071
# Validation loss decreased (0.007174 --> 0.007139).  Saving model ...
# Epoch [432/500], Train Loss: 0.0027, Val Loss: 0.0071
# Validation loss decreased (0.007139 --> 0.007108).  Saving model ...
# Epoch [433/500], Train Loss: 0.0027, Val Loss: 0.0071
# Validation loss decreased (0.007108 --> 0.007076).  Saving model ...
# Epoch [434/500], Train Loss: 0.0028, Val Loss: 0.0070
# Validation loss decreased (0.007076 --> 0.007042).  Saving model ...
# Epoch [435/500], Train Loss: 0.0026, Val Loss: 0.0070
# Validation loss decreased (0.007042 --> 0.007006).  Saving model ...
# Epoch [436/500], Train Loss: 0.0027, Val Loss: 0.0070
# Validation loss decreased (0.007006 --> 0.006970).  Saving model ...
# Epoch [437/500], Train Loss: 0.0026, Val Loss: 0.0069
# Validation loss decreased (0.006970 --> 0.006940).  Saving model ...
# Epoch [438/500], Train Loss: 0.0026, Val Loss: 0.0069
# Validation loss decreased (0.006940 --> 0.006907).  Saving model ...
# Epoch [439/500], Train Loss: 0.0027, Val Loss: 0.0069
# Validation loss decreased (0.006907 --> 0.006879).  Saving model ...
# Epoch [440/500], Train Loss: 0.0026, Val Loss: 0.0068
# Validation loss decreased (0.006879 --> 0.006847).  Saving model ...
# Epoch [441/500], Train Loss: 0.0026, Val Loss: 0.0068
# Validation loss decreased (0.006847 --> 0.006815).  Saving model ...
# Epoch [442/500], Train Loss: 0.0026, Val Loss: 0.0068
# Validation loss decreased (0.006815 --> 0.006791).  Saving model ...
# Epoch [443/500], Train Loss: 0.0027, Val Loss: 0.0068
# Validation loss decreased (0.006791 --> 0.006758).  Saving model ...
# Epoch [444/500], Train Loss: 0.0025, Val Loss: 0.0067
# Validation loss decreased (0.006758 --> 0.006729).  Saving model ...
# Epoch [445/500], Train Loss: 0.0025, Val Loss: 0.0067
# Validation loss decreased (0.006729 --> 0.006703).  Saving model ...
# Epoch [446/500], Train Loss: 0.0025, Val Loss: 0.0067
# Validation loss decreased (0.006703 --> 0.006679).  Saving model ...
# Epoch [447/500], Train Loss: 0.0025, Val Loss: 0.0067
# Validation loss decreased (0.006679 --> 0.006655).  Saving model ...
# Epoch [448/500], Train Loss: 0.0025, Val Loss: 0.0066
# Validation loss decreased (0.006655 --> 0.006624).  Saving model ...
# Epoch [449/500], Train Loss: 0.0025, Val Loss: 0.0066
# Validation loss decreased (0.006624 --> 0.006598).  Saving model ...
# Epoch [450/500], Train Loss: 0.0025, Val Loss: 0.0066
# Validation loss decreased (0.006598 --> 0.006561).  Saving model ...
# Epoch [451/500], Train Loss: 0.0025, Val Loss: 0.0065
# Validation loss decreased (0.006561 --> 0.006533).  Saving model ...
# Epoch [452/500], Train Loss: 0.0024, Val Loss: 0.0065
# Validation loss decreased (0.006533 --> 0.006508).  Saving model ...
# Epoch [453/500], Train Loss: 0.0024, Val Loss: 0.0065
# Validation loss decreased (0.006508 --> 0.006488).  Saving model ...
# Epoch [454/500], Train Loss: 0.0025, Val Loss: 0.0065
# Validation loss decreased (0.006488 --> 0.006467).  Saving model ...
# Epoch [455/500], Train Loss: 0.0024, Val Loss: 0.0064
# Validation loss decreased (0.006467 --> 0.006440).  Saving model ...
# Epoch [456/500], Train Loss: 0.0024, Val Loss: 0.0064
# Validation loss decreased (0.006440 --> 0.006406).  Saving model ...
# Epoch [457/500], Train Loss: 0.0024, Val Loss: 0.0064
# Validation loss decreased (0.006406 --> 0.006385).  Saving model ...
# Epoch [458/500], Train Loss: 0.0024, Val Loss: 0.0064
# Validation loss decreased (0.006385 --> 0.006359).  Saving model ...
# Epoch [459/500], Train Loss: 0.0025, Val Loss: 0.0063
# Validation loss decreased (0.006359 --> 0.006330).  Saving model ...
# Epoch [460/500], Train Loss: 0.0025, Val Loss: 0.0063
# Validation loss decreased (0.006330 --> 0.006299).  Saving model ...
# Epoch [461/500], Train Loss: 0.0024, Val Loss: 0.0063
# Validation loss decreased (0.006299 --> 0.006274).  Saving model ...
# Epoch [462/500], Train Loss: 0.0024, Val Loss: 0.0062
# Validation loss decreased (0.006274 --> 0.006244).  Saving model ...
# Epoch [463/500], Train Loss: 0.0024, Val Loss: 0.0062
# Validation loss decreased (0.006244 --> 0.006222).  Saving model ...
# Epoch [464/500], Train Loss: 0.0024, Val Loss: 0.0062
# Validation loss decreased (0.006222 --> 0.006198).  Saving model ...
# Epoch [465/500], Train Loss: 0.0023, Val Loss: 0.0062
# Validation loss decreased (0.006198 --> 0.006175).  Saving model ...
# Epoch [466/500], Train Loss: 0.0022, Val Loss: 0.0062
# Validation loss decreased (0.006175 --> 0.006157).  Saving model ...
# Epoch [467/500], Train Loss: 0.0024, Val Loss: 0.0061
# Validation loss decreased (0.006157 --> 0.006137).  Saving model ...
# Epoch [468/500], Train Loss: 0.0025, Val Loss: 0.0061
# Validation loss decreased (0.006137 --> 0.006113).  Saving model ...
# Epoch [469/500], Train Loss: 0.0024, Val Loss: 0.0061
# Validation loss decreased (0.006113 --> 0.006092).  Saving model ...
# Epoch [470/500], Train Loss: 0.0023, Val Loss: 0.0061
# Validation loss decreased (0.006092 --> 0.006078).  Saving model ...
# Epoch [471/500], Train Loss: 0.0024, Val Loss: 0.0061
# Validation loss decreased (0.006078 --> 0.006055).  Saving model ...
# Epoch [472/500], Train Loss: 0.0024, Val Loss: 0.0060
# Validation loss decreased (0.006055 --> 0.006040).  Saving model ...
# Epoch [473/500], Train Loss: 0.0023, Val Loss: 0.0060
# Validation loss decreased (0.006040 --> 0.006021).  Saving model ...
# Epoch [474/500], Train Loss: 0.0024, Val Loss: 0.0060
# Validation loss decreased (0.006021 --> 0.006002).  Saving model ...
# Epoch [475/500], Train Loss: 0.0022, Val Loss: 0.0060
# Validation loss decreased (0.006002 --> 0.005981).  Saving model ...
# Epoch [476/500], Train Loss: 0.0023, Val Loss: 0.0060
# Validation loss decreased (0.005981 --> 0.005960).  Saving model ...
# Epoch [477/500], Train Loss: 0.0023, Val Loss: 0.0059
# Validation loss decreased (0.005960 --> 0.005946).  Saving model ...
# Epoch [478/500], Train Loss: 0.0022, Val Loss: 0.0059
# Validation loss decreased (0.005946 --> 0.005928).  Saving model ...
# Epoch [479/500], Train Loss: 0.0022, Val Loss: 0.0059
# Validation loss decreased (0.005928 --> 0.005911).  Saving model ...
# Epoch [480/500], Train Loss: 0.0022, Val Loss: 0.0059
# Validation loss decreased (0.005911 --> 0.005896).  Saving model ...
# Epoch [481/500], Train Loss: 0.0023, Val Loss: 0.0059
# Validation loss decreased (0.005896 --> 0.005874).  Saving model ...
# Epoch [482/500], Train Loss: 0.0022, Val Loss: 0.0059
# Validation loss decreased (0.005874 --> 0.005856).  Saving model ...
# Epoch [483/500], Train Loss: 0.0022, Val Loss: 0.0058
# Validation loss decreased (0.005856 --> 0.005835).  Saving model ...
# Epoch [484/500], Train Loss: 0.0022, Val Loss: 0.0058
# Validation loss decreased (0.005835 --> 0.005815).  Saving model ...
# Epoch [485/500], Train Loss: 0.0021, Val Loss: 0.0058
# Validation loss decreased (0.005815 --> 0.005797).  Saving model ...
# Epoch [486/500], Train Loss: 0.0022, Val Loss: 0.0058
# Validation loss decreased (0.005797 --> 0.005781).  Saving model ...
# Epoch [487/500], Train Loss: 0.0020, Val Loss: 0.0058
# Validation loss decreased (0.005781 --> 0.005771).  Saving model ...
# Epoch [488/500], Train Loss: 0.0021, Val Loss: 0.0058
# Validation loss decreased (0.005771 --> 0.005758).  Saving model ...
# Epoch [489/500], Train Loss: 0.0022, Val Loss: 0.0057
# Validation loss decreased (0.005758 --> 0.005743).  Saving model ...
# Epoch [490/500], Train Loss: 0.0021, Val Loss: 0.0057
# Validation loss decreased (0.005743 --> 0.005730).  Saving model ...
# Epoch [491/500], Train Loss: 0.0021, Val Loss: 0.0057
# Validation loss decreased (0.005730 --> 0.005716).  Saving model ...
# Epoch [492/500], Train Loss: 0.0021, Val Loss: 0.0057
# Validation loss decreased (0.005716 --> 0.005701).  Saving model ...
# Epoch [493/500], Train Loss: 0.0021, Val Loss: 0.0057
# Validation loss decreased (0.005701 --> 0.005688).  Saving model ...
# Epoch [494/500], Train Loss: 0.0021, Val Loss: 0.0057
# Validation loss decreased (0.005688 --> 0.005669).  Saving model ...
# Epoch [495/500], Train Loss: 0.0021, Val Loss: 0.0057
# Validation loss decreased (0.005669 --> 0.005659).  Saving model ...
# Epoch [496/500], Train Loss: 0.0021, Val Loss: 0.0056
# Validation loss decreased (0.005659 --> 0.005645).  Saving model ...
# Epoch [497/500], Train Loss: 0.0021, Val Loss: 0.0056
# Validation loss decreased (0.005645 --> 0.005633).  Saving model ...
# Epoch [498/500], Train Loss: 0.0021, Val Loss: 0.0056
# Validation loss decreased (0.005633 --> 0.005616).  Saving model ...
# Epoch [499/500], Train Loss: 0.0020, Val Loss: 0.0056
# Validation loss decreased (0.005616 --> 0.005600).  Saving model ...
# Epoch [500/500], Train Loss: 0.0021, Val Loss: 0.0056
# Validation loss decreased (0.005600 --> 0.005589).  Saving model ...

# %%
with h5py.File('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_2/training_losses.h5', 'r') as f:
    train_losses_apple = np.array(f['train_losses_apple'])
    val_losses_apple = np.array(f['val_losses_apple'])
    train_losses_google = np.array(f['train_losses_google'])
    val_losses_google = np.array(f['val_losses_google'])
    train_losses_tesla = np.array(f['train_losses_tesla'])
    val_losses_tesla = np.array(f['val_losses_tesla'])

# %%
def plot_learning_curves(train_losses, val_losses, title):
    epochs = range(1, len(train_losses) + 1)
    plt.plot(epochs, train_losses, 'bo', label='Training loss')
    plt.plot(epochs, val_losses, 'b', label='Validation loss')
    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

plot_learning_curves(train_losses_apple, val_losses_apple, 'Learning Curve for Apple')
plot_learning_curves(train_losses_google, val_losses_google, 'Learning Curve for Google')
plot_learning_curves(train_losses_tesla, val_losses_tesla, 'Learning Curve for Tesla')

# %%
# Load model parameters
model_apple = StockPredictor(input_size, hidden_layer_size, num_layers, output_size)
model_google = StockPredictor(input_size, hidden_layer_size, num_layers, output_size)
model_tesla = StockPredictor(input_size, hidden_layer_size, num_layers, output_size)

model_apple.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_2/model_apple.pth'))
model_google.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_2/model_google.pth'))
model_tesla.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_2/model_tesla.pth'))
# Out:
# <All keys matched successfully>

# %%
def validate_model(model, X_test, y_test, stock_name):
    model.eval()
    with torch.no_grad():
        predictions, _ = model(X_test)
        predictions = predictions.numpy()

    # Reshape predicted and true values into two-dimensional arrays
    predictions_2d = predictions.reshape(-1, y_test.shape[-1])
    y_test_2d = y_test.numpy().reshape(-1, y_test.shape[-1])

    np.savetxt(f"/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_2/{stock_name}_predictions.csv", predictions_2d, delimiter=",", header="Predicted_Close,Predicted_Adj_Close", comments="")
    np.savetxt(f"/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_2/{stock_name}_true_values.csv", y_test_2d, delimiter=",", header="True_Close,True_Adj_Close", comments="")

    # Calculate RMSE, MAE, MAPE, and R2 for each feature
    rmses, maes, mapes, r2s = [], [], [], []
    for i in range(predictions_2d.shape[1]):
        mse = mean_squared_error(y_test_2d[:, i], predictions_2d[:, i])
        mae = mean_absolute_error(y_test_2d[:, i], predictions_2d[:, i])
        mape = np.mean(np.abs((y_test_2d[:, i] - predictions_2d[:, i]) / y_test_2d[:, i])) * 100
        r2 = r2_score(y_test_2d[:, i], predictions_2d[:, i])

        rmse = sqrt(mse)
        rmses.append(rmse)
        maes.append(mae)
        mapes.append(mape)
        r2s.append(r2)

    # Plotting of actual versus predicted values
    plt.figure(figsize=(15, 5))
    plt.plot(y_test_2d[:, 0], label='Actual')
    plt.plot(predictions_2d[:, 0], label='Predicted')
    plt.title('Actual vs Predicted')
    plt.legend()
    plt.show()

    # Error distribution analysis
    sns.histplot(y_test_2d[:, 0] - predictions_2d[:, 0], kde=True)
    plt.title('Error Distribution')
    plt.xlabel('Error')
    plt.ylabel('Frequency')
    plt.show()

    # Calculate total RMSE, MAE, MAPE and R2
    total_rmse = sqrt(mean_squared_error(y_test_2d, predictions_2d))
    total_mae = mean_absolute_error(y_test_2d, predictions_2d)
    total_mape = np.mean(np.abs((y_test_2d - predictions_2d) / y_test_2d)) * 100
    total_r2 = r2_score(y_test_2d, predictions_2d)

    return rmses, total_rmse, maes, total_mae, mapes, total_mape, r2s, total_r2

# Evaluate Apple's model
rmses_apple, total_rmse_apple, maes_apple, total_mae_apple, mapes_apple, total_mape_apple, r2s_apple, total_r2_apple = validate_model(model_apple, X_test_apple, y_test_apple, 'apple')

# Evaluate Google's models
rmses_google, total_rmse_google, maes_google, total_mae_google, mapes_google, total_mape_google, r2s_google, total_r2_google = validate_model(model_google, X_test_google, y_test_google, 'google')

# Evaluate Tesla's models
rmses_tesla, total_rmse_tesla, maes_tesla, total_mae_tesla, mapes_tesla, total_mape_tesla, r2s_tesla, total_r2_tesla = validate_model(model_tesla, X_test_tesla, y_test_tesla, 'tesla')

# %%
# Print Apple's evaluation results
print("Apple Stock:")
print("Feature-wise RMSE:", rmses_apple)
print("Total RMSE:", total_rmse_apple)
print("Feature-wise MAE:", maes_apple)
print("Total MAE:", total_mae_apple)
print("Feature-wise MAPE:", mapes_apple)
print("Total MAPE:", total_mape_apple)
print("Feature-wise R-squared:", r2s_apple)
print("Total R-squared:", total_r2_apple)
print("\n")

# Print Google's assessment results
print("Google Stock:")
print("Feature-wise RMSE:", rmses_google)
print("Total RMSE:", total_rmse_google)
print("Feature-wise MAE:", maes_google)
print("Total MAE:", total_mae_google)
print("Feature-wise MAPE:", mapes_google)
print("Total MAPE:", total_mape_google)
print("Feature-wise R-squared:", r2s_google)
print("Total R-squared:", total_r2_google)
print("\n")

# Print Tesla's evaluation results
print("Tesla Stock:")
print("Feature-wise RMSE:", rmses_tesla)
print("Total RMSE:", total_rmse_tesla)
print("Feature-wise MAE:", maes_tesla)
print("Total MAE:", total_mae_tesla)
print("Feature-wise MAPE:", mapes_tesla)
print("Total MAPE:", total_mape_tesla)
print("Feature-wise R-squared:", r2s_tesla)
print("Total R-squared:", total_r2_tesla)
# Out:
# Apple Stock:
# Feature-wise RMSE: [0.05698285221175979, 0.04680693174447144]
# Total RMSE: 0.05214371856312203
# Feature-wise MAE: [0.04788399, 0.03974662]
# Total MAE: 0.043815292
# Feature-wise MAPE: [6.0228850692510605, 4.993320629000664]
# Total MAPE: 5.508102476596832
# Feature-wise R-squared: [0.3752314056716264, 0.5709118741491747]
# Total R-squared: 0.47307163906282795
#
#
# Google Stock:
# Feature-wise RMSE: [0.05364345516138587, 0.05323301223304356]
# Total RMSE: 0.053438625578291654
# Feature-wise MAE: [0.045366887, 0.04460197]
# Total MAE: 0.044984423
# Feature-wise MAPE: [9.111707657575607, 9.044840186834335]
# Total MAPE: 9.078273177146912
# Feature-wise R-squared: [0.7044006500343775, 0.7089067645751481]
# Total R-squared: 0.7066537073047627
#
#
# Tesla Stock:
# Feature-wise RMSE: [0.06173511639719247, 0.05573050607463581]
# Total RMSE: 0.0588094951442734
# Feature-wise MAE: [0.04957443, 0.045695484]
# Total MAE: 0.047634967
# Feature-wise MAPE: [9.617935121059418, 9.010045230388641]
# Total MAPE: 9.31398943066597
# Feature-wise R-squared: [0.7873035668352579, 0.826666859907711]
# Total R-squared: 0.8069852138633123

# %% [markdown]
# ### Apple Stock Model Comparison
#
# | Metric      | Model 2 Feature-wise   | Model 2 Total  | Model 1 Feature-wise   | Model 1 Total  |
# |-------------|------------------------|----------------|------------------------|----------------|
# | RMSE        | [0.0424, 0.0427]       | 0.0426         | [0.0570, 0.0468]       | 0.0521         |
# | MAE         | [0.0351, 0.0354]       | 0.0352         | [0.0479, 0.0397]       | 0.0438         |
# | MAPE        | [4.5209, 4.4823]       | 4.5016         | [6.0229, 4.9933]       | 5.5081         |
# | R-squared   | [0.6540, 0.6423]       | 0.6482         | [0.3752, 0.5709]       | 0.4731         |
#
# ### Google Stock Model Comparison
#
# | Metric      | Model 2 Feature-wise   | Model 2 Total  | Model 1 Feature-wise   | Model 1 Total  |
# |-------------|------------------------|----------------|------------------------|----------------|
# | RMSE        | [0.0637, 0.0632]       | 0.0634         | [0.0536, 0.0532]       | 0.0534         |
# | MAE         | [0.0528, 0.0524]       | 0.0526         | [0.0454, 0.0446]       | 0.0450         |
# | MAPE        | [10.7197, 10.6423]     | 10.6810        | [9.1117, 9.0448]       | 9.0783         |
# | R-squared   | [0.5837, 0.5895]       | 0.5866         | [0.7044, 0.7089]       | 0.7067         |
#
# ### Tesla Stock Model Comparison
#
# | Metric      | Model 2 Feature-wise   | Model 2 Total  | Model 1 Feature-wise   | Model 1 Total  |
# |-------------|------------------------|----------------|------------------------|----------------|
# | RMSE        | [0.0543, 0.0541]       | 0.0542         | [0.0617, 0.0557]       | 0.0588         |
# | MAE         | [0.0442, 0.0440]       | 0.0441         | [0.0496, 0.0457]       | 0.0476         |
# | MAPE        | [9.2754, 9.2124]       | 9.2439         | [9.6179, 9.0100]       | 9.3140         |
# | R-squared   | [0.8355, 0.8368]       | 0.8362         | [0.7873, 0.8267]       | 0.8070
