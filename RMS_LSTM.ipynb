# %% [markdown]
# <a href="https://colab.research.google.com/github/AndyDengFKu/DPA3/blob/main/RMS_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import h5py
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

from math import sqrt
from sklearn.model_selection import KFold
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import TensorDataset, DataLoader, Subset
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with h5py.File('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/stock_data.h5', 'r') as f:
    # apple
    X_train_apple = torch.tensor(f['X_train_apple'][:], dtype=torch.float32)
    y_train_apple = torch.tensor(f['y_train_apple'][:], dtype=torch.float32)
    X_val_apple = torch.tensor(f['X_val_apple'][:], dtype=torch.float32)
    y_val_apple = torch.tensor(f['y_val_apple'][:], dtype=torch.float32)
    X_test_apple = torch.tensor(f['X_test_apple'][:], dtype=torch.float32)
    y_test_apple = torch.tensor(f['y_test_apple'][:], dtype=torch.float32)

    # google
    X_train_google = torch.tensor(f['X_train_google'][:], dtype=torch.float32)
    y_train_google = torch.tensor(f['y_train_google'][:], dtype=torch.float32)
    X_val_google = torch.tensor(f['X_val_google'][:], dtype=torch.float32)
    y_val_google = torch.tensor(f['y_val_google'][:], dtype=torch.float32)
    X_test_google = torch.tensor(f['X_test_google'][:], dtype=torch.float32)
    y_test_google = torch.tensor(f['y_test_google'][:], dtype=torch.float32)

    # tesla
    X_train_tesla = torch.tensor(f['X_train_tesla'][:], dtype=torch.float32)
    y_train_tesla = torch.tensor(f['y_train_tesla'][:], dtype=torch.float32)
    X_val_tesla = torch.tensor(f['X_val_tesla'][:], dtype=torch.float32)
    y_val_tesla = torch.tensor(f['y_val_tesla'][:], dtype=torch.float32)
    X_test_tesla = torch.tensor(f['X_test_tesla'][:], dtype=torch.float32)
    y_test_tesla = torch.tensor(f['y_test_tesla'][:], dtype=torch.float32)

# dataloader
train_loader_apple = DataLoader(TensorDataset(X_train_apple, y_train_apple), batch_size=64, shuffle=True)
val_loader_apple = DataLoader(TensorDataset(X_val_apple, y_val_apple), batch_size=64, shuffle=False)
test_loader_apple = DataLoader(TensorDataset(X_test_apple, y_test_apple), batch_size=64, shuffle=False)

train_loader_google = DataLoader(TensorDataset(X_train_google, y_train_google), batch_size=64, shuffle=True)
val_loader_google = DataLoader(TensorDataset(X_val_google, y_val_google), batch_size=64, shuffle=False)
test_loader_google = DataLoader(TensorDataset(X_test_google, y_test_google), batch_size=64, shuffle=False)

train_loader_tesla = DataLoader(TensorDataset(X_train_tesla, y_train_tesla), batch_size=64, shuffle=True)
val_loader_tesla = DataLoader(TensorDataset(X_val_tesla, y_val_tesla), batch_size=64, shuffle=False)
test_loader_tesla = DataLoader(TensorDataset(X_test_tesla, y_test_tesla), batch_size=64, shuffle=False)

# %%
class Attention(nn.Module):
    def __init__(self, hidden_layer_size):
        super(Attention, self).__init__()
        self.hidden_layer_size = hidden_layer_size
        self.attention = nn.Linear(self.hidden_layer_size, 1)

    def forward(self, x):
        attention_scores = self.attention(x)
        attention_weights = F.softmax(attention_scores, dim=1)
        context_vector = attention_weights * x
        context_vector = torch.sum(context_vector, dim=1)
        return context_vector, attention_weights

# %%
class StockPredictor(nn.Module):
    def __init__(self, input_size, hidden_layer_size, num_layers, output_size, dropout=0.2):
        super(StockPredictor, self).__init__()
        self.hidden_layer_size = hidden_layer_size
        self.num_layers = num_layers

        self.attention = Attention(hidden_layer_size)

        # Initialize LSTM with the dropout
        self.lstm = nn.LSTM(input_size, hidden_layer_size, num_layers,
                            batch_first=True, dropout=dropout if num_layers > 1 else 0)

        # Initialize Dense layer with He initialization
        self.linear = nn.Linear(hidden_layer_size * 2, output_size)
        nn.init.kaiming_normal_(self.linear.weight, mode='fan_out', nonlinearity='leaky_relu')

        # Leaky ReLU activation
        self.leaky_relu = nn.LeakyReLU(negative_slope=0.01)

    def forward(self, x):
      # Initialize hidden state and cell state
      h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_layer_size).to(x.device)
      c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_layer_size).to(x.device)

      # Forward propagate LSTM
      lstm_out, _ = self.lstm(x, (h0, c0))

      # Get the context vector from the attention layer
      context_vector, attention_weights = self.attention(lstm_out)
      out = lstm_out[:, -1, :]  # Get the last time step output from LSTM

      # Apply Leaky ReLU activation
      out = self.leaky_relu(out)

      # Pass through the linear layer
      combined_out = torch.cat((out, context_vector), 1)
      out = self.linear(combined_out)
      return out, attention_weights  # Make sure to return both output and attention weights

# %%
def cross_validate(model_class, dataset, k_folds, l2_penalties):
    # Initialise K-fold cross validation
    kf = KFold(n_splits=k_folds, shuffle=True)

    # Record the average validation loss for each regularisation parameter
    avg_val_losses = {}

    # For each L2 regularised intensity
    for l2_penalty in l2_penalties:
        print(f"Testing L2 penalty: {l2_penalty}")
        val_losses = []  # Save the validation losses for each fold

        # Perform k-fold cross validation
        for fold, (train_ids, val_ids) in enumerate(kf.split(dataset)):
            print(f"Folding {fold+1}/{k_folds}")
            # Split the data
            X_train_fold = dataset.tensors[0][train_ids]
            y_train_fold = dataset.tensors[1][train_ids]
            X_val_fold = dataset.tensors[0][val_ids]
            y_val_fold = dataset.tensors[1][val_ids]

            # Create the data loader
            train_loader = DataLoader(TensorDataset(X_train_fold, y_train_fold), batch_size=64, shuffle=True)
            val_loader = DataLoader(TensorDataset(X_val_fold, y_val_fold), batch_size=64, shuffle=False)

            # Initialise the model
            model = model_class(input_size, hidden_layer_size, num_layers, output_size)

            trained_model, train_losses, fold_val_losses = train_and_validate(
                model, train_loader, val_loader, num_epochs=30, weight_decay=l2_penalty)

            # Record the average validation loss for this fold
            avg_fold_val_loss = sum(fold_val_losses) / len(fold_val_losses)
            val_losses.append(avg_fold_val_loss)

        # Calculate the average validation loss for this L2 regularisation parameter
        avg_val_losses[l2_penalty] = sum(val_losses) / len(val_losses)

    # Return the L2 regularisation parameter with the lowest average validation loss
    best_l2_penalty = min(avg_val_losses, key=avg_val_losses.get)
    return best_l2_penalty, avg_val_losses

# %%
class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), 'checkpoint.pth')
        self.val_loss_min = val_loss

def train_and_validate(model, train_loader, val_loader, num_epochs=50, weight_decay=0.01):
    criterion = nn.MSELoss()

    optimizer = optim.RMSprop(model.parameters(), lr=0.001, alpha=0.99, eps=1e-08, weight_decay=weight_decay, momentum=0, centered=False)
    # Learning rate scheduler
    scheduler = ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.5, min_lr=1e-5, verbose=True)
    # Early stop
    early_stopping = EarlyStopping(patience=50, verbose=True)

    train_losses = []
    val_losses = []

    for epoch in range(num_epochs):
        # Training modalities
        model.train()
        train_loss = 0.0
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            outputs, attention_weights = model(X_batch)  # Get outputs and attention weights
            outputs = outputs  # Only use outputs for loss calculation

            loss = criterion(outputs, y_batch.view(y_batch.size(0), -1))
            loss.backward()
            optimizer.step()
            train_loss += loss.item()

        avg_train_loss = train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        #Evaluation model
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for X_batch, y_batch in val_loader:
                outputs, attention_weights = model(X_batch)  # Get outputs and attention weights
                outputs = outputs  # Only use outputs for loss calculation

                loss = criterion(outputs, y_batch.view(y_batch.size(0), -1))
                val_loss += loss.item()

        avg_val_loss = val_loss / len(val_loader)
        val_losses.append(avg_val_loss)

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')

        # Updated early stop method and learning rate scheduler
        early_stopping(avg_val_loss, model)
        scheduler.step(avg_val_loss)

        if early_stopping.early_stop:
            print("Early Stop")
            break

    # Load optimal model weights
    model.load_state_dict(torch.load('checkpoint.pth'))

    return model, train_losses, val_losses

# %%
# Initialize the model, loss function and optimizer
input_size = X_train_apple.shape[2]
hidden_layer_size = 256
num_layers = 3
output_size = y_train_apple.shape[2] * y_train_apple.shape[1]

# %%
l2_penalties = [0.0001, 0.001, 0.01, 0.1, 1.0]
# Cross-validation of Apple's dataset
dataset_apple = TensorDataset(X_train_apple, y_train_apple)
best_penalty_apple, validation_results_apple = cross_validate(
    StockPredictor, dataset_apple, 5, l2_penalties)


# Cross-validation of Google Inc. datasets
dataset_google = TensorDataset(X_train_google, y_train_google)
best_penalty_google, validation_results_google = cross_validate(
    StockPredictor, dataset_google, 5, l2_penalties)


# Cross-validation of Tesla Inc. datasets
dataset_tesla = TensorDataset(X_train_tesla, y_train_tesla)
best_penalty_tesla, validation_results_tesla = cross_validate(
    StockPredictor, dataset_tesla, 5, l2_penalties)

print(f"Best L2 penalty for Apple: {best_penalty_apple}")
print(f"Best L2 penalty for Google: {best_penalty_google}")
print(f"Best L2 penalty for Tesla: {best_penalty_tesla}")
# Out:
# Testing L2 penalty: 0.0001
# Folding 1/5
# Epoch [1/30], Train Loss: 0.0767, Val Loss: 0.0112
# Validation loss decreased (inf --> 0.011227).  Saving model ...
# Epoch [2/30], Train Loss: 0.0055, Val Loss: 0.0031
# Validation loss decreased (0.011227 --> 0.003137).  Saving model ...
# Epoch [3/30], Train Loss: 0.0021, Val Loss: 0.0020
# Validation loss decreased (0.003137 --> 0.002021).  Saving model ...
# Epoch [4/30], Train Loss: 0.0014, Val Loss: 0.0043
# EarlyStopping counter: 1 out of 50
# Epoch [5/30], Train Loss: 0.0016, Val Loss: 0.0021
# EarlyStopping counter: 2 out of 50
# Epoch [6/30], Train Loss: 0.0033, Val Loss: 0.0196
# EarlyStopping counter: 3 out of 50
# Epoch [7/30], Train Loss: 0.0041, Val Loss: 0.0030
# EarlyStopping counter: 4 out of 50
# Epoch [8/30], Train Loss: 0.0013, Val Loss: 0.0029
# EarlyStopping counter: 5 out of 50
# Epoch [9/30], Train Loss: 0.0020, Val Loss: 0.0022
# EarlyStopping counter: 6 out of 50
# Epoch 00009: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [10/30], Train Loss: 0.0013, Val Loss: 0.0021
# EarlyStopping counter: 7 out of 50
# Epoch [11/30], Train Loss: 0.0012, Val Loss: 0.0018
# Validation loss decreased (0.002021 --> 0.001818).  Saving model ...
# Epoch [12/30], Train Loss: 0.0011, Val Loss: 0.0018
# Validation loss decreased (0.001818 --> 0.001806).  Saving model ...
# Epoch [13/30], Train Loss: 0.0011, Val Loss: 0.0023
# EarlyStopping counter: 1 out of 50
# Epoch [14/30], Train Loss: 0.0011, Val Loss: 0.0013
# Validation loss decreased (0.001806 --> 0.001287).  Saving model ...
# Epoch [15/30], Train Loss: 0.0011, Val Loss: 0.0012
# Validation loss decreased (0.001287 --> 0.001245).  Saving model ...
# Epoch [16/30], Train Loss: 0.0011, Val Loss: 0.0044
# EarlyStopping counter: 1 out of 50
# Epoch [17/30], Train Loss: 0.0013, Val Loss: 0.0012
# Validation loss decreased (0.001245 --> 0.001188).  Saving model ...
# Epoch [18/30], Train Loss: 0.0013, Val Loss: 0.0015
# EarlyStopping counter: 1 out of 50
# Epoch [19/30], Train Loss: 0.0010, Val Loss: 0.0019
# EarlyStopping counter: 2 out of 50
# Epoch [20/30], Train Loss: 0.0012, Val Loss: 0.0018
# EarlyStopping counter: 3 out of 50
# Epoch [21/30], Train Loss: 0.0011, Val Loss: 0.0011
# Validation loss decreased (0.001188 --> 0.001144).  Saving model ...
# Epoch [22/30], Train Loss: 0.0010, Val Loss: 0.0048
# EarlyStopping counter: 1 out of 50
# Epoch [23/30], Train Loss: 0.0027, Val Loss: 0.0015
# EarlyStopping counter: 2 out of 50
# Epoch [24/30], Train Loss: 0.0011, Val Loss: 0.0017
# EarlyStopping counter: 3 out of 50
# Epoch [25/30], Train Loss: 0.0011, Val Loss: 0.0014
# EarlyStopping counter: 4 out of 50
# Epoch [26/30], Train Loss: 0.0017, Val Loss: 0.0013
# EarlyStopping counter: 5 out of 50
# Epoch [27/30], Train Loss: 0.0011, Val Loss: 0.0053
# EarlyStopping counter: 6 out of 50
# Epoch 00027: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [28/30], Train Loss: 0.0010, Val Loss: 0.0015
# EarlyStopping counter: 7 out of 50
# Epoch [29/30], Train Loss: 0.0010, Val Loss: 0.0018
# EarlyStopping counter: 8 out of 50
# Epoch [30/30], Train Loss: 0.0010, Val Loss: 0.0015
# EarlyStopping counter: 9 out of 50
# Folding 2/5
# Epoch [1/30], Train Loss: 0.0907, Val Loss: 0.0083
# Validation loss decreased (inf --> 0.008312).  Saving model ...
# Epoch [2/30], Train Loss: 0.0024, Val Loss: 0.0085
# EarlyStopping counter: 1 out of 50
# Epoch [3/30], Train Loss: 0.0033, Val Loss: 0.0026
# Validation loss decreased (0.008312 --> 0.002650).  Saving model ...
# Epoch [4/30], Train Loss: 0.0017, Val Loss: 0.0014
# Validation loss decreased (0.002650 --> 0.001396).  Saving model ...
# Epoch [5/30], Train Loss: 0.0018, Val Loss: 0.0013
# Validation loss decreased (0.001396 --> 0.001290).  Saving model ...
# Epoch [6/30], Train Loss: 0.0027, Val Loss: 0.0027
# EarlyStopping counter: 1 out of 50
# Epoch [7/30], Train Loss: 0.0013, Val Loss: 0.0018
# EarlyStopping counter: 2 out of 50
# Epoch [8/30], Train Loss: 0.0036, Val Loss: 0.0036
# EarlyStopping counter: 3 out of 50
# Epoch [9/30], Train Loss: 0.0031, Val Loss: 0.0076
# EarlyStopping counter: 4 out of 50
# Epoch [10/30], Train Loss: 0.0028, Val Loss: 0.0014
# EarlyStopping counter: 5 out of 50
# Epoch [11/30], Train Loss: 0.0022, Val Loss: 0.0070
# EarlyStopping counter: 6 out of 50
# Epoch 00011: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [12/30], Train Loss: 0.0013, Val Loss: 0.0013
# Validation loss decreased (0.001290 --> 0.001284).  Saving model ...
# Epoch [13/30], Train Loss: 0.0011, Val Loss: 0.0013
# EarlyStopping counter: 1 out of 50
# Epoch [14/30], Train Loss: 0.0014, Val Loss: 0.0009
# Validation loss decreased (0.001284 --> 0.000928).  Saving model ...
# Epoch [15/30], Train Loss: 0.0010, Val Loss: 0.0012
# EarlyStopping counter: 1 out of 50
# Epoch [16/30], Train Loss: 0.0011, Val Loss: 0.0008
# Validation loss decreased (0.000928 --> 0.000794).  Saving model ...
# Epoch [17/30], Train Loss: 0.0012, Val Loss: 0.0009
# EarlyStopping counter: 1 out of 50
# Epoch [18/30], Train Loss: 0.0012, Val Loss: 0.0012
# EarlyStopping counter: 2 out of 50
# Epoch [19/30], Train Loss: 0.0012, Val Loss: 0.0020
# EarlyStopping counter: 3 out of 50
# Epoch [20/30], Train Loss: 0.0012, Val Loss: 0.0009
# EarlyStopping counter: 4 out of 50
# Epoch [21/30], Train Loss: 0.0012, Val Loss: 0.0008
# Validation loss decreased (0.000794 --> 0.000755).  Saving model ...
# Epoch [22/30], Train Loss: 0.0012, Val Loss: 0.0008
# EarlyStopping counter: 1 out of 50
# Epoch [23/30], Train Loss: 0.0011, Val Loss: 0.0007
# Validation loss decreased (0.000755 --> 0.000651).  Saving model ...
# Epoch [24/30], Train Loss: 0.0011, Val Loss: 0.0007
# EarlyStopping counter: 1 out of 50
# Epoch [25/30], Train Loss: 0.0020, Val Loss: 0.0049
# EarlyStopping counter: 2 out of 50
# Epoch [26/30], Train Loss: 0.0015, Val Loss: 0.0015
# EarlyStopping counter: 3 out of 50
# Epoch [27/30], Train Loss: 0.0010, Val Loss: 0.0008
# EarlyStopping counter: 4 out of 50
# Epoch [28/30], Train Loss: 0.0015, Val Loss: 0.0014
# EarlyStopping counter: 5 out of 50
# Epoch [29/30], Train Loss: 0.0015, Val Loss: 0.0051
# EarlyStopping counter: 6 out of 50
# Epoch 00029: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [30/30], Train Loss: 0.0011, Val Loss: 0.0013
# EarlyStopping counter: 7 out of 50
# Folding 3/5
# Epoch [1/30], Train Loss: 0.0597, Val Loss: 0.0154
# Validation loss decreased (inf --> 0.015390).  Saving model ...
# Epoch [2/30], Train Loss: 0.0020, Val Loss: 0.0012
# Validation loss decreased (0.015390 --> 0.001156).  Saving model ...
# Epoch [3/30], Train Loss: 0.0029, Val Loss: 0.0022
# EarlyStopping counter: 1 out of 50
# Epoch [4/30], Train Loss: 0.0014, Val Loss: 0.0026
# EarlyStopping counter: 2 out of 50
# Epoch [5/30], Train Loss: 0.0015, Val Loss: 0.0025
# EarlyStopping counter: 3 out of 50
# Epoch [6/30], Train Loss: 0.0021, Val Loss: 0.0015
# EarlyStopping counter: 4 out of 50
# Epoch [7/30], Train Loss: 0.0018, Val Loss: 0.0095
# EarlyStopping counter: 5 out of 50
# Epoch [8/30], Train Loss: 0.0026, Val Loss: 0.0009
# Validation loss decreased (0.001156 --> 0.000893).  Saving model ...
# Epoch [9/30], Train Loss: 0.0018, Val Loss: 0.0011
# EarlyStopping counter: 1 out of 50
# Epoch [10/30], Train Loss: 0.0014, Val Loss: 0.0068
# EarlyStopping counter: 2 out of 50
# Epoch [11/30], Train Loss: 0.0029, Val Loss: 0.0012
# EarlyStopping counter: 3 out of 50
# Epoch [12/30], Train Loss: 0.0019, Val Loss: 0.0011
# EarlyStopping counter: 4 out of 50
# Epoch [13/30], Train Loss: 0.0015, Val Loss: 0.0048
# EarlyStopping counter: 5 out of 50
# Epoch [14/30], Train Loss: 0.0029, Val Loss: 0.0027
# EarlyStopping counter: 6 out of 50
# Epoch 00014: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [15/30], Train Loss: 0.0010, Val Loss: 0.0008
# Validation loss decreased (0.000893 --> 0.000844).  Saving model ...
# Epoch [16/30], Train Loss: 0.0010, Val Loss: 0.0009
# EarlyStopping counter: 1 out of 50
# Epoch [17/30], Train Loss: 0.0010, Val Loss: 0.0012
# EarlyStopping counter: 2 out of 50
# Epoch [18/30], Train Loss: 0.0009, Val Loss: 0.0010
# EarlyStopping counter: 3 out of 50
# Epoch [19/30], Train Loss: 0.0010, Val Loss: 0.0014
# EarlyStopping counter: 4 out of 50
# Epoch [20/30], Train Loss: 0.0009, Val Loss: 0.0011
# EarlyStopping counter: 5 out of 50
# Epoch [21/30], Train Loss: 0.0010, Val Loss: 0.0016
# EarlyStopping counter: 6 out of 50
# Epoch 00021: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [22/30], Train Loss: 0.0009, Val Loss: 0.0007
# Validation loss decreased (0.000844 --> 0.000750).  Saving model ...
# Epoch [23/30], Train Loss: 0.0009, Val Loss: 0.0008
# EarlyStopping counter: 1 out of 50
# Epoch [24/30], Train Loss: 0.0009, Val Loss: 0.0007
# Validation loss decreased (0.000750 --> 0.000706).  Saving model ...
# Epoch [25/30], Train Loss: 0.0009, Val Loss: 0.0007
# Validation loss decreased (0.000706 --> 0.000705).  Saving model ...
# Epoch [26/30], Train Loss: 0.0009, Val Loss: 0.0007
# Validation loss decreased (0.000705 --> 0.000704).  Saving model ...
# Epoch [27/30], Train Loss: 0.0009, Val Loss: 0.0008
# EarlyStopping counter: 1 out of 50
# Epoch [28/30], Train Loss: 0.0009, Val Loss: 0.0007
# EarlyStopping counter: 2 out of 50
# Epoch [29/30], Train Loss: 0.0009, Val Loss: 0.0007
# EarlyStopping counter: 3 out of 50
# Epoch [30/30], Train Loss: 0.0010, Val Loss: 0.0010
# EarlyStopping counter: 4 out of 50
# Folding 4/5
# Epoch [1/30], Train Loss: 0.0773, Val Loss: 0.0038
# Validation loss decreased (inf --> 0.003783).  Saving model ...
# Epoch [2/30], Train Loss: 0.0034, Val Loss: 0.0147
# EarlyStopping counter: 1 out of 50
# Epoch [3/30], Train Loss: 0.0038, Val Loss: 0.0024
# Validation loss decreased (0.003783 --> 0.002351).  Saving model ...
# Epoch [4/30], Train Loss: 0.0015, Val Loss: 0.0028
# EarlyStopping counter: 1 out of 50
# Epoch [5/30], Train Loss: 0.0021, Val Loss: 0.0130
# EarlyStopping counter: 2 out of 50
# Epoch [6/30], Train Loss: 0.0019, Val Loss: 0.0022
# Validation loss decreased (0.002351 --> 0.002225).  Saving model ...
# Epoch [7/30], Train Loss: 0.0028, Val Loss: 0.0024
# EarlyStopping counter: 1 out of 50
# Epoch [8/30], Train Loss: 0.0024, Val Loss: 0.0028
# EarlyStopping counter: 2 out of 50
# Epoch [9/30], Train Loss: 0.0016, Val Loss: 0.0039
# EarlyStopping counter: 3 out of 50
# Epoch [10/30], Train Loss: 0.0031, Val Loss: 0.0019
# Validation loss decreased (0.002225 --> 0.001900).  Saving model ...
# Epoch [11/30], Train Loss: 0.0020, Val Loss: 0.0056
# EarlyStopping counter: 1 out of 50
# Epoch [12/30], Train Loss: 0.0018, Val Loss: 0.0019
# Validation loss decreased (0.001900 --> 0.001897).  Saving model ...
# Epoch [13/30], Train Loss: 0.0032, Val Loss: 0.0023
# EarlyStopping counter: 1 out of 50
# Epoch [14/30], Train Loss: 0.0013, Val Loss: 0.0037
# EarlyStopping counter: 2 out of 50
# Epoch [15/30], Train Loss: 0.0014, Val Loss: 0.0027
# EarlyStopping counter: 3 out of 50
# Epoch [16/30], Train Loss: 0.0015, Val Loss: 0.0021
# EarlyStopping counter: 4 out of 50
# Epoch [17/30], Train Loss: 0.0039, Val Loss: 0.0059
# EarlyStopping counter: 5 out of 50
# Epoch [18/30], Train Loss: 0.0029, Val Loss: 0.0018
# Validation loss decreased (0.001897 --> 0.001766).  Saving model ...
# Epoch [19/30], Train Loss: 0.0020, Val Loss: 0.0018
# EarlyStopping counter: 1 out of 50
# Epoch [20/30], Train Loss: 0.0014, Val Loss: 0.0094
# EarlyStopping counter: 2 out of 50
# Epoch [21/30], Train Loss: 0.0015, Val Loss: 0.0043
# EarlyStopping counter: 3 out of 50
# Epoch [22/30], Train Loss: 0.0028, Val Loss: 0.0032
# EarlyStopping counter: 4 out of 50
# Epoch [23/30], Train Loss: 0.0021, Val Loss: 0.0072
# EarlyStopping counter: 5 out of 50
# Epoch [24/30], Train Loss: 0.0015, Val Loss: 0.0020
# EarlyStopping counter: 6 out of 50
# Epoch 00024: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [25/30], Train Loss: 0.0009, Val Loss: 0.0017
# Validation loss decreased (0.001766 --> 0.001675).  Saving model ...
# Epoch [26/30], Train Loss: 0.0008, Val Loss: 0.0014
# Validation loss decreased (0.001675 --> 0.001387).  Saving model ...
# Epoch [27/30], Train Loss: 0.0009, Val Loss: 0.0014
# Validation loss decreased (0.001387 --> 0.001353).  Saving model ...
# Epoch [28/30], Train Loss: 0.0010, Val Loss: 0.0031
# EarlyStopping counter: 1 out of 50
# Epoch [29/30], Train Loss: 0.0010, Val Loss: 0.0014
# EarlyStopping counter: 2 out of 50
# Epoch [30/30], Train Loss: 0.0009, Val Loss: 0.0019
# EarlyStopping counter: 3 out of 50
# Folding 5/5
# Epoch [1/30], Train Loss: 0.1027, Val Loss: 0.0411
# Validation loss decreased (inf --> 0.041105).  Saving model ...
# Epoch [2/30], Train Loss: 0.0066, Val Loss: 0.0015
# Validation loss decreased (0.041105 --> 0.001537).  Saving model ...
# Epoch [3/30], Train Loss: 0.0017, Val Loss: 0.0016
# EarlyStopping counter: 1 out of 50
# Epoch [4/30], Train Loss: 0.0014, Val Loss: 0.0023
# EarlyStopping counter: 2 out of 50
# Epoch [5/30], Train Loss: 0.0019, Val Loss: 0.0020
# EarlyStopping counter: 3 out of 50
# Epoch [6/30], Train Loss: 0.0015, Val Loss: 0.0014
# Validation loss decreased (0.001537 --> 0.001415).  Saving model ...
# Epoch [7/30], Train Loss: 0.0016, Val Loss: 0.0018
# EarlyStopping counter: 1 out of 50
# Epoch [8/30], Train Loss: 0.0015, Val Loss: 0.0035
# EarlyStopping counter: 2 out of 50
# Epoch [9/30], Train Loss: 0.0017, Val Loss: 0.0021
# EarlyStopping counter: 3 out of 50
# Epoch [10/30], Train Loss: 0.0020, Val Loss: 0.0087
# EarlyStopping counter: 4 out of 50
# Epoch [11/30], Train Loss: 0.0024, Val Loss: 0.0026
# EarlyStopping counter: 5 out of 50
# Epoch [12/30], Train Loss: 0.0019, Val Loss: 0.0013
# Validation loss decreased (0.001415 --> 0.001350).  Saving model ...
# Epoch [13/30], Train Loss: 0.0012, Val Loss: 0.0013
# Validation loss decreased (0.001350 --> 0.001257).  Saving model ...
# Epoch [14/30], Train Loss: 0.0019, Val Loss: 0.0043
# EarlyStopping counter: 1 out of 50
# Epoch [15/30], Train Loss: 0.0031, Val Loss: 0.0038
# EarlyStopping counter: 2 out of 50
# Epoch [16/30], Train Loss: 0.0013, Val Loss: 0.0016
# EarlyStopping counter: 3 out of 50
# Epoch [17/30], Train Loss: 0.0024, Val Loss: 0.0022
# EarlyStopping counter: 4 out of 50
# Epoch [18/30], Train Loss: 0.0016, Val Loss: 0.0015
# EarlyStopping counter: 5 out of 50
# Epoch [19/30], Train Loss: 0.0027, Val Loss: 0.0013
# EarlyStopping counter: 6 out of 50
# Epoch 00019: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [20/30], Train Loss: 0.0011, Val Loss: 0.0011
# Validation loss decreased (0.001257 --> 0.001145).  Saving model ...
# Epoch [21/30], Train Loss: 0.0011, Val Loss: 0.0014
# EarlyStopping counter: 1 out of 50
# Epoch [22/30], Train Loss: 0.0011, Val Loss: 0.0011
# Validation loss decreased (0.001145 --> 0.001124).  Saving model ...
# Epoch [23/30], Train Loss: 0.0010, Val Loss: 0.0012
# EarlyStopping counter: 1 out of 50
# Epoch [24/30], Train Loss: 0.0009, Val Loss: 0.0011
# Validation loss decreased (0.001124 --> 0.001097).  Saving model ...
# Epoch [25/30], Train Loss: 0.0009, Val Loss: 0.0011
# EarlyStopping counter: 1 out of 50
# Epoch [26/30], Train Loss: 0.0010, Val Loss: 0.0012
# EarlyStopping counter: 2 out of 50
# Epoch [27/30], Train Loss: 0.0010, Val Loss: 0.0012
# EarlyStopping counter: 3 out of 50
# Epoch [28/30], Train Loss: 0.0009, Val Loss: 0.0015
# EarlyStopping counter: 4 out of 50
# Epoch [29/30], Train Loss: 0.0010, Val Loss: 0.0023
# EarlyStopping counter: 5 out of 50
# Epoch [30/30], Train Loss: 0.0010, Val Loss: 0.0054
# EarlyStopping counter: 6 out of 50
# Epoch 00030: reducing learning rate of group 0 to 2.5000e-04.
# Testing L2 penalty: 0.001
# Folding 1/5
# Epoch [1/30], Train Loss: 0.0702, Val Loss: 0.0143
# Validation loss decreased (inf --> 0.014293).  Saving model ...
# Epoch [2/30], Train Loss: 0.0041, Val Loss: 0.0613
# EarlyStopping counter: 1 out of 50
# Epoch [3/30], Train Loss: 0.0049, Val Loss: 0.0029
# Validation loss decreased (0.014293 --> 0.002914).  Saving model ...
# Epoch [4/30], Train Loss: 0.0015, Val Loss: 0.0028
# Validation loss decreased (0.002914 --> 0.002850).  Saving model ...
# Epoch [5/30], Train Loss: 0.0014, Val Loss: 0.0048
# EarlyStopping counter: 1 out of 50
# Epoch [6/30], Train Loss: 0.0020, Val Loss: 0.0018
# Validation loss decreased (0.002850 --> 0.001796).  Saving model ...
# Epoch [7/30], Train Loss: 0.0028, Val Loss: 0.0126
# EarlyStopping counter: 1 out of 50
# Epoch [8/30], Train Loss: 0.0018, Val Loss: 0.0027
# EarlyStopping counter: 2 out of 50
# Epoch [9/30], Train Loss: 0.0025, Val Loss: 0.0032
# EarlyStopping counter: 3 out of 50
# Epoch [10/30], Train Loss: 0.0021, Val Loss: 0.0022
# EarlyStopping counter: 4 out of 50
# Epoch [11/30], Train Loss: 0.0023, Val Loss: 0.0028
# EarlyStopping counter: 5 out of 50
# Epoch [12/30], Train Loss: 0.0031, Val Loss: 0.0071
# EarlyStopping counter: 6 out of 50
# Epoch 00012: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [13/30], Train Loss: 0.0013, Val Loss: 0.0020
# EarlyStopping counter: 7 out of 50
# Epoch [14/30], Train Loss: 0.0011, Val Loss: 0.0015
# Validation loss decreased (0.001796 --> 0.001470).  Saving model ...
# Epoch [15/30], Train Loss: 0.0012, Val Loss: 0.0019
# EarlyStopping counter: 1 out of 50
# Epoch [16/30], Train Loss: 0.0011, Val Loss: 0.0019
# EarlyStopping counter: 2 out of 50
# Epoch [17/30], Train Loss: 0.0012, Val Loss: 0.0016
# EarlyStopping counter: 3 out of 50
# Epoch [18/30], Train Loss: 0.0015, Val Loss: 0.0014
# Validation loss decreased (0.001470 --> 0.001383).  Saving model ...
# Epoch [19/30], Train Loss: 0.0011, Val Loss: 0.0016
# EarlyStopping counter: 1 out of 50
# Epoch [20/30], Train Loss: 0.0012, Val Loss: 0.0017
# EarlyStopping counter: 2 out of 50
# Epoch [21/30], Train Loss: 0.0010, Val Loss: 0.0018
# EarlyStopping counter: 3 out of 50
# Epoch [22/30], Train Loss: 0.0011, Val Loss: 0.0042
# EarlyStopping counter: 4 out of 50
# Epoch [23/30], Train Loss: 0.0013, Val Loss: 0.0028
# EarlyStopping counter: 5 out of 50
# Epoch [24/30], Train Loss: 0.0018, Val Loss: 0.0014
# EarlyStopping counter: 6 out of 50
# Epoch 00024: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [25/30], Train Loss: 0.0011, Val Loss: 0.0013
# Validation loss decreased (0.001383 --> 0.001330).  Saving model ...
# Epoch [26/30], Train Loss: 0.0010, Val Loss: 0.0032
# EarlyStopping counter: 1 out of 50
# Epoch [27/30], Train Loss: 0.0010, Val Loss: 0.0012
# Validation loss decreased (0.001330 --> 0.001250).  Saving model ...
# Epoch [28/30], Train Loss: 0.0010, Val Loss: 0.0025
# EarlyStopping counter: 1 out of 50
# Epoch [29/30], Train Loss: 0.0010, Val Loss: 0.0014
# EarlyStopping counter: 2 out of 50
# Epoch [30/30], Train Loss: 0.0011, Val Loss: 0.0012
# Validation loss decreased (0.001250 --> 0.001168).  Saving model ...
# Folding 2/5
# Epoch [1/30], Train Loss: 0.0714, Val Loss: 0.0374
# Validation loss decreased (inf --> 0.037363).  Saving model ...
# Epoch [2/30], Train Loss: 0.0035, Val Loss: 0.0018
# Validation loss decreased (0.037363 --> 0.001843).  Saving model ...
# Epoch [3/30], Train Loss: 0.0014, Val Loss: 0.0023
# EarlyStopping counter: 1 out of 50
# Epoch [4/30], Train Loss: 0.0015, Val Loss: 0.0023
# EarlyStopping counter: 2 out of 50
# Epoch [5/30], Train Loss: 0.0021, Val Loss: 0.0017
# Validation loss decreased (0.001843 --> 0.001693).  Saving model ...
# Epoch [6/30], Train Loss: 0.0015, Val Loss: 0.0024
# EarlyStopping counter: 1 out of 50
# Epoch [7/30], Train Loss: 0.0013, Val Loss: 0.0028
# EarlyStopping counter: 2 out of 50
# Epoch [8/30], Train Loss: 0.0033, Val Loss: 0.0027
# EarlyStopping counter: 3 out of 50
# Epoch [9/30], Train Loss: 0.0015, Val Loss: 0.0030
# EarlyStopping counter: 4 out of 50
# Epoch [10/30], Train Loss: 0.0022, Val Loss: 0.0013
# Validation loss decreased (0.001693 --> 0.001278).  Saving model ...
# Epoch [11/30], Train Loss: 0.0015, Val Loss: 0.0037
# EarlyStopping counter: 1 out of 50
# Epoch [12/30], Train Loss: 0.0036, Val Loss: 0.0013
# EarlyStopping counter: 2 out of 50
# Epoch [13/30], Train Loss: 0.0012, Val Loss: 0.0013
# Validation loss decreased (0.001278 --> 0.001265).  Saving model ...
# Epoch [14/30], Train Loss: 0.0026, Val Loss: 0.0065
# EarlyStopping counter: 1 out of 50
# Epoch [15/30], Train Loss: 0.0020, Val Loss: 0.0013
# EarlyStopping counter: 2 out of 50
# Epoch [16/30], Train Loss: 0.0027, Val Loss: 0.0054
# EarlyStopping counter: 3 out of 50
# Epoch [17/30], Train Loss: 0.0017, Val Loss: 0.0027
# EarlyStopping counter: 4 out of 50
# Epoch [18/30], Train Loss: 0.0014, Val Loss: 0.0045
# EarlyStopping counter: 5 out of 50
# Epoch [19/30], Train Loss: 0.0042, Val Loss: 0.0018
# EarlyStopping counter: 6 out of 50
# Epoch 00019: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [20/30], Train Loss: 0.0010, Val Loss: 0.0017
# EarlyStopping counter: 7 out of 50
# Epoch [21/30], Train Loss: 0.0010, Val Loss: 0.0011
# Validation loss decreased (0.001265 --> 0.001149).  Saving model ...
# Epoch [22/30], Train Loss: 0.0010, Val Loss: 0.0014
# EarlyStopping counter: 1 out of 50
# Epoch [23/30], Train Loss: 0.0010, Val Loss: 0.0011
# Validation loss decreased (0.001149 --> 0.001113).  Saving model ...
# Epoch [24/30], Train Loss: 0.0009, Val Loss: 0.0017
# EarlyStopping counter: 1 out of 50
# Epoch [25/30], Train Loss: 0.0010, Val Loss: 0.0011
# Validation loss decreased (0.001113 --> 0.001077).  Saving model ...
# Epoch [26/30], Train Loss: 0.0012, Val Loss: 0.0016
# EarlyStopping counter: 1 out of 50
# Epoch [27/30], Train Loss: 0.0012, Val Loss: 0.0044
# EarlyStopping counter: 2 out of 50
# Epoch [28/30], Train Loss: 0.0013, Val Loss: 0.0034
# EarlyStopping counter: 3 out of 50
# Epoch [29/30], Train Loss: 0.0011, Val Loss: 0.0012
# EarlyStopping counter: 4 out of 50
# Epoch [30/30], Train Loss: 0.0014, Val Loss: 0.0014
# EarlyStopping counter: 5 out of 50
# Folding 3/5
# Epoch [1/30], Train Loss: 0.1098, Val Loss: 0.0147
# Validation loss decreased (inf --> 0.014706).  Saving model ...
# Epoch [2/30], Train Loss: 0.0022, Val Loss: 0.0019
# Validation loss decreased (0.014706 --> 0.001857).  Saving model ...
# Epoch [3/30], Train Loss: 0.0020, Val Loss: 0.0030
# EarlyStopping counter: 1 out of 50
# Epoch [4/30], Train Loss: 0.0014, Val Loss: 0.0022
# EarlyStopping counter: 2 out of 50
# Epoch [5/30], Train Loss: 0.0018, Val Loss: 0.0020
# EarlyStopping counter: 3 out of 50
# Epoch [6/30], Train Loss: 0.0014, Val Loss: 0.0027
# EarlyStopping counter: 4 out of 50
# Epoch [7/30], Train Loss: 0.0013, Val Loss: 0.0019
# EarlyStopping counter: 5 out of 50
# Epoch [8/30], Train Loss: 0.0042, Val Loss: 0.0087
# EarlyStopping counter: 6 out of 50
# Epoch 00008: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [9/30], Train Loss: 0.0015, Val Loss: 0.0039
# EarlyStopping counter: 7 out of 50
# Epoch [10/30], Train Loss: 0.0012, Val Loss: 0.0019
# EarlyStopping counter: 8 out of 50
# Epoch [11/30], Train Loss: 0.0011, Val Loss: 0.0015
# Validation loss decreased (0.001857 --> 0.001503).  Saving model ...
# Epoch [12/30], Train Loss: 0.0012, Val Loss: 0.0040
# EarlyStopping counter: 1 out of 50
# Epoch [13/30], Train Loss: 0.0011, Val Loss: 0.0027
# EarlyStopping counter: 2 out of 50
# Epoch [14/30], Train Loss: 0.0011, Val Loss: 0.0017
# EarlyStopping counter: 3 out of 50
# Epoch [15/30], Train Loss: 0.0014, Val Loss: 0.0014
# Validation loss decreased (0.001503 --> 0.001437).  Saving model ...
# Epoch [16/30], Train Loss: 0.0013, Val Loss: 0.0015
# EarlyStopping counter: 1 out of 50
# Epoch [17/30], Train Loss: 0.0011, Val Loss: 0.0019
# EarlyStopping counter: 2 out of 50
# Epoch [18/30], Train Loss: 0.0012, Val Loss: 0.0030
# EarlyStopping counter: 3 out of 50
# Epoch [19/30], Train Loss: 0.0016, Val Loss: 0.0016
# EarlyStopping counter: 4 out of 50
# Epoch [20/30], Train Loss: 0.0015, Val Loss: 0.0032
# EarlyStopping counter: 5 out of 50
# Epoch [21/30], Train Loss: 0.0018, Val Loss: 0.0016
# EarlyStopping counter: 6 out of 50
# Epoch 00021: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [22/30], Train Loss: 0.0010, Val Loss: 0.0019
# EarlyStopping counter: 7 out of 50
# Epoch [23/30], Train Loss: 0.0011, Val Loss: 0.0015
# EarlyStopping counter: 8 out of 50
# Epoch [24/30], Train Loss: 0.0010, Val Loss: 0.0019
# EarlyStopping counter: 9 out of 50
# Epoch [25/30], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 10 out of 50
# Epoch [26/30], Train Loss: 0.0010, Val Loss: 0.0044
# EarlyStopping counter: 11 out of 50
# Epoch [27/30], Train Loss: 0.0010, Val Loss: 0.0016
# EarlyStopping counter: 12 out of 50
# Epoch 00027: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [28/30], Train Loss: 0.0010, Val Loss: 0.0017
# EarlyStopping counter: 13 out of 50
# Epoch [29/30], Train Loss: 0.0009, Val Loss: 0.0018
# EarlyStopping counter: 14 out of 50
# Epoch [30/30], Train Loss: 0.0010, Val Loss: 0.0016
# EarlyStopping counter: 15 out of 50
# Folding 4/5
# Epoch [1/30], Train Loss: 0.1034, Val Loss: 0.0068
# Validation loss decreased (inf --> 0.006808).  Saving model ...
# Epoch [2/30], Train Loss: 0.0019, Val Loss: 0.0049
# Validation loss decreased (0.006808 --> 0.004919).  Saving model ...
# Epoch [3/30], Train Loss: 0.0047, Val Loss: 0.0056
# EarlyStopping counter: 1 out of 50
# Epoch [4/30], Train Loss: 0.0020, Val Loss: 0.0044
# Validation loss decreased (0.004919 --> 0.004421).  Saving model ...
# Epoch [5/30], Train Loss: 0.0014, Val Loss: 0.0070
# EarlyStopping counter: 1 out of 50
# Epoch [6/30], Train Loss: 0.0037, Val Loss: 0.0017
# Validation loss decreased (0.004421 --> 0.001654).  Saving model ...
# Epoch [7/30], Train Loss: 0.0014, Val Loss: 0.0012
# Validation loss decreased (0.001654 --> 0.001239).  Saving model ...
# Epoch [8/30], Train Loss: 0.0034, Val Loss: 0.0089
# EarlyStopping counter: 1 out of 50
# Epoch [9/30], Train Loss: 0.0028, Val Loss: 0.0015
# EarlyStopping counter: 2 out of 50
# Epoch [10/30], Train Loss: 0.0019, Val Loss: 0.0017
# EarlyStopping counter: 3 out of 50
# Epoch [11/30], Train Loss: 0.0012, Val Loss: 0.0035
# EarlyStopping counter: 4 out of 50
# Epoch [12/30], Train Loss: 0.0033, Val Loss: 0.0024
# EarlyStopping counter: 5 out of 50
# Epoch [13/30], Train Loss: 0.0048, Val Loss: 0.0014
# EarlyStopping counter: 6 out of 50
# Epoch 00013: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [14/30], Train Loss: 0.0011, Val Loss: 0.0023
# EarlyStopping counter: 7 out of 50
# Epoch [15/30], Train Loss: 0.0011, Val Loss: 0.0013
# EarlyStopping counter: 8 out of 50
# Epoch [16/30], Train Loss: 0.0011, Val Loss: 0.0021
# EarlyStopping counter: 9 out of 50
# Epoch [17/30], Train Loss: 0.0012, Val Loss: 0.0012
# Validation loss decreased (0.001239 --> 0.001159).  Saving model ...
# Epoch [18/30], Train Loss: 0.0011, Val Loss: 0.0031
# EarlyStopping counter: 1 out of 50
# Epoch [19/30], Train Loss: 0.0012, Val Loss: 0.0011
# Validation loss decreased (0.001159 --> 0.001124).  Saving model ...
# Epoch [20/30], Train Loss: 0.0012, Val Loss: 0.0010
# Validation loss decreased (0.001124 --> 0.001016).  Saving model ...
# Epoch [21/30], Train Loss: 0.0012, Val Loss: 0.0023
# EarlyStopping counter: 1 out of 50
# Epoch [22/30], Train Loss: 0.0015, Val Loss: 0.0022
# EarlyStopping counter: 2 out of 50
# Epoch [23/30], Train Loss: 0.0012, Val Loss: 0.0028
# EarlyStopping counter: 3 out of 50
# Epoch [24/30], Train Loss: 0.0012, Val Loss: 0.0012
# EarlyStopping counter: 4 out of 50
# Epoch [25/30], Train Loss: 0.0014, Val Loss: 0.0015
# EarlyStopping counter: 5 out of 50
# Epoch [26/30], Train Loss: 0.0010, Val Loss: 0.0018
# EarlyStopping counter: 6 out of 50
# Epoch 00026: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [27/30], Train Loss: 0.0010, Val Loss: 0.0023
# EarlyStopping counter: 7 out of 50
# Epoch [28/30], Train Loss: 0.0010, Val Loss: 0.0015
# EarlyStopping counter: 8 out of 50
# Epoch [29/30], Train Loss: 0.0010, Val Loss: 0.0015
# EarlyStopping counter: 9 out of 50
# Epoch [30/30], Train Loss: 0.0010, Val Loss: 0.0015
# EarlyStopping counter: 10 out of 50
# Folding 5/5
# Epoch [1/30], Train Loss: 0.0777, Val Loss: 0.0062
# Validation loss decreased (inf --> 0.006219).  Saving model ...
# Epoch [2/30], Train Loss: 0.0036, Val Loss: 0.0018
# Validation loss decreased (0.006219 --> 0.001831).  Saving model ...
# Epoch [3/30], Train Loss: 0.0022, Val Loss: 0.0032
# EarlyStopping counter: 1 out of 50
# Epoch [4/30], Train Loss: 0.0032, Val Loss: 0.0014
# Validation loss decreased (0.001831 --> 0.001433).  Saving model ...
# Epoch [5/30], Train Loss: 0.0032, Val Loss: 0.0094
# EarlyStopping counter: 1 out of 50
# Epoch [6/30], Train Loss: 0.0017, Val Loss: 0.0018
# EarlyStopping counter: 2 out of 50
# Epoch [7/30], Train Loss: 0.0023, Val Loss: 0.0022
# EarlyStopping counter: 3 out of 50
# Epoch [8/30], Train Loss: 0.0029, Val Loss: 0.0024
# EarlyStopping counter: 4 out of 50
# Epoch [9/30], Train Loss: 0.0018, Val Loss: 0.0033
# EarlyStopping counter: 5 out of 50
# Epoch [10/30], Train Loss: 0.0020, Val Loss: 0.0149
# EarlyStopping counter: 6 out of 50
# Epoch 00010: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [11/30], Train Loss: 0.0015, Val Loss: 0.0020
# EarlyStopping counter: 7 out of 50
# Epoch [12/30], Train Loss: 0.0012, Val Loss: 0.0040
# EarlyStopping counter: 8 out of 50
# Epoch [13/30], Train Loss: 0.0011, Val Loss: 0.0019
# EarlyStopping counter: 9 out of 50
# Epoch [14/30], Train Loss: 0.0011, Val Loss: 0.0046
# EarlyStopping counter: 10 out of 50
# Epoch [15/30], Train Loss: 0.0011, Val Loss: 0.0012
# Validation loss decreased (0.001433 --> 0.001235).  Saving model ...
# Epoch [16/30], Train Loss: 0.0011, Val Loss: 0.0019
# EarlyStopping counter: 1 out of 50
# Epoch [17/30], Train Loss: 0.0011, Val Loss: 0.0029
# EarlyStopping counter: 2 out of 50
# Epoch [18/30], Train Loss: 0.0011, Val Loss: 0.0013
# EarlyStopping counter: 3 out of 50
# Epoch [19/30], Train Loss: 0.0011, Val Loss: 0.0017
# EarlyStopping counter: 4 out of 50
# Epoch [20/30], Train Loss: 0.0019, Val Loss: 0.0026
# EarlyStopping counter: 5 out of 50
# Epoch [21/30], Train Loss: 0.0018, Val Loss: 0.0014
# EarlyStopping counter: 6 out of 50
# Epoch 00021: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [22/30], Train Loss: 0.0010, Val Loss: 0.0014
# EarlyStopping counter: 7 out of 50
# Epoch [23/30], Train Loss: 0.0010, Val Loss: 0.0014
# EarlyStopping counter: 8 out of 50
# Epoch [24/30], Train Loss: 0.0010, Val Loss: 0.0020
# EarlyStopping counter: 9 out of 50
# Epoch [25/30], Train Loss: 0.0010, Val Loss: 0.0014
# EarlyStopping counter: 10 out of 50
# Epoch [26/30], Train Loss: 0.0010, Val Loss: 0.0027
# EarlyStopping counter: 11 out of 50
# Epoch [27/30], Train Loss: 0.0011, Val Loss: 0.0012
# Validation loss decreased (0.001235 --> 0.001177).  Saving model ...
# Epoch [28/30], Train Loss: 0.0011, Val Loss: 0.0011
# Validation loss decreased (0.001177 --> 0.001130).  Saving model ...
# Epoch [29/30], Train Loss: 0.0010, Val Loss: 0.0012
# EarlyStopping counter: 1 out of 50
# Epoch [30/30], Train Loss: 0.0010, Val Loss: 0.0011
# Validation loss decreased (0.001130 --> 0.001054).  Saving model ...
# Testing L2 penalty: 0.01
# Folding 1/5
# Epoch [1/30], Train Loss: 0.0746, Val Loss: 0.0596
# Validation loss decreased (inf --> 0.059558).  Saving model ...
# Epoch [2/30], Train Loss: 0.0107, Val Loss: 0.0117
# Validation loss decreased (0.059558 --> 0.011743).  Saving model ...
# Epoch [3/30], Train Loss: 0.0036, Val Loss: 0.0056
# Validation loss decreased (0.011743 --> 0.005614).  Saving model ...
# Epoch [4/30], Train Loss: 0.0042, Val Loss: 0.0105
# EarlyStopping counter: 1 out of 50
# Epoch [5/30], Train Loss: 0.0032, Val Loss: 0.0072
# EarlyStopping counter: 2 out of 50
# Epoch [6/30], Train Loss: 0.0028, Val Loss: 0.0060
# EarlyStopping counter: 3 out of 50
# Epoch [7/30], Train Loss: 0.0037, Val Loss: 0.0130
# EarlyStopping counter: 4 out of 50
# Epoch [8/30], Train Loss: 0.0023, Val Loss: 0.0085
# EarlyStopping counter: 5 out of 50
# Epoch [9/30], Train Loss: 0.0022, Val Loss: 0.0073
# EarlyStopping counter: 6 out of 50
# Epoch 00009: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [10/30], Train Loss: 0.0020, Val Loss: 0.0067
# EarlyStopping counter: 7 out of 50
# Epoch [11/30], Train Loss: 0.0020, Val Loss: 0.0081
# EarlyStopping counter: 8 out of 50
# Epoch [12/30], Train Loss: 0.0021, Val Loss: 0.0054
# Validation loss decreased (0.005614 --> 0.005439).  Saving model ...
# Epoch [13/30], Train Loss: 0.0022, Val Loss: 0.0056
# EarlyStopping counter: 1 out of 50
# Epoch [14/30], Train Loss: 0.0021, Val Loss: 0.0077
# EarlyStopping counter: 2 out of 50
# Epoch [15/30], Train Loss: 0.0021, Val Loss: 0.0096
# EarlyStopping counter: 3 out of 50
# Epoch [16/30], Train Loss: 0.0023, Val Loss: 0.0090
# EarlyStopping counter: 4 out of 50
# Epoch [17/30], Train Loss: 0.0021, Val Loss: 0.0116
# EarlyStopping counter: 5 out of 50
# Epoch [18/30], Train Loss: 0.0022, Val Loss: 0.0129
# EarlyStopping counter: 6 out of 50
# Epoch 00018: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [19/30], Train Loss: 0.0023, Val Loss: 0.0071
# EarlyStopping counter: 7 out of 50
# Epoch [20/30], Train Loss: 0.0020, Val Loss: 0.0077
# EarlyStopping counter: 8 out of 50
# Epoch [21/30], Train Loss: 0.0020, Val Loss: 0.0053
# Validation loss decreased (0.005439 --> 0.005256).  Saving model ...
# Epoch [22/30], Train Loss: 0.0020, Val Loss: 0.0093
# EarlyStopping counter: 1 out of 50
# Epoch [23/30], Train Loss: 0.0023, Val Loss: 0.0058
# EarlyStopping counter: 2 out of 50
# Epoch [24/30], Train Loss: 0.0020, Val Loss: 0.0081
# EarlyStopping counter: 3 out of 50
# Epoch [25/30], Train Loss: 0.0022, Val Loss: 0.0048
# Validation loss decreased (0.005256 --> 0.004796).  Saving model ...
# Epoch [26/30], Train Loss: 0.0020, Val Loss: 0.0050
# EarlyStopping counter: 1 out of 50
# Epoch [27/30], Train Loss: 0.0020, Val Loss: 0.0054
# EarlyStopping counter: 2 out of 50
# Epoch [28/30], Train Loss: 0.0020, Val Loss: 0.0085
# EarlyStopping counter: 3 out of 50
# Epoch [29/30], Train Loss: 0.0022, Val Loss: 0.0038
# Validation loss decreased (0.004796 --> 0.003842).  Saving model ...
# Epoch [30/30], Train Loss: 0.0018, Val Loss: 0.0079
# EarlyStopping counter: 1 out of 50
# Folding 2/5
# Epoch [1/30], Train Loss: 0.0763, Val Loss: 0.0179
# Validation loss decreased (inf --> 0.017946).  Saving model ...
# Epoch [2/30], Train Loss: 0.0053, Val Loss: 0.0199
# EarlyStopping counter: 1 out of 50
# Epoch [3/30], Train Loss: 0.0029, Val Loss: 0.0045
# Validation loss decreased (0.017946 --> 0.004482).  Saving model ...
# Epoch [4/30], Train Loss: 0.0050, Val Loss: 0.0109
# EarlyStopping counter: 1 out of 50
# Epoch [5/30], Train Loss: 0.0057, Val Loss: 0.0031
# Validation loss decreased (0.004482 --> 0.003111).  Saving model ...
# Epoch [6/30], Train Loss: 0.0034, Val Loss: 0.0037
# EarlyStopping counter: 1 out of 50
# Epoch [7/30], Train Loss: 0.0029, Val Loss: 0.0074
# EarlyStopping counter: 2 out of 50
# Epoch [8/30], Train Loss: 0.0020, Val Loss: 0.0075
# EarlyStopping counter: 3 out of 50
# Epoch [9/30], Train Loss: 0.0044, Val Loss: 0.0077
# EarlyStopping counter: 4 out of 50
# Epoch [10/30], Train Loss: 0.0021, Val Loss: 0.0058
# EarlyStopping counter: 5 out of 50
# Epoch [11/30], Train Loss: 0.0038, Val Loss: 0.0092
# EarlyStopping counter: 6 out of 50
# Epoch 00011: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [12/30], Train Loss: 0.0021, Val Loss: 0.0074
# EarlyStopping counter: 7 out of 50
# Epoch [13/30], Train Loss: 0.0020, Val Loss: 0.0060
# EarlyStopping counter: 8 out of 50
# Epoch [14/30], Train Loss: 0.0020, Val Loss: 0.0049
# EarlyStopping counter: 9 out of 50
# Epoch [15/30], Train Loss: 0.0019, Val Loss: 0.0083
# EarlyStopping counter: 10 out of 50
# Epoch [16/30], Train Loss: 0.0020, Val Loss: 0.0060
# EarlyStopping counter: 11 out of 50
# Epoch [17/30], Train Loss: 0.0019, Val Loss: 0.0048
# EarlyStopping counter: 12 out of 50
# Epoch 00017: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [18/30], Train Loss: 0.0018, Val Loss: 0.0058
# EarlyStopping counter: 13 out of 50
# Epoch [19/30], Train Loss: 0.0020, Val Loss: 0.0049
# EarlyStopping counter: 14 out of 50
# Epoch [20/30], Train Loss: 0.0018, Val Loss: 0.0054
# EarlyStopping counter: 15 out of 50
# Epoch [21/30], Train Loss: 0.0021, Val Loss: 0.0057
# EarlyStopping counter: 16 out of 50
# Epoch [22/30], Train Loss: 0.0018, Val Loss: 0.0044
# EarlyStopping counter: 17 out of 50
# Epoch [23/30], Train Loss: 0.0019, Val Loss: 0.0067
# EarlyStopping counter: 18 out of 50
# Epoch 00023: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [24/30], Train Loss: 0.0019, Val Loss: 0.0057
# EarlyStopping counter: 19 out of 50
# Epoch [25/30], Train Loss: 0.0019, Val Loss: 0.0050
# EarlyStopping counter: 20 out of 50
# Epoch [26/30], Train Loss: 0.0019, Val Loss: 0.0054
# EarlyStopping counter: 21 out of 50
# Epoch [27/30], Train Loss: 0.0020, Val Loss: 0.0041
# EarlyStopping counter: 22 out of 50
# Epoch [28/30], Train Loss: 0.0017, Val Loss: 0.0059
# EarlyStopping counter: 23 out of 50
# Epoch [29/30], Train Loss: 0.0020, Val Loss: 0.0050
# EarlyStopping counter: 24 out of 50
# Epoch 00029: reducing learning rate of group 0 to 6.2500e-05.
# Epoch [30/30], Train Loss: 0.0018, Val Loss: 0.0051
# EarlyStopping counter: 25 out of 50
# Folding 3/5
# Epoch [1/30], Train Loss: 0.0744, Val Loss: 0.1232
# Validation loss decreased (inf --> 0.123245).  Saving model ...
# Epoch [2/30], Train Loss: 0.0129, Val Loss: 0.0039
# Validation loss decreased (0.123245 --> 0.003904).  Saving model ...
# Epoch [3/30], Train Loss: 0.0023, Val Loss: 0.0086
# EarlyStopping counter: 1 out of 50
# Epoch [4/30], Train Loss: 0.0063, Val Loss: 0.0025
# Validation loss decreased (0.003904 --> 0.002525).  Saving model ...
# Epoch [5/30], Train Loss: 0.0049, Val Loss: 0.0027
# EarlyStopping counter: 1 out of 50
# Epoch [6/30], Train Loss: 0.0026, Val Loss: 0.0060
# EarlyStopping counter: 2 out of 50
# Epoch [7/30], Train Loss: 0.0036, Val Loss: 0.0038
# EarlyStopping counter: 3 out of 50
# Epoch [8/30], Train Loss: 0.0038, Val Loss: 0.0027
# EarlyStopping counter: 4 out of 50
# Epoch [9/30], Train Loss: 0.0032, Val Loss: 0.0027
# EarlyStopping counter: 5 out of 50
# Epoch [10/30], Train Loss: 0.0020, Val Loss: 0.0057
# EarlyStopping counter: 6 out of 50
# Epoch 00010: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [11/30], Train Loss: 0.0022, Val Loss: 0.0033
# EarlyStopping counter: 7 out of 50
# Epoch [12/30], Train Loss: 0.0019, Val Loss: 0.0054
# EarlyStopping counter: 8 out of 50
# Epoch [13/30], Train Loss: 0.0019, Val Loss: 0.0025
# Validation loss decreased (0.002525 --> 0.002478).  Saving model ...
# Epoch [14/30], Train Loss: 0.0019, Val Loss: 0.0038
# EarlyStopping counter: 1 out of 50
# Epoch [15/30], Train Loss: 0.0020, Val Loss: 0.0026
# EarlyStopping counter: 2 out of 50
# Epoch [16/30], Train Loss: 0.0018, Val Loss: 0.0054
# EarlyStopping counter: 3 out of 50
# Epoch [17/30], Train Loss: 0.0021, Val Loss: 0.0027
# EarlyStopping counter: 4 out of 50
# Epoch [18/30], Train Loss: 0.0021, Val Loss: 0.0028
# EarlyStopping counter: 5 out of 50
# Epoch [19/30], Train Loss: 0.0020, Val Loss: 0.0049
# EarlyStopping counter: 6 out of 50
# Epoch 00019: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [20/30], Train Loss: 0.0020, Val Loss: 0.0021
# Validation loss decreased (0.002478 --> 0.002114).  Saving model ...
# Epoch [21/30], Train Loss: 0.0017, Val Loss: 0.0031
# EarlyStopping counter: 1 out of 50
# Epoch [22/30], Train Loss: 0.0019, Val Loss: 0.0038
# EarlyStopping counter: 2 out of 50
# Epoch [23/30], Train Loss: 0.0017, Val Loss: 0.0053
# EarlyStopping counter: 3 out of 50
# Epoch [24/30], Train Loss: 0.0019, Val Loss: 0.0039
# EarlyStopping counter: 4 out of 50
# Epoch [25/30], Train Loss: 0.0020, Val Loss: 0.0021
# EarlyStopping counter: 5 out of 50
# Epoch [26/30], Train Loss: 0.0017, Val Loss: 0.0057
# EarlyStopping counter: 6 out of 50
# Epoch 00026: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [27/30], Train Loss: 0.0020, Val Loss: 0.0034
# EarlyStopping counter: 7 out of 50
# Epoch [28/30], Train Loss: 0.0018, Val Loss: 0.0034
# EarlyStopping counter: 8 out of 50
# Epoch [29/30], Train Loss: 0.0018, Val Loss: 0.0030
# EarlyStopping counter: 9 out of 50
# Epoch [30/30], Train Loss: 0.0018, Val Loss: 0.0035
# EarlyStopping counter: 10 out of 50
# Folding 4/5
# Epoch [1/30], Train Loss: 0.0682, Val Loss: 0.0644
# Validation loss decreased (inf --> 0.064432).  Saving model ...
# Epoch [2/30], Train Loss: 0.0082, Val Loss: 0.0061
# Validation loss decreased (0.064432 --> 0.006088).  Saving model ...
# Epoch [3/30], Train Loss: 0.0037, Val Loss: 0.0025
# Validation loss decreased (0.006088 --> 0.002451).  Saving model ...
# Epoch [4/30], Train Loss: 0.0053, Val Loss: 0.0041
# EarlyStopping counter: 1 out of 50
# Epoch [5/30], Train Loss: 0.0026, Val Loss: 0.0062
# EarlyStopping counter: 2 out of 50
# Epoch [6/30], Train Loss: 0.0042, Val Loss: 0.0146
# EarlyStopping counter: 3 out of 50
# Epoch [7/30], Train Loss: 0.0050, Val Loss: 0.0049
# EarlyStopping counter: 4 out of 50
# Epoch [8/30], Train Loss: 0.0021, Val Loss: 0.0104
# EarlyStopping counter: 5 out of 50
# Epoch [9/30], Train Loss: 0.0031, Val Loss: 0.0041
# EarlyStopping counter: 6 out of 50
# Epoch 00009: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [10/30], Train Loss: 0.0018, Val Loss: 0.0052
# EarlyStopping counter: 7 out of 50
# Epoch [11/30], Train Loss: 0.0018, Val Loss: 0.0025
# EarlyStopping counter: 8 out of 50
# Epoch [12/30], Train Loss: 0.0017, Val Loss: 0.0032
# EarlyStopping counter: 9 out of 50
# Epoch [13/30], Train Loss: 0.0019, Val Loss: 0.0033
# EarlyStopping counter: 10 out of 50
# Epoch [14/30], Train Loss: 0.0020, Val Loss: 0.0036
# EarlyStopping counter: 11 out of 50
# Epoch [15/30], Train Loss: 0.0019, Val Loss: 0.0019
# Validation loss decreased (0.002451 --> 0.001857).  Saving model ...
# Epoch [16/30], Train Loss: 0.0019, Val Loss: 0.0049
# EarlyStopping counter: 1 out of 50
# Epoch [17/30], Train Loss: 0.0020, Val Loss: 0.0023
# EarlyStopping counter: 2 out of 50
# Epoch [18/30], Train Loss: 0.0022, Val Loss: 0.0051
# EarlyStopping counter: 3 out of 50
# Epoch [19/30], Train Loss: 0.0019, Val Loss: 0.0022
# EarlyStopping counter: 4 out of 50
# Epoch [20/30], Train Loss: 0.0019, Val Loss: 0.0037
# EarlyStopping counter: 5 out of 50
# Epoch [21/30], Train Loss: 0.0018, Val Loss: 0.0054
# EarlyStopping counter: 6 out of 50
# Epoch 00021: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [22/30], Train Loss: 0.0019, Val Loss: 0.0043
# EarlyStopping counter: 7 out of 50
# Epoch [23/30], Train Loss: 0.0019, Val Loss: 0.0044
# EarlyStopping counter: 8 out of 50
# Epoch [24/30], Train Loss: 0.0018, Val Loss: 0.0033
# EarlyStopping counter: 9 out of 50
# Epoch [25/30], Train Loss: 0.0019, Val Loss: 0.0034
# EarlyStopping counter: 10 out of 50
# Epoch [26/30], Train Loss: 0.0018, Val Loss: 0.0033
# EarlyStopping counter: 11 out of 50
# Epoch [27/30], Train Loss: 0.0018, Val Loss: 0.0025
# EarlyStopping counter: 12 out of 50
# Epoch 00027: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [28/30], Train Loss: 0.0017, Val Loss: 0.0044
# EarlyStopping counter: 13 out of 50
# Epoch [29/30], Train Loss: 0.0017, Val Loss: 0.0027
# EarlyStopping counter: 14 out of 50
# Epoch [30/30], Train Loss: 0.0017, Val Loss: 0.0038
# EarlyStopping counter: 15 out of 50
# Folding 5/5
# Epoch [1/30], Train Loss: 0.0881, Val Loss: 0.1484
# Validation loss decreased (inf --> 0.148428).  Saving model ...
# Epoch [2/30], Train Loss: 0.0132, Val Loss: 0.0072
# Validation loss decreased (0.148428 --> 0.007248).  Saving model ...
# Epoch [3/30], Train Loss: 0.0045, Val Loss: 0.0137
# EarlyStopping counter: 1 out of 50
# Epoch [4/30], Train Loss: 0.0034, Val Loss: 0.0055
# Validation loss decreased (0.007248 --> 0.005533).  Saving model ...
# Epoch [5/30], Train Loss: 0.0075, Val Loss: 0.0073
# EarlyStopping counter: 1 out of 50
# Epoch [6/30], Train Loss: 0.0025, Val Loss: 0.0028
# Validation loss decreased (0.005533 --> 0.002795).  Saving model ...
# Epoch [7/30], Train Loss: 0.0027, Val Loss: 0.0033
# EarlyStopping counter: 1 out of 50
# Epoch [8/30], Train Loss: 0.0041, Val Loss: 0.0161
# EarlyStopping counter: 2 out of 50
# Epoch [9/30], Train Loss: 0.0032, Val Loss: 0.0242
# EarlyStopping counter: 3 out of 50
# Epoch [10/30], Train Loss: 0.0038, Val Loss: 0.0030
# EarlyStopping counter: 4 out of 50
# Epoch [11/30], Train Loss: 0.0047, Val Loss: 0.0163
# EarlyStopping counter: 5 out of 50
# Epoch [12/30], Train Loss: 0.0029, Val Loss: 0.0045
# EarlyStopping counter: 6 out of 50
# Epoch 00012: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [13/30], Train Loss: 0.0018, Val Loss: 0.0072
# EarlyStopping counter: 7 out of 50
# Epoch [14/30], Train Loss: 0.0018, Val Loss: 0.0068
# EarlyStopping counter: 8 out of 50
# Epoch [15/30], Train Loss: 0.0019, Val Loss: 0.0063
# EarlyStopping counter: 9 out of 50
# Epoch [16/30], Train Loss: 0.0019, Val Loss: 0.0056
# EarlyStopping counter: 10 out of 50
# Epoch [17/30], Train Loss: 0.0019, Val Loss: 0.0059
# EarlyStopping counter: 11 out of 50
# Epoch [18/30], Train Loss: 0.0021, Val Loss: 0.0062
# EarlyStopping counter: 12 out of 50
# Epoch 00018: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [19/30], Train Loss: 0.0018, Val Loss: 0.0063
# EarlyStopping counter: 13 out of 50
# Epoch [20/30], Train Loss: 0.0018, Val Loss: 0.0057
# EarlyStopping counter: 14 out of 50
# Epoch [21/30], Train Loss: 0.0017, Val Loss: 0.0057
# EarlyStopping counter: 15 out of 50
# Epoch [22/30], Train Loss: 0.0018, Val Loss: 0.0068
# EarlyStopping counter: 16 out of 50
# Epoch [23/30], Train Loss: 0.0018, Val Loss: 0.0048
# EarlyStopping counter: 17 out of 50
# Epoch [24/30], Train Loss: 0.0018, Val Loss: 0.0089
# EarlyStopping counter: 18 out of 50
# Epoch 00024: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [25/30], Train Loss: 0.0020, Val Loss: 0.0054
# EarlyStopping counter: 19 out of 50
# Epoch [26/30], Train Loss: 0.0017, Val Loss: 0.0051
# EarlyStopping counter: 20 out of 50
# Epoch [27/30], Train Loss: 0.0017, Val Loss: 0.0052
# EarlyStopping counter: 21 out of 50
# Epoch [28/30], Train Loss: 0.0018, Val Loss: 0.0057
# EarlyStopping counter: 22 out of 50
# Epoch [29/30], Train Loss: 0.0019, Val Loss: 0.0044
# EarlyStopping counter: 23 out of 50
# Epoch [30/30], Train Loss: 0.0018, Val Loss: 0.0053
# EarlyStopping counter: 24 out of 50
# Epoch 00030: reducing learning rate of group 0 to 6.2500e-05.
# Testing L2 penalty: 0.1
# Folding 1/5
# Epoch [1/30], Train Loss: 0.0831, Val Loss: 0.1585
# Validation loss decreased (inf --> 0.158465).  Saving model ...
# Epoch [2/30], Train Loss: 0.0747, Val Loss: 0.1627
# EarlyStopping counter: 1 out of 50
# Epoch [3/30], Train Loss: 0.0742, Val Loss: 0.1707
# EarlyStopping counter: 2 out of 50
# Epoch [4/30], Train Loss: 0.0744, Val Loss: 0.1643
# EarlyStopping counter: 3 out of 50
# Epoch [5/30], Train Loss: 0.0736, Val Loss: 0.1677
# EarlyStopping counter: 4 out of 50
# Epoch [6/30], Train Loss: 0.0744, Val Loss: 0.1666
# EarlyStopping counter: 5 out of 50
# Epoch [7/30], Train Loss: 0.0750, Val Loss: 0.1628
# EarlyStopping counter: 6 out of 50
# Epoch 00007: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [8/30], Train Loss: 0.0736, Val Loss: 0.1657
# EarlyStopping counter: 7 out of 50
# Epoch [9/30], Train Loss: 0.0751, Val Loss: 0.1597
# EarlyStopping counter: 8 out of 50
# Epoch [10/30], Train Loss: 0.0739, Val Loss: 0.1687
# EarlyStopping counter: 9 out of 50
# Epoch [11/30], Train Loss: 0.0755, Val Loss: 0.1635
# EarlyStopping counter: 10 out of 50
# Epoch [12/30], Train Loss: 0.0739, Val Loss: 0.1642
# EarlyStopping counter: 11 out of 50
# Epoch [13/30], Train Loss: 0.0741, Val Loss: 0.1657
# EarlyStopping counter: 12 out of 50
# Epoch 00013: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [14/30], Train Loss: 0.0754, Val Loss: 0.1642
# EarlyStopping counter: 13 out of 50
# Epoch [15/30], Train Loss: 0.0748, Val Loss: 0.1637
# EarlyStopping counter: 14 out of 50
# Epoch [16/30], Train Loss: 0.0733, Val Loss: 0.1663
# EarlyStopping counter: 15 out of 50
# Epoch [17/30], Train Loss: 0.0744, Val Loss: 0.1659
# EarlyStopping counter: 16 out of 50
# Epoch [18/30], Train Loss: 0.0757, Val Loss: 0.1633
# EarlyStopping counter: 17 out of 50
# Epoch [19/30], Train Loss: 0.0752, Val Loss: 0.1633
# EarlyStopping counter: 18 out of 50
# Epoch 00019: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [20/30], Train Loss: 0.0747, Val Loss: 0.1631
# EarlyStopping counter: 19 out of 50
# Epoch [21/30], Train Loss: 0.0736, Val Loss: 0.1636
# EarlyStopping counter: 20 out of 50
# Epoch [22/30], Train Loss: 0.0747, Val Loss: 0.1639
# EarlyStopping counter: 21 out of 50
# Epoch [23/30], Train Loss: 0.0736, Val Loss: 0.1641
# EarlyStopping counter: 22 out of 50
# Epoch [24/30], Train Loss: 0.0737, Val Loss: 0.1642
# EarlyStopping counter: 23 out of 50
# Epoch [25/30], Train Loss: 0.0738, Val Loss: 0.1639
# EarlyStopping counter: 24 out of 50
# Epoch 00025: reducing learning rate of group 0 to 6.2500e-05.
# Epoch [26/30], Train Loss: 0.0736, Val Loss: 0.1639
# EarlyStopping counter: 25 out of 50
# Epoch [27/30], Train Loss: 0.0737, Val Loss: 0.1640
# EarlyStopping counter: 26 out of 50
# Epoch [28/30], Train Loss: 0.0738, Val Loss: 0.1641
# EarlyStopping counter: 27 out of 50
# Epoch [29/30], Train Loss: 0.0748, Val Loss: 0.1633
# EarlyStopping counter: 28 out of 50
# Epoch [30/30], Train Loss: 0.0736, Val Loss: 0.1635
# EarlyStopping counter: 29 out of 50
# Folding 2/5
# Epoch [1/30], Train Loss: 0.0901, Val Loss: 0.1144
# Validation loss decreased (inf --> 0.114418).  Saving model ...
# Epoch [2/30], Train Loss: 0.0803, Val Loss: 0.1071
# ...
# Epoch [23/30], Train Loss: 0.0692, Val Loss: 0.1687
# EarlyStopping counter: 21 out of 50
# Epoch [24/30], Train Loss: 0.0701, Val Loss: 0.1687
# EarlyStopping counter: 22 out of 50
# Epoch [25/30], Train Loss: 0.0693, Val Loss: 0.1686
# EarlyStopping counter: 23 out of 50
# Epoch [26/30], Train Loss: 0.0709, Val Loss: 0.1679
# EarlyStopping counter: 24 out of 50
# Epoch 00026: reducing learning rate of group 0 to 6.2500e-05.
# Epoch [27/30], Train Loss: 0.0698, Val Loss: 0.1681
# EarlyStopping counter: 25 out of 50
# Epoch [28/30], Train Loss: 0.0700, Val Loss: 0.1683
# EarlyStopping counter: 26 out of 50
# Epoch [29/30], Train Loss: 0.0701, Val Loss: 0.1684
# EarlyStopping counter: 27 out of 50
# Epoch [30/30], Train Loss: 0.0704, Val Loss: 0.1682
# EarlyStopping counter: 28 out of 50
# Testing L2 penalty: 1.0
# Folding 1/5
# Epoch [1/30], Train Loss: 0.0818, Val Loss: 0.1876
# Validation loss decreased (inf --> 0.187605).  Saving model ...
# Epoch [2/30], Train Loss: 0.0799, Val Loss: 0.1816
# Validation loss decreased (0.187605 --> 0.181609).  Saving model ...
# Epoch [3/30], Train Loss: 0.0811, Val Loss: 0.1758
# Validation loss decreased (0.181609 --> 0.175764).  Saving model ...
# Epoch [4/30], Train Loss: 0.0798, Val Loss: 0.1771
# EarlyStopping counter: 1 out of 50
# Epoch [5/30], Train Loss: 0.0788, Val Loss: 0.1864
# EarlyStopping counter: 2 out of 50
# Epoch [6/30], Train Loss: 0.0788, Val Loss: 0.1891
# EarlyStopping counter: 3 out of 50
# Epoch [7/30], Train Loss: 0.0789, Val Loss: 0.1891
# EarlyStopping counter: 4 out of 50
# Epoch [8/30], Train Loss: 0.0810, Val Loss: 0.1813
# EarlyStopping counter: 5 out of 50
# Epoch [9/30], Train Loss: 0.0779, Val Loss: 0.1872
# EarlyStopping counter: 6 out of 50
# Epoch 00009: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [10/30], Train Loss: 0.0781, Val Loss: 0.1866
# EarlyStopping counter: 7 out of 50
# Epoch [11/30], Train Loss: 0.0795, Val Loss: 0.1836
# EarlyStopping counter: 8 out of 50
# Epoch [12/30], Train Loss: 0.0799, Val Loss: 0.1861
# EarlyStopping counter: 9 out of 50
# Epoch [13/30], Train Loss: 0.0786, Val Loss: 0.1872
# EarlyStopping counter: 10 out of 50
# Epoch [14/30], Train Loss: 0.0805, Val Loss: 0.1848
# EarlyStopping counter: 11 out of 50
# Epoch [15/30], Train Loss: 0.0785, Val Loss: 0.1875
# EarlyStopping counter: 12 out of 50
# Epoch 00015: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [16/30], Train Loss: 0.0795, Val Loss: 0.1866
# EarlyStopping counter: 13 out of 50
# Epoch [17/30], Train Loss: 0.0793, Val Loss: 0.1863
# EarlyStopping counter: 14 out of 50
# Epoch [18/30], Train Loss: 0.0794, Val Loss: 0.1874
# EarlyStopping counter: 15 out of 50
# Epoch [19/30], Train Loss: 0.0786, Val Loss: 0.1880
# EarlyStopping counter: 16 out of 50
# Epoch [20/30], Train Loss: 0.0792, Val Loss: 0.1885
# EarlyStopping counter: 17 out of 50
# Epoch [21/30], Train Loss: 0.0803, Val Loss: 0.1881
# EarlyStopping counter: 18 out of 50
# Epoch 00021: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [22/30], Train Loss: 0.0797, Val Loss: 0.1883
# EarlyStopping counter: 19 out of 50
# Epoch [23/30], Train Loss: 0.0795, Val Loss: 0.1879
# EarlyStopping counter: 20 out of 50
# Epoch [24/30], Train Loss: 0.0789, Val Loss: 0.1886
# EarlyStopping counter: 21 out of 50
# Epoch [25/30], Train Loss: 0.0791, Val Loss: 0.1886
# EarlyStopping counter: 22 out of 50
# Epoch [26/30], Train Loss: 0.0795, Val Loss: 0.1885
# EarlyStopping counter: 23 out of 50
# Epoch [27/30], Train Loss: 0.0804, Val Loss: 0.1885
# EarlyStopping counter: 24 out of 50
# Epoch 00027: reducing learning rate of group 0 to 6.2500e-05.
# Epoch [28/30], Train Loss: 0.0798, Val Loss: 0.1884
# EarlyStopping counter: 25 out of 50
# Epoch [29/30], Train Loss: 0.0823, Val Loss: 0.1881
# EarlyStopping counter: 26 out of 50
# Epoch [30/30], Train Loss: 0.0795, Val Loss: 0.1883
# EarlyStopping counter: 27 out of 50
# Folding 2/5
# Epoch [1/30], Train Loss: 0.1009, Val Loss: 0.1978
# Validation loss decreased (inf --> 0.197782).  Saving model ...
# Epoch [2/30], Train Loss: 0.0852, Val Loss: 0.1928
# Validation loss decreased (0.197782 --> 0.192806).  Saving model ...
# Epoch [3/30], Train Loss: 0.0848, Val Loss: 0.1888
# Validation loss decreased (0.192806 --> 0.188825).  Saving model ...
# Epoch [4/30], Train Loss: 0.0837, Val Loss: 0.1916
# EarlyStopping counter: 1 out of 50
# Epoch [5/30], Train Loss: 0.0816, Val Loss: 0.1949
# EarlyStopping counter: 2 out of 50
# Epoch [6/30], Train Loss: 0.0849, Val Loss: 0.1884
# Validation loss decreased (0.188825 --> 0.188379).  Saving model ...
# Epoch [7/30], Train Loss: 0.0819, Val Loss: 0.1879
# Validation loss decreased (0.188379 --> 0.187918).  Saving model ...
# Epoch [8/30], Train Loss: 0.0821, Val Loss: 0.1826
# Validation loss decreased (0.187918 --> 0.182584).  Saving model ...
# Epoch [9/30], Train Loss: 0.0801, Val Loss: 0.1801
# Validation loss decreased (0.182584 --> 0.180070).  Saving model ...
# Epoch [10/30], Train Loss: 0.0781, Val Loss: 0.1854
# EarlyStopping counter: 1 out of 50
# Epoch [11/30], Train Loss: 0.0792, Val Loss: 0.1827
# EarlyStopping counter: 2 out of 50
# Epoch [12/30], Train Loss: 0.0794, Val Loss: 0.1830
# EarlyStopping counter: 3 out of 50
# Epoch [13/30], Train Loss: 0.0809, Val Loss: 0.1816
# EarlyStopping counter: 4 out of 50
# Epoch [14/30], Train Loss: 0.0798, Val Loss: 0.1851
# EarlyStopping counter: 5 out of 50
# Epoch [15/30], Train Loss: 0.0809, Val Loss: 0.1862
# EarlyStopping counter: 6 out of 50
# Epoch 00015: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [16/30], Train Loss: 0.0816, Val Loss: 0.1856
# EarlyStopping counter: 7 out of 50
# Epoch [17/30], Train Loss: 0.0828, Val Loss: 0.1847
# EarlyStopping counter: 8 out of 50
# Epoch [18/30], Train Loss: 0.0802, Val Loss: 0.1874
# EarlyStopping counter: 9 out of 50
# Epoch [19/30], Train Loss: 0.0808, Val Loss: 0.1878
# EarlyStopping counter: 10 out of 50
# Epoch [20/30], Train Loss: 0.0826, Val Loss: 0.1864
# EarlyStopping counter: 11 out of 50
# Epoch [21/30], Train Loss: 0.0815, Val Loss: 0.1868
# EarlyStopping counter: 12 out of 50
# Epoch 00021: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [22/30], Train Loss: 0.0796, Val Loss: 0.1888
# EarlyStopping counter: 13 out of 50
# Epoch [23/30], Train Loss: 0.0812, Val Loss: 0.1888
# EarlyStopping counter: 14 out of 50
# Epoch [24/30], Train Loss: 0.0819, Val Loss: 0.1887
# EarlyStopping counter: 15 out of 50
# Epoch [25/30], Train Loss: 0.0807, Val Loss: 0.1886
# EarlyStopping counter: 16 out of 50
# Epoch [26/30], Train Loss: 0.0809, Val Loss: 0.1891
# EarlyStopping counter: 17 out of 50
# Epoch [27/30], Train Loss: 0.0820, Val Loss: 0.1886
# EarlyStopping counter: 18 out of 50
# Epoch 00027: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [28/30], Train Loss: 0.0814, Val Loss: 0.1888
# EarlyStopping counter: 19 out of 50
# Epoch [29/30], Train Loss: 0.0798, Val Loss: 0.1895
# EarlyStopping counter: 20 out of 50
# Epoch [30/30], Train Loss: 0.0830, Val Loss: 0.1891
# EarlyStopping counter: 21 out of 50
# Folding 3/5
# Epoch [1/30], Train Loss: 0.1003, Val Loss: 0.1865
# Validation loss decreased (inf --> 0.186527).  Saving model ...
# Epoch [2/30], Train Loss: 0.0834, Val Loss: 0.1770
# Validation loss decreased (0.186527 --> 0.176985).  Saving model ...
# Epoch [3/30], Train Loss: 0.0814, Val Loss: 0.1744
# Validation loss decreased (0.176985 --> 0.174447).  Saving model ...
# Epoch [4/30], Train Loss: 0.0808, Val Loss: 0.1764
# EarlyStopping counter: 1 out of 50
# Epoch [5/30], Train Loss: 0.0819, Val Loss: 0.1682
# Validation loss decreased (0.174447 --> 0.168232).  Saving model ...
# Epoch [6/30], Train Loss: 0.0804, Val Loss: 0.1733
# EarlyStopping counter: 1 out of 50
# Epoch [7/30], Train Loss: 0.0816, Val Loss: 0.1694
# EarlyStopping counter: 2 out of 50
# Epoch [8/30], Train Loss: 0.0798, Val Loss: 0.1700
# EarlyStopping counter: 3 out of 50
# Epoch [9/30], Train Loss: 0.0810, Val Loss: 0.1679
# Validation loss decreased (0.168232 --> 0.167886).  Saving model ...
# Epoch [10/30], Train Loss: 0.0807, Val Loss: 0.1709
# EarlyStopping counter: 1 out of 50
# Epoch [11/30], Train Loss: 0.0821, Val Loss: 0.1658
# Validation loss decreased (0.167886 --> 0.165838).  Saving model ...
# Epoch [12/30], Train Loss: 0.0792, Val Loss: 0.1750
# EarlyStopping counter: 1 out of 50
# Epoch [13/30], Train Loss: 0.0813, Val Loss: 0.1713
# EarlyStopping counter: 2 out of 50
# Epoch [14/30], Train Loss: 0.0813, Val Loss: 0.1700
# EarlyStopping counter: 3 out of 50
# Epoch [15/30], Train Loss: 0.0818, Val Loss: 0.1727
# EarlyStopping counter: 4 out of 50
# Epoch [16/30], Train Loss: 0.0805, Val Loss: 0.1747
# EarlyStopping counter: 5 out of 50
# Epoch [17/30], Train Loss: 0.0824, Val Loss: 0.1750
# EarlyStopping counter: 6 out of 50
# Epoch 00017: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [18/30], Train Loss: 0.0843, Val Loss: 0.1718
# EarlyStopping counter: 7 out of 50
# Epoch [19/30], Train Loss: 0.0798, Val Loss: 0.1760
# EarlyStopping counter: 8 out of 50
# Epoch [20/30], Train Loss: 0.0814, Val Loss: 0.1769
# EarlyStopping counter: 9 out of 50
# Epoch [21/30], Train Loss: 0.0843, Val Loss: 0.1760
# EarlyStopping counter: 10 out of 50
# Epoch [22/30], Train Loss: 0.0830, Val Loss: 0.1747
# EarlyStopping counter: 11 out of 50
# Epoch [23/30], Train Loss: 0.0818, Val Loss: 0.1758
# EarlyStopping counter: 12 out of 50
# Epoch 00023: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [24/30], Train Loss: 0.0857, Val Loss: 0.1755
# EarlyStopping counter: 13 out of 50
# Epoch [25/30], Train Loss: 0.0804, Val Loss: 0.1779
# EarlyStopping counter: 14 out of 50
# Epoch [26/30], Train Loss: 0.0863, Val Loss: 0.1756
# EarlyStopping counter: 15 out of 50
# Epoch [27/30], Train Loss: 0.0831, Val Loss: 0.1768
# EarlyStopping counter: 16 out of 50
# Epoch [28/30], Train Loss: 0.0835, Val Loss: 0.1767
# EarlyStopping counter: 17 out of 50
# Epoch [29/30], Train Loss: 0.0819, Val Loss: 0.1777
# EarlyStopping counter: 18 out of 50
# Epoch 00029: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [30/30], Train Loss: 0.0830, Val Loss: 0.1777
# EarlyStopping counter: 19 out of 50
# Folding 4/5
# Epoch [1/30], Train Loss: 0.0893, Val Loss: 0.1940
# Validation loss decreased (inf --> 0.194042).  Saving model ...
# Epoch [2/30], Train Loss: 0.0810, Val Loss: 0.1895
# Validation loss decreased (0.194042 --> 0.189465).  Saving model ...
# Epoch [3/30], Train Loss: 0.0783, Val Loss: 0.1890
# Validation loss decreased (0.189465 --> 0.189009).  Saving model ...
# Epoch [4/30], Train Loss: 0.0786, Val Loss: 0.1798
# Validation loss decreased (0.189009 --> 0.179817).  Saving model ...
# Epoch [5/30], Train Loss: 0.0777, Val Loss: 0.1830
# EarlyStopping counter: 1 out of 50
# Epoch [6/30], Train Loss: 0.0804, Val Loss: 0.1727
# Validation loss decreased (0.179817 --> 0.172744).  Saving model ...
# Epoch [7/30], Train Loss: 0.0780, Val Loss: 0.1787
# EarlyStopping counter: 1 out of 50
# Epoch [8/30], Train Loss: 0.0801, Val Loss: 0.1731
# EarlyStopping counter: 2 out of 50
# Epoch [9/30], Train Loss: 0.0815, Val Loss: 0.1668
# Validation loss decreased (0.172744 --> 0.166751).  Saving model ...
# Epoch [10/30], Train Loss: 0.0736, Val Loss: 0.1852
# EarlyStopping counter: 1 out of 50
# Epoch [11/30], Train Loss: 0.0801, Val Loss: 0.1740
# EarlyStopping counter: 2 out of 50
# Epoch [12/30], Train Loss: 0.0778, Val Loss: 0.1782
# EarlyStopping counter: 3 out of 50
# Epoch [13/30], Train Loss: 0.0776, Val Loss: 0.1802
# EarlyStopping counter: 4 out of 50
# Epoch [14/30], Train Loss: 0.0775, Val Loss: 0.1815
# EarlyStopping counter: 5 out of 50
# Epoch [15/30], Train Loss: 0.0787, Val Loss: 0.1770
# EarlyStopping counter: 6 out of 50
# Epoch 00015: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [16/30], Train Loss: 0.0779, Val Loss: 0.1798
# EarlyStopping counter: 7 out of 50
# Epoch [17/30], Train Loss: 0.0785, Val Loss: 0.1808
# EarlyStopping counter: 8 out of 50
# Epoch [18/30], Train Loss: 0.0783, Val Loss: 0.1810
# EarlyStopping counter: 9 out of 50
# Epoch [19/30], Train Loss: 0.0780, Val Loss: 0.1832
# EarlyStopping counter: 10 out of 50
# Epoch [20/30], Train Loss: 0.0788, Val Loss: 0.1825
# EarlyStopping counter: 11 out of 50
# Epoch [21/30], Train Loss: 0.0806, Val Loss: 0.1813
# EarlyStopping counter: 12 out of 50
# Epoch 00021: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [22/30], Train Loss: 0.0774, Val Loss: 0.1832
# EarlyStopping counter: 13 out of 50
# Epoch [23/30], Train Loss: 0.0806, Val Loss: 0.1822
# EarlyStopping counter: 14 out of 50
# Epoch [24/30], Train Loss: 0.0808, Val Loss: 0.1829
# EarlyStopping counter: 15 out of 50
# Epoch [25/30], Train Loss: 0.0808, Val Loss: 0.1830
# EarlyStopping counter: 16 out of 50
# Epoch [26/30], Train Loss: 0.0787, Val Loss: 0.1843
# EarlyStopping counter: 17 out of 50
# Epoch [27/30], Train Loss: 0.0787, Val Loss: 0.1849
# EarlyStopping counter: 18 out of 50
# Epoch 00027: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [28/30], Train Loss: 0.0793, Val Loss: 0.1844
# EarlyStopping counter: 19 out of 50
# Epoch [29/30], Train Loss: 0.0807, Val Loss: 0.1841
# EarlyStopping counter: 20 out of 50
# Epoch [30/30], Train Loss: 0.0782, Val Loss: 0.1848
# EarlyStopping counter: 21 out of 50
# Folding 5/5
# Epoch [1/30], Train Loss: 0.1082, Val Loss: 0.2012
# Validation loss decreased (inf --> 0.201222).  Saving model ...
# Epoch [2/30], Train Loss: 0.0868, Val Loss: 0.1935
# Validation loss decreased (0.201222 --> 0.193525).  Saving model ...
# Epoch [3/30], Train Loss: 0.0848, Val Loss: 0.1789
# Validation loss decreased (0.193525 --> 0.178917).  Saving model ...
# Epoch [4/30], Train Loss: 0.0817, Val Loss: 0.1781
# Validation loss decreased (0.178917 --> 0.178093).  Saving model ...
# Epoch [5/30], Train Loss: 0.0815, Val Loss: 0.1747
# Validation loss decreased (0.178093 --> 0.174687).  Saving model ...
# Epoch [6/30], Train Loss: 0.0801, Val Loss: 0.1782
# EarlyStopping counter: 1 out of 50
# Epoch [7/30], Train Loss: 0.0797, Val Loss: 0.1818
# EarlyStopping counter: 2 out of 50
# Epoch [8/30], Train Loss: 0.0816, Val Loss: 0.1801
# EarlyStopping counter: 3 out of 50
# Epoch [9/30], Train Loss: 0.0823, Val Loss: 0.1808
# EarlyStopping counter: 4 out of 50
# Epoch [10/30], Train Loss: 0.0794, Val Loss: 0.1883
# EarlyStopping counter: 5 out of 50
# Epoch [11/30], Train Loss: 0.0817, Val Loss: 0.1882
# EarlyStopping counter: 6 out of 50
# Epoch 00011: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [12/30], Train Loss: 0.0818, Val Loss: 0.1862
# EarlyStopping counter: 7 out of 50
# Epoch [13/30], Train Loss: 0.0831, Val Loss: 0.1833
# EarlyStopping counter: 8 out of 50
# Epoch [14/30], Train Loss: 0.0822, Val Loss: 0.1847
# EarlyStopping counter: 9 out of 50
# Epoch [15/30], Train Loss: 0.0808, Val Loss: 0.1865
# EarlyStopping counter: 10 out of 50
# Epoch [16/30], Train Loss: 0.0813, Val Loss: 0.1880
# EarlyStopping counter: 11 out of 50
# Epoch [17/30], Train Loss: 0.0857, Val Loss: 0.1842
# EarlyStopping counter: 12 out of 50
# Epoch 00017: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [18/30], Train Loss: 0.0822, Val Loss: 0.1852
# EarlyStopping counter: 13 out of 50
# Epoch [19/30], Train Loss: 0.0812, Val Loss: 0.1863
# EarlyStopping counter: 14 out of 50
# Epoch [20/30], Train Loss: 0.0838, Val Loss: 0.1858
# EarlyStopping counter: 15 out of 50
# Epoch [21/30], Train Loss: 0.0860, Val Loss: 0.1852
# EarlyStopping counter: 16 out of 50
# Epoch [22/30], Train Loss: 0.0832, Val Loss: 0.1864
# EarlyStopping counter: 17 out of 50
# Epoch [23/30], Train Loss: 0.0821, Val Loss: 0.1881
# EarlyStopping counter: 18 out of 50
# Epoch 00023: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [24/30], Train Loss: 0.0853, Val Loss: 0.1872
# EarlyStopping counter: 19 out of 50
# Epoch [25/30], Train Loss: 0.0843, Val Loss: 0.1870
# EarlyStopping counter: 20 out of 50
# Epoch [26/30], Train Loss: 0.0816, Val Loss: 0.1876
# EarlyStopping counter: 21 out of 50
# Epoch [27/30], Train Loss: 0.0851, Val Loss: 0.1870
# EarlyStopping counter: 22 out of 50
# Epoch [28/30], Train Loss: 0.0833, Val Loss: 0.1872
# EarlyStopping counter: 23 out of 50
# Epoch [29/30], Train Loss: 0.0821, Val Loss: 0.1880
# EarlyStopping counter: 24 out of 50
# Epoch 00029: reducing learning rate of group 0 to 6.2500e-05.
# Epoch [30/30], Train Loss: 0.0842, Val Loss: 0.1878
# EarlyStopping counter: 25 out of 50
# Best L2 penalty for Apple: 0.0001
# Best L2 penalty for Google: 0.0001
# Best L2 penalty for Tesla: 0.0001

# %%
# Train and save the model for Apple
model_apple = StockPredictor(input_size, hidden_layer_size, num_layers, output_size)
model_apple, train_losses_apple, val_losses_apple = train_and_validate(
    model_apple, train_loader_apple, val_loader_apple, num_epochs=1000, weight_decay=best_penalty_apple)
torch.save(model_apple.state_dict(), '/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/model_apple.pth')

# Train and save the model for Google
model_google = StockPredictor(input_size, hidden_layer_size, num_layers, output_size)
model_google, train_losses_google, val_losses_google = train_and_validate(
    model_google, train_loader_google, val_loader_google, num_epochs=1000, weight_decay=best_penalty_google)
torch.save(model_google.state_dict(), '/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/model_google.pth')

# Train and save the model for Tesla
model_tesla = StockPredictor(input_size, hidden_layer_size, num_layers, output_size)
model_tesla, train_losses_tesla, val_losses_tesla = train_and_validate(
    model_tesla, train_loader_tesla, val_loader_tesla, num_epochs=1000, weight_decay=best_penalty_tesla)
torch.save(model_tesla.state_dict(), '/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/model_tesla.pth')

# Saving training and validation losses
with h5py.File('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/training_losses.h5', 'w') as f:
    f.create_dataset('train_losses_apple', data=np.array(train_losses_apple))
    f.create_dataset('val_losses_apple', data=np.array(val_losses_apple))
    f.create_dataset('train_losses_google', data=np.array(train_losses_google))
    f.create_dataset('val_losses_google', data=np.array(val_losses_google))
    f.create_dataset('train_losses_tesla', data=np.array(train_losses_tesla))
    f.create_dataset('val_losses_tesla', data=np.array(val_losses_tesla))
# Out:
# Epoch [1/1000], Train Loss: 0.9598, Val Loss: 0.0049
# Validation loss decreased (inf --> 0.004852).  Saving model ...
# Epoch [2/1000], Train Loss: 0.0034, Val Loss: 0.0056
# EarlyStopping counter: 1 out of 50
# Epoch [3/1000], Train Loss: 0.0019, Val Loss: 0.0029
# Validation loss decreased (0.004852 --> 0.002884).  Saving model ...
# Epoch [4/1000], Train Loss: 0.0016, Val Loss: 0.0027
# Validation loss decreased (0.002884 --> 0.002710).  Saving model ...
# Epoch [5/1000], Train Loss: 0.0030, Val Loss: 0.0035
# EarlyStopping counter: 1 out of 50
# Epoch [6/1000], Train Loss: 0.0018, Val Loss: 0.0035
# EarlyStopping counter: 2 out of 50
# Epoch [7/1000], Train Loss: 0.0023, Val Loss: 0.0108
# EarlyStopping counter: 3 out of 50
# Epoch [8/1000], Train Loss: 0.0043, Val Loss: 0.0032
# EarlyStopping counter: 4 out of 50
# Epoch [9/1000], Train Loss: 0.0017, Val Loss: 0.0051
# EarlyStopping counter: 5 out of 50
# Epoch [10/1000], Train Loss: 0.0020, Val Loss: 0.0028
# EarlyStopping counter: 6 out of 50
# Epoch 00010: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [11/1000], Train Loss: 0.0012, Val Loss: 0.0025
# Validation loss decreased (0.002710 --> 0.002463).  Saving model ...
# Epoch [12/1000], Train Loss: 0.0011, Val Loss: 0.0035
# EarlyStopping counter: 1 out of 50
# Epoch [13/1000], Train Loss: 0.0011, Val Loss: 0.0025
# EarlyStopping counter: 2 out of 50
# Epoch [14/1000], Train Loss: 0.0012, Val Loss: 0.0028
# EarlyStopping counter: 3 out of 50
# Epoch [15/1000], Train Loss: 0.0011, Val Loss: 0.0029
# EarlyStopping counter: 4 out of 50
# Epoch [16/1000], Train Loss: 0.0011, Val Loss: 0.0026
# EarlyStopping counter: 5 out of 50
# Epoch [17/1000], Train Loss: 0.0012, Val Loss: 0.0029
# EarlyStopping counter: 6 out of 50
# Epoch 00017: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [18/1000], Train Loss: 0.0011, Val Loss: 0.0029
# EarlyStopping counter: 7 out of 50
# Epoch [19/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 8 out of 50
# Epoch [20/1000], Train Loss: 0.0011, Val Loss: 0.0037
# EarlyStopping counter: 9 out of 50
# Epoch [21/1000], Train Loss: 0.0010, Val Loss: 0.0025
# EarlyStopping counter: 10 out of 50
# Epoch [22/1000], Train Loss: 0.0010, Val Loss: 0.0027
# EarlyStopping counter: 11 out of 50
# Epoch [23/1000], Train Loss: 0.0011, Val Loss: 0.0026
# EarlyStopping counter: 12 out of 50
# Epoch 00023: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [24/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 13 out of 50
# Epoch [25/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 14 out of 50
# Epoch [26/1000], Train Loss: 0.0010, Val Loss: 0.0029
# EarlyStopping counter: 15 out of 50
# Epoch [27/1000], Train Loss: 0.0011, Val Loss: 0.0029
# EarlyStopping counter: 16 out of 50
# Epoch [28/1000], Train Loss: 0.0011, Val Loss: 0.0026
# EarlyStopping counter: 17 out of 50
# Epoch [29/1000], Train Loss: 0.0010, Val Loss: 0.0037
# EarlyStopping counter: 18 out of 50
# Epoch 00029: reducing learning rate of group 0 to 6.2500e-05.
# Epoch [30/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 19 out of 50
# Epoch [31/1000], Train Loss: 0.0010, Val Loss: 0.0028
# EarlyStopping counter: 20 out of 50
# Epoch [32/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 21 out of 50
# Epoch [33/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 22 out of 50
# Epoch [34/1000], Train Loss: 0.0010, Val Loss: 0.0028
# EarlyStopping counter: 23 out of 50
# Epoch [35/1000], Train Loss: 0.0009, Val Loss: 0.0030
# EarlyStopping counter: 24 out of 50
# Epoch 00035: reducing learning rate of group 0 to 3.1250e-05.
# Epoch [36/1000], Train Loss: 0.0010, Val Loss: 0.0029
# EarlyStopping counter: 25 out of 50
# Epoch [37/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 26 out of 50
# Epoch [38/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 27 out of 50
# Epoch [39/1000], Train Loss: 0.0010, Val Loss: 0.0029
# EarlyStopping counter: 28 out of 50
# Epoch [40/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 29 out of 50
# Epoch [41/1000], Train Loss: 0.0010, Val Loss: 0.0029
# EarlyStopping counter: 30 out of 50
# Epoch 00041: reducing learning rate of group 0 to 1.5625e-05.
# Epoch [42/1000], Train Loss: 0.0010, Val Loss: 0.0028
# EarlyStopping counter: 31 out of 50
# Epoch [43/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 32 out of 50
# Epoch [44/1000], Train Loss: 0.0009, Val Loss: 0.0027
# EarlyStopping counter: 33 out of 50
# Epoch [45/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 34 out of 50
# Epoch [46/1000], Train Loss: 0.0010, Val Loss: 0.0028
# EarlyStopping counter: 35 out of 50
# Epoch [47/1000], Train Loss: 0.0010, Val Loss: 0.0029
# EarlyStopping counter: 36 out of 50
# Epoch 00047: reducing learning rate of group 0 to 1.0000e-05.
# Epoch [48/1000], Train Loss: 0.0009, Val Loss: 0.0028
# EarlyStopping counter: 37 out of 50
# Epoch [49/1000], Train Loss: 0.0010, Val Loss: 0.0028
# EarlyStopping counter: 38 out of 50
# Epoch [50/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 39 out of 50
# Epoch [51/1000], Train Loss: 0.0010, Val Loss: 0.0027
# EarlyStopping counter: 40 out of 50
# Epoch [52/1000], Train Loss: 0.0010, Val Loss: 0.0028
# EarlyStopping counter: 41 out of 50
# Epoch [53/1000], Train Loss: 0.0010, Val Loss: 0.0029
# EarlyStopping counter: 42 out of 50
# Epoch [54/1000], Train Loss: 0.0009, Val Loss: 0.0027
# EarlyStopping counter: 43 out of 50
# Epoch [55/1000], Train Loss: 0.0010, Val Loss: 0.0027
# EarlyStopping counter: 44 out of 50
# Epoch [56/1000], Train Loss: 0.0010, Val Loss: 0.0027
# EarlyStopping counter: 45 out of 50
# Epoch [57/1000], Train Loss: 0.0009, Val Loss: 0.0029
# EarlyStopping counter: 46 out of 50
# Epoch [58/1000], Train Loss: 0.0010, Val Loss: 0.0026
# EarlyStopping counter: 47 out of 50
# Epoch [59/1000], Train Loss: 0.0010, Val Loss: 0.0027
# EarlyStopping counter: 48 out of 50
# Epoch [60/1000], Train Loss: 0.0010, Val Loss: 0.0028
# EarlyStopping counter: 49 out of 50
# Epoch [61/1000], Train Loss: 0.0010, Val Loss: 0.0031
# EarlyStopping counter: 50 out of 50
# Early Stop
# Epoch [1/1000], Train Loss: 0.7962, Val Loss: 0.0052
# Validation loss decreased (inf --> 0.005189).  Saving model ...
# Epoch [2/1000], Train Loss: 0.0024, Val Loss: 0.0041
# Validation loss decreased (0.005189 --> 0.004145).  Saving model ...
# Epoch [3/1000], Train Loss: 0.0017, Val Loss: 0.0044
# EarlyStopping counter: 1 out of 50
# Epoch [4/1000], Train Loss: 0.0029, Val Loss: 0.0062
# EarlyStopping counter: 2 out of 50
# Epoch [5/1000], Train Loss: 0.0027, Val Loss: 0.0054
# EarlyStopping counter: 3 out of 50
# Epoch [6/1000], Train Loss: 0.0026, Val Loss: 0.0053
# EarlyStopping counter: 4 out of 50
# Epoch [7/1000], Train Loss: 0.0023, Val Loss: 0.0065
# EarlyStopping counter: 5 out of 50
# Epoch [8/1000], Train Loss: 0.0021, Val Loss: 0.0132
# EarlyStopping counter: 6 out of 50
# Epoch 00008: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [9/1000], Train Loss: 0.0014, Val Loss: 0.0048
# EarlyStopping counter: 7 out of 50
# Epoch [10/1000], Train Loss: 0.0012, Val Loss: 0.0054
# EarlyStopping counter: 8 out of 50
# Epoch [11/1000], Train Loss: 0.0012, Val Loss: 0.0049
# EarlyStopping counter: 9 out of 50
# Epoch [12/1000], Train Loss: 0.0011, Val Loss: 0.0041
# Validation loss decreased (0.004145 --> 0.004086).  Saving model ...
# Epoch [13/1000], Train Loss: 0.0011, Val Loss: 0.0044
# EarlyStopping counter: 1 out of 50
# Epoch [14/1000], Train Loss: 0.0013, Val Loss: 0.0050
# EarlyStopping counter: 2 out of 50
# Epoch [15/1000], Train Loss: 0.0012, Val Loss: 0.0049
# EarlyStopping counter: 3 out of 50
# Epoch [16/1000], Train Loss: 0.0017, Val Loss: 0.0055
# EarlyStopping counter: 4 out of 50
# Epoch [17/1000], Train Loss: 0.0015, Val Loss: 0.0047
# EarlyStopping counter: 5 out of 50
# Epoch [18/1000], Train Loss: 0.0013, Val Loss: 0.0082
# EarlyStopping counter: 6 out of 50
# Epoch 00018: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [19/1000], Train Loss: 0.0011, Val Loss: 0.0039
# Validation loss decreased (0.004086 --> 0.003932).  Saving model ...
# Epoch [20/1000], Train Loss: 0.0011, Val Loss: 0.0053
# EarlyStopping counter: 1 out of 50
# Epoch [21/1000], Train Loss: 0.0010, Val Loss: 0.0059
# EarlyStopping counter: 2 out of 50
# Epoch [22/1000], Train Loss: 0.0011, Val Loss: 0.0040
# EarlyStopping counter: 3 out of 50
# Epoch [23/1000], Train Loss: 0.0011, Val Loss: 0.0037
# Validation loss decreased (0.003932 --> 0.003698).  Saving model ...
# Epoch [24/1000], Train Loss: 0.0011, Val Loss: 0.0037
# Validation loss decreased (0.003698 --> 0.003659).  Saving model ...
# Epoch [25/1000], Train Loss: 0.0012, Val Loss: 0.0048
# EarlyStopping counter: 1 out of 50
# Epoch [26/1000], Train Loss: 0.0011, Val Loss: 0.0042
# EarlyStopping counter: 2 out of 50
# Epoch [27/1000], Train Loss: 0.0011, Val Loss: 0.0045
# EarlyStopping counter: 3 out of 50
# Epoch [28/1000], Train Loss: 0.0016, Val Loss: 0.0046
# EarlyStopping counter: 4 out of 50
# Epoch [29/1000], Train Loss: 0.0013, Val Loss: 0.0039
# EarlyStopping counter: 5 out of 50
# Epoch [30/1000], Train Loss: 0.0012, Val Loss: 0.0056
# EarlyStopping counter: 6 out of 50
# Epoch 00030: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [31/1000], Train Loss: 0.0010, Val Loss: 0.0050
# EarlyStopping counter: 7 out of 50
# Epoch [32/1000], Train Loss: 0.0010, Val Loss: 0.0052
# EarlyStopping counter: 8 out of 50
# Epoch [33/1000], Train Loss: 0.0010, Val Loss: 0.0048
# EarlyStopping counter: 9 out of 50
# Epoch [34/1000], Train Loss: 0.0010, Val Loss: 0.0059
# EarlyStopping counter: 10 out of 50
# Epoch [35/1000], Train Loss: 0.0010, Val Loss: 0.0057
# EarlyStopping counter: 11 out of 50
# Epoch [36/1000], Train Loss: 0.0010, Val Loss: 0.0043
# EarlyStopping counter: 12 out of 50
# Epoch 00036: reducing learning rate of group 0 to 6.2500e-05.
# Epoch [37/1000], Train Loss: 0.0010, Val Loss: 0.0051
# EarlyStopping counter: 13 out of 50
# Epoch [38/1000], Train Loss: 0.0010, Val Loss: 0.0039
# EarlyStopping counter: 14 out of 50
# Epoch [39/1000], Train Loss: 0.0010, Val Loss: 0.0041
# EarlyStopping counter: 15 out of 50
# Epoch [40/1000], Train Loss: 0.0010, Val Loss: 0.0046
# EarlyStopping counter: 16 out of 50
# Epoch [41/1000], Train Loss: 0.0010, Val Loss: 0.0047
# EarlyStopping counter: 17 out of 50
# Epoch [42/1000], Train Loss: 0.0010, Val Loss: 0.0044
# EarlyStopping counter: 18 out of 50
# Epoch 00042: reducing learning rate of group 0 to 3.1250e-05.
# Epoch [43/1000], Train Loss: 0.0009, Val Loss: 0.0041
# EarlyStopping counter: 19 out of 50
# Epoch [44/1000], Train Loss: 0.0010, Val Loss: 0.0040
# EarlyStopping counter: 20 out of 50
# Epoch [45/1000], Train Loss: 0.0009, Val Loss: 0.0049
# EarlyStopping counter: 21 out of 50
# Epoch [46/1000], Train Loss: 0.0010, Val Loss: 0.0043
# EarlyStopping counter: 22 out of 50
# Epoch [47/1000], Train Loss: 0.0010, Val Loss: 0.0046
# EarlyStopping counter: 23 out of 50
# Epoch [48/1000], Train Loss: 0.0010, Val Loss: 0.0044
# EarlyStopping counter: 24 out of 50
# Epoch 00048: reducing learning rate of group 0 to 1.5625e-05.
# Epoch [49/1000], Train Loss: 0.0010, Val Loss: 0.0046
# EarlyStopping counter: 25 out of 50
# Epoch [50/1000], Train Loss: 0.0010, Val Loss: 0.0041
# EarlyStopping counter: 26 out of 50
# Epoch [51/1000], Train Loss: 0.0010, Val Loss: 0.0047
# EarlyStopping counter: 27 out of 50
# Epoch [52/1000], Train Loss: 0.0009, Val Loss: 0.0050
# EarlyStopping counter: 28 out of 50
# Epoch [53/1000], Train Loss: 0.0010, Val Loss: 0.0045
# EarlyStopping counter: 29 out of 50
# Epoch [54/1000], Train Loss: 0.0009, Val Loss: 0.0047
# EarlyStopping counter: 30 out of 50
# Epoch 00054: reducing learning rate of group 0 to 1.0000e-05.
# Epoch [55/1000], Train Loss: 0.0010, Val Loss: 0.0045
# EarlyStopping counter: 31 out of 50
# Epoch [56/1000], Train Loss: 0.0010, Val Loss: 0.0043
# EarlyStopping counter: 32 out of 50
# Epoch [57/1000], Train Loss: 0.0009, Val Loss: 0.0047
# EarlyStopping counter: 33 out of 50
# Epoch [58/1000], Train Loss: 0.0009, Val Loss: 0.0046
# EarlyStopping counter: 34 out of 50
# Epoch [59/1000], Train Loss: 0.0010, Val Loss: 0.0041
# EarlyStopping counter: 35 out of 50
# Epoch [60/1000], Train Loss: 0.0009, Val Loss: 0.0041
# EarlyStopping counter: 36 out of 50
# Epoch [61/1000], Train Loss: 0.0010, Val Loss: 0.0045
# EarlyStopping counter: 37 out of 50
# Epoch [62/1000], Train Loss: 0.0010, Val Loss: 0.0043
# EarlyStopping counter: 38 out of 50
# Epoch [63/1000], Train Loss: 0.0010, Val Loss: 0.0044
# EarlyStopping counter: 39 out of 50
# Epoch [64/1000], Train Loss: 0.0010, Val Loss: 0.0049
# EarlyStopping counter: 40 out of 50
# Epoch [65/1000], Train Loss: 0.0009, Val Loss: 0.0043
# EarlyStopping counter: 41 out of 50
# Epoch [66/1000], Train Loss: 0.0009, Val Loss: 0.0043
# EarlyStopping counter: 42 out of 50
# Epoch [67/1000], Train Loss: 0.0010, Val Loss: 0.0045
# EarlyStopping counter: 43 out of 50
# Epoch [68/1000], Train Loss: 0.0009, Val Loss: 0.0044
# EarlyStopping counter: 44 out of 50
# Epoch [69/1000], Train Loss: 0.0009, Val Loss: 0.0046
# EarlyStopping counter: 45 out of 50
# Epoch [70/1000], Train Loss: 0.0010, Val Loss: 0.0045
# EarlyStopping counter: 46 out of 50
# Epoch [71/1000], Train Loss: 0.0009, Val Loss: 0.0040
# EarlyStopping counter: 47 out of 50
# Epoch [72/1000], Train Loss: 0.0010, Val Loss: 0.0047
# EarlyStopping counter: 48 out of 50
# Epoch [73/1000], Train Loss: 0.0010, Val Loss: 0.0050
# EarlyStopping counter: 49 out of 50
# Epoch [74/1000], Train Loss: 0.0009, Val Loss: 0.0050
# EarlyStopping counter: 50 out of 50
# Early Stop
# Epoch [1/1000], Train Loss: 1.3175, Val Loss: 0.0055
# Validation loss decreased (inf --> 0.005502).  Saving model ...
# Epoch [2/1000], Train Loss: 0.0017, Val Loss: 0.0063
# EarlyStopping counter: 1 out of 50
# Epoch [3/1000], Train Loss: 0.0017, Val Loss: 0.0075
# EarlyStopping counter: 2 out of 50
# Epoch [4/1000], Train Loss: 0.0016, Val Loss: 0.0054
# Validation loss decreased (0.005502 --> 0.005420).  Saving model ...
# Epoch [5/1000], Train Loss: 0.0016, Val Loss: 0.0049
# Validation loss decreased (0.005420 --> 0.004891).  Saving model ...
# Epoch [6/1000], Train Loss: 0.0017, Val Loss: 0.0112
# EarlyStopping counter: 1 out of 50
# Epoch [7/1000], Train Loss: 0.0018, Val Loss: 0.0063
# EarlyStopping counter: 2 out of 50
# Epoch [8/1000], Train Loss: 0.0016, Val Loss: 0.0053
# EarlyStopping counter: 3 out of 50
# Epoch [9/1000], Train Loss: 0.0018, Val Loss: 0.0058
# EarlyStopping counter: 4 out of 50
# Epoch [10/1000], Train Loss: 0.0030, Val Loss: 0.0051
# EarlyStopping counter: 5 out of 50
# Epoch [11/1000], Train Loss: 0.0016, Val Loss: 0.0052
# EarlyStopping counter: 6 out of 50
# Epoch 00011: reducing learning rate of group 0 to 5.0000e-04.
# Epoch [12/1000], Train Loss: 0.0015, Val Loss: 0.0051
# EarlyStopping counter: 7 out of 50
# Epoch [13/1000], Train Loss: 0.0014, Val Loss: 0.0070
# EarlyStopping counter: 8 out of 50
# Epoch [14/1000], Train Loss: 0.0014, Val Loss: 0.0044
# Validation loss decreased (0.004891 --> 0.004446).  Saving model ...
# Epoch [15/1000], Train Loss: 0.0014, Val Loss: 0.0042
# Validation loss decreased (0.004446 --> 0.004235).  Saving model ...
# Epoch [16/1000], Train Loss: 0.0014, Val Loss: 0.0052
# EarlyStopping counter: 1 out of 50
# Epoch [17/1000], Train Loss: 0.0014, Val Loss: 0.0068
# EarlyStopping counter: 2 out of 50
# Epoch [18/1000], Train Loss: 0.0014, Val Loss: 0.0042
# Validation loss decreased (0.004235 --> 0.004210).  Saving model ...
# Epoch [19/1000], Train Loss: 0.0013, Val Loss: 0.0043
# EarlyStopping counter: 1 out of 50
# Epoch [20/1000], Train Loss: 0.0013, Val Loss: 0.0083
# EarlyStopping counter: 2 out of 50
# Epoch [21/1000], Train Loss: 0.0017, Val Loss: 0.0049
# EarlyStopping counter: 3 out of 50
# Epoch [22/1000], Train Loss: 0.0022, Val Loss: 0.0049
# EarlyStopping counter: 4 out of 50
# Epoch [23/1000], Train Loss: 0.0017, Val Loss: 0.0041
# Validation loss decreased (0.004210 --> 0.004065).  Saving model ...
# Epoch [24/1000], Train Loss: 0.0013, Val Loss: 0.0067
# EarlyStopping counter: 1 out of 50
# Epoch [25/1000], Train Loss: 0.0026, Val Loss: 0.0064
# EarlyStopping counter: 2 out of 50
# Epoch [26/1000], Train Loss: 0.0021, Val Loss: 0.0070
# EarlyStopping counter: 3 out of 50
# Epoch [27/1000], Train Loss: 0.0016, Val Loss: 0.0053
# EarlyStopping counter: 4 out of 50
# Epoch [28/1000], Train Loss: 0.0043, Val Loss: 0.0071
# EarlyStopping counter: 5 out of 50
# Epoch [29/1000], Train Loss: 0.0015, Val Loss: 0.0042
# EarlyStopping counter: 6 out of 50
# Epoch 00029: reducing learning rate of group 0 to 2.5000e-04.
# Epoch [30/1000], Train Loss: 0.0012, Val Loss: 0.0049
# EarlyStopping counter: 7 out of 50
# Epoch [31/1000], Train Loss: 0.0012, Val Loss: 0.0058
# EarlyStopping counter: 8 out of 50
# Epoch [32/1000], Train Loss: 0.0012, Val Loss: 0.0042
# EarlyStopping counter: 9 out of 50
# Epoch [33/1000], Train Loss: 0.0012, Val Loss: 0.0050
# EarlyStopping counter: 10 out of 50
# Epoch [34/1000], Train Loss: 0.0012, Val Loss: 0.0049
# EarlyStopping counter: 11 out of 50
# Epoch [35/1000], Train Loss: 0.0012, Val Loss: 0.0040
# Validation loss decreased (0.004065 --> 0.003993).  Saving model ...
# Epoch [36/1000], Train Loss: 0.0011, Val Loss: 0.0039
# Validation loss decreased (0.003993 --> 0.003851).  Saving model ...
# Epoch [37/1000], Train Loss: 0.0012, Val Loss: 0.0085
# EarlyStopping counter: 1 out of 50
# Epoch [38/1000], Train Loss: 0.0013, Val Loss: 0.0043
# EarlyStopping counter: 2 out of 50
# Epoch [39/1000], Train Loss: 0.0013, Val Loss: 0.0040
# EarlyStopping counter: 3 out of 50
# Epoch [40/1000], Train Loss: 0.0019, Val Loss: 0.0045
# EarlyStopping counter: 4 out of 50
# Epoch [41/1000], Train Loss: 0.0015, Val Loss: 0.0043
# EarlyStopping counter: 5 out of 50
# Epoch [42/1000], Train Loss: 0.0015, Val Loss: 0.0079
# EarlyStopping counter: 6 out of 50
# Epoch 00042: reducing learning rate of group 0 to 1.2500e-04.
# Epoch [43/1000], Train Loss: 0.0011, Val Loss: 0.0038
# Validation loss decreased (0.003851 --> 0.003765).  Saving model ...
# Epoch [44/1000], Train Loss: 0.0012, Val Loss: 0.0041
# EarlyStopping counter: 1 out of 50
# Epoch [45/1000], Train Loss: 0.0011, Val Loss: 0.0043
# EarlyStopping counter: 2 out of 50
# Epoch [46/1000], Train Loss: 0.0011, Val Loss: 0.0042
# EarlyStopping counter: 3 out of 50
# Epoch [47/1000], Train Loss: 0.0011, Val Loss: 0.0038
# EarlyStopping counter: 4 out of 50
# Epoch [48/1000], Train Loss: 0.0011, Val Loss: 0.0043
# EarlyStopping counter: 5 out of 50
# Epoch [49/1000], Train Loss: 0.0011, Val Loss: 0.0060
# EarlyStopping counter: 6 out of 50
# Epoch 00049: reducing learning rate of group 0 to 6.2500e-05.
# Epoch [50/1000], Train Loss: 0.0011, Val Loss: 0.0038
# EarlyStopping counter: 7 out of 50
# Epoch [51/1000], Train Loss: 0.0011, Val Loss: 0.0047
# EarlyStopping counter: 8 out of 50
# Epoch [52/1000], Train Loss: 0.0011, Val Loss: 0.0042
# EarlyStopping counter: 9 out of 50
# Epoch [53/1000], Train Loss: 0.0011, Val Loss: 0.0037
# Validation loss decreased (0.003765 --> 0.003672).  Saving model ...
# Epoch [54/1000], Train Loss: 0.0011, Val Loss: 0.0044
# EarlyStopping counter: 1 out of 50
# Epoch [55/1000], Train Loss: 0.0011, Val Loss: 0.0036
# Validation loss decreased (0.003672 --> 0.003639).  Saving model ...
# Epoch [56/1000], Train Loss: 0.0011, Val Loss: 0.0046
# EarlyStopping counter: 1 out of 50
# Epoch [57/1000], Train Loss: 0.0011, Val Loss: 0.0042
# EarlyStopping counter: 2 out of 50
# Epoch [58/1000], Train Loss: 0.0011, Val Loss: 0.0044
# EarlyStopping counter: 3 out of 50
# Epoch [59/1000], Train Loss: 0.0011, Val Loss: 0.0040
# EarlyStopping counter: 4 out of 50
# Epoch [60/1000], Train Loss: 0.0011, Val Loss: 0.0040
# EarlyStopping counter: 5 out of 50
# Epoch [61/1000], Train Loss: 0.0011, Val Loss: 0.0043
# EarlyStopping counter: 6 out of 50
# Epoch 00061: reducing learning rate of group 0 to 3.1250e-05.
# Epoch [62/1000], Train Loss: 0.0010, Val Loss: 0.0049
# EarlyStopping counter: 7 out of 50
# Epoch [63/1000], Train Loss: 0.0011, Val Loss: 0.0038
# EarlyStopping counter: 8 out of 50
# Epoch [64/1000], Train Loss: 0.0010, Val Loss: 0.0040
# EarlyStopping counter: 9 out of 50
# Epoch [65/1000], Train Loss: 0.0011, Val Loss: 0.0040
# EarlyStopping counter: 10 out of 50
# Epoch [66/1000], Train Loss: 0.0011, Val Loss: 0.0039
# EarlyStopping counter: 11 out of 50
# Epoch [67/1000], Train Loss: 0.0011, Val Loss: 0.0047
# EarlyStopping counter: 12 out of 50
# Epoch 00067: reducing learning rate of group 0 to 1.5625e-05.
# Epoch [68/1000], Train Loss: 0.0010, Val Loss: 0.0039
# EarlyStopping counter: 13 out of 50
# Epoch [69/1000], Train Loss: 0.0011, Val Loss: 0.0041
# EarlyStopping counter: 14 out of 50
# Epoch [70/1000], Train Loss: 0.0010, Val Loss: 0.0041
# EarlyStopping counter: 15 out of 50
# Epoch [71/1000], Train Loss: 0.0011, Val Loss: 0.0037
# EarlyStopping counter: 16 out of 50
# Epoch [72/1000], Train Loss: 0.0010, Val Loss: 0.0045
# EarlyStopping counter: 17 out of 50
# Epoch [73/1000], Train Loss: 0.0011, Val Loss: 0.0040
# EarlyStopping counter: 18 out of 50
# Epoch 00073: reducing learning rate of group 0 to 1.0000e-05.
# Epoch [74/1000], Train Loss: 0.0010, Val Loss: 0.0039
# EarlyStopping counter: 19 out of 50
# Epoch [75/1000], Train Loss: 0.0010, Val Loss: 0.0037
# EarlyStopping counter: 20 out of 50
# Epoch [76/1000], Train Loss: 0.0010, Val Loss: 0.0040
# EarlyStopping counter: 21 out of 50
# Epoch [77/1000], Train Loss: 0.0011, Val Loss: 0.0040
# EarlyStopping counter: 22 out of 50
# Epoch [78/1000], Train Loss: 0.0010, Val Loss: 0.0038
# EarlyStopping counter: 23 out of 50
# Epoch [79/1000], Train Loss: 0.0010, Val Loss: 0.0039
# EarlyStopping counter: 24 out of 50
# Epoch [80/1000], Train Loss: 0.0010, Val Loss: 0.0041
# EarlyStopping counter: 25 out of 50
# Epoch [81/1000], Train Loss: 0.0010, Val Loss: 0.0038
# EarlyStopping counter: 26 out of 50
# Epoch [82/1000], Train Loss: 0.0010, Val Loss: 0.0042
# EarlyStopping counter: 27 out of 50
# Epoch [83/1000], Train Loss: 0.0010, Val Loss: 0.0038
# EarlyStopping counter: 28 out of 50
# Epoch [84/1000], Train Loss: 0.0010, Val Loss: 0.0038
# EarlyStopping counter: 29 out of 50
# Epoch [85/1000], Train Loss: 0.0010, Val Loss: 0.0040
# EarlyStopping counter: 30 out of 50
# Epoch [86/1000], Train Loss: 0.0010, Val Loss: 0.0039
# EarlyStopping counter: 31 out of 50
# Epoch [87/1000], Train Loss: 0.0011, Val Loss: 0.0040
# EarlyStopping counter: 32 out of 50
# Epoch [88/1000], Train Loss: 0.0010, Val Loss: 0.0043
# EarlyStopping counter: 33 out of 50
# Epoch [89/1000], Train Loss: 0.0010, Val Loss: 0.0041
# EarlyStopping counter: 34 out of 50
# Epoch [90/1000], Train Loss: 0.0010, Val Loss: 0.0040
# EarlyStopping counter: 35 out of 50
# Epoch [91/1000], Train Loss: 0.0010, Val Loss: 0.0043
# EarlyStopping counter: 36 out of 50
# Epoch [92/1000], Train Loss: 0.0010, Val Loss: 0.0038
# EarlyStopping counter: 37 out of 50
# Epoch [93/1000], Train Loss: 0.0010, Val Loss: 0.0035
# Validation loss decreased (0.003639 --> 0.003532).  Saving model ...
# Epoch [94/1000], Train Loss: 0.0010, Val Loss: 0.0038
# EarlyStopping counter: 1 out of 50
# Epoch [95/1000], Train Loss: 0.0010, Val Loss: 0.0035
# Validation loss decreased (0.003532 --> 0.003493).  Saving model ...
# Epoch [96/1000], Train Loss: 0.0010, Val Loss: 0.0042
# EarlyStopping counter: 1 out of 50
# Epoch [97/1000], Train Loss: 0.0010, Val Loss: 0.0037
# EarlyStopping counter: 2 out of 50
# Epoch [98/1000], Train Loss: 0.0011, Val Loss: 0.0041
# EarlyStopping counter: 3 out of 50
# Epoch [99/1000], Train Loss: 0.0010, Val Loss: 0.0039
# EarlyStopping counter: 4 out of 50
# Epoch [100/1000], Train Loss: 0.0010, Val Loss: 0.0042
# EarlyStopping counter: 5 out of 50
# Epoch [101/1000], Train Loss: 0.0010, Val Loss: 0.0035
# EarlyStopping counter: 6 out of 50
# Epoch [102/1000], Train Loss: 0.0009, Val Loss: 0.0038
# EarlyStopping counter: 7 out of 50
# Epoch [103/1000], Train Loss: 0.0009, Val Loss: 0.0041
# EarlyStopping counter: 8 out of 50
# Epoch [104/1000], Train Loss: 0.0010, Val Loss: 0.0039
# EarlyStopping counter: 9 out of 50
# Epoch [105/1000], Train Loss: 0.0009, Val Loss: 0.0038
# EarlyStopping counter: 10 out of 50
# Epoch [106/1000], Train Loss: 0.0010, Val Loss: 0.0038
# EarlyStopping counter: 11 out of 50
# Epoch [107/1000], Train Loss: 0.0010, Val Loss: 0.0035
# EarlyStopping counter: 12 out of 50
# Epoch [108/1000], Train Loss: 0.0009, Val Loss: 0.0040
# EarlyStopping counter: 13 out of 50
# Epoch [109/1000], Train Loss: 0.0009, Val Loss: 0.0038
# EarlyStopping counter: 14 out of 50
# Epoch [110/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 15 out of 50
# Epoch [111/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 16 out of 50
# Epoch [112/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 17 out of 50
# Epoch [113/1000], Train Loss: 0.0010, Val Loss: 0.0042
# EarlyStopping counter: 18 out of 50
# Epoch [114/1000], Train Loss: 0.0010, Val Loss: 0.0035
# EarlyStopping counter: 19 out of 50
# Epoch [115/1000], Train Loss: 0.0010, Val Loss: 0.0034
# Validation loss decreased (0.003493 --> 0.003386).  Saving model ...
# Epoch [116/1000], Train Loss: 0.0010, Val Loss: 0.0041
# EarlyStopping counter: 1 out of 50
# Epoch [117/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 2 out of 50
# Epoch [118/1000], Train Loss: 0.0009, Val Loss: 0.0038
# EarlyStopping counter: 3 out of 50
# Epoch [119/1000], Train Loss: 0.0010, Val Loss: 0.0038
# EarlyStopping counter: 4 out of 50
# Epoch [120/1000], Train Loss: 0.0010, Val Loss: 0.0038
# EarlyStopping counter: 5 out of 50
# Epoch [121/1000], Train Loss: 0.0010, Val Loss: 0.0040
# EarlyStopping counter: 6 out of 50
# Epoch [122/1000], Train Loss: 0.0009, Val Loss: 0.0033
# Validation loss decreased (0.003386 --> 0.003340).  Saving model ...
# Epoch [123/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 1 out of 50
# Epoch [124/1000], Train Loss: 0.0009, Val Loss: 0.0039
# EarlyStopping counter: 2 out of 50
# Epoch [125/1000], Train Loss: 0.0010, Val Loss: 0.0036
# EarlyStopping counter: 3 out of 50
# Epoch [126/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 4 out of 50
# Epoch [127/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 5 out of 50
# Epoch [128/1000], Train Loss: 0.0010, Val Loss: 0.0034
# EarlyStopping counter: 6 out of 50
# Epoch [129/1000], Train Loss: 0.0009, Val Loss: 0.0039
# EarlyStopping counter: 7 out of 50
# Epoch [130/1000], Train Loss: 0.0009, Val Loss: 0.0041
# EarlyStopping counter: 8 out of 50
# Epoch [131/1000], Train Loss: 0.0010, Val Loss: 0.0036
# EarlyStopping counter: 9 out of 50
# Epoch [132/1000], Train Loss: 0.0009, Val Loss: 0.0042
# EarlyStopping counter: 10 out of 50
# Epoch [133/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 11 out of 50
# Epoch [134/1000], Train Loss: 0.0010, Val Loss: 0.0034
# EarlyStopping counter: 12 out of 50
# Epoch [135/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 13 out of 50
# Epoch [136/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 14 out of 50
# Epoch [137/1000], Train Loss: 0.0010, Val Loss: 0.0038
# EarlyStopping counter: 15 out of 50
# Epoch [138/1000], Train Loss: 0.0009, Val Loss: 0.0033
# Validation loss decreased (0.003340 --> 0.003260).  Saving model ...
# Epoch [139/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 1 out of 50
# Epoch [140/1000], Train Loss: 0.0009, Val Loss: 0.0041
# EarlyStopping counter: 2 out of 50
# Epoch [141/1000], Train Loss: 0.0010, Val Loss: 0.0043
# EarlyStopping counter: 3 out of 50
# Epoch [142/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 4 out of 50
# Epoch [143/1000], Train Loss: 0.0010, Val Loss: 0.0037
# EarlyStopping counter: 5 out of 50
# Epoch [144/1000], Train Loss: 0.0010, Val Loss: 0.0036
# EarlyStopping counter: 6 out of 50
# Epoch [145/1000], Train Loss: 0.0010, Val Loss: 0.0036
# EarlyStopping counter: 7 out of 50
# Epoch [146/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 8 out of 50
# Epoch [147/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 9 out of 50
# Epoch [148/1000], Train Loss: 0.0009, Val Loss: 0.0039
# EarlyStopping counter: 10 out of 50
# Epoch [149/1000], Train Loss: 0.0010, Val Loss: 0.0033
# EarlyStopping counter: 11 out of 50
# Epoch [150/1000], Train Loss: 0.0009, Val Loss: 0.0041
# EarlyStopping counter: 12 out of 50
# Epoch [151/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 13 out of 50
# Epoch [152/1000], Train Loss: 0.0010, Val Loss: 0.0035
# EarlyStopping counter: 14 out of 50
# Epoch [153/1000], Train Loss: 0.0010, Val Loss: 0.0040
# EarlyStopping counter: 15 out of 50
# Epoch [154/1000], Train Loss: 0.0009, Val Loss: 0.0047
# EarlyStopping counter: 16 out of 50
# Epoch [155/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 17 out of 50
# Epoch [156/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 18 out of 50
# Epoch [157/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 19 out of 50
# Epoch [158/1000], Train Loss: 0.0010, Val Loss: 0.0036
# EarlyStopping counter: 20 out of 50
# Epoch [159/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 21 out of 50
# Epoch [160/1000], Train Loss: 0.0010, Val Loss: 0.0036
# EarlyStopping counter: 22 out of 50
# Epoch [161/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 23 out of 50
# Epoch [162/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 24 out of 50
# Epoch [163/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 25 out of 50
# Epoch [164/1000], Train Loss: 0.0010, Val Loss: 0.0036
# EarlyStopping counter: 26 out of 50
# Epoch [165/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 27 out of 50
# Epoch [166/1000], Train Loss: 0.0010, Val Loss: 0.0042
# EarlyStopping counter: 28 out of 50
# Epoch [167/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 29 out of 50
# Epoch [168/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 30 out of 50
# Epoch [169/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 31 out of 50
# Epoch [170/1000], Train Loss: 0.0009, Val Loss: 0.0033
# Validation loss decreased (0.003260 --> 0.003258).  Saving model ...
# Epoch [171/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 1 out of 50
# Epoch [172/1000], Train Loss: 0.0009, Val Loss: 0.0044
# EarlyStopping counter: 2 out of 50
# Epoch [173/1000], Train Loss: 0.0010, Val Loss: 0.0032
# Validation loss decreased (0.003258 --> 0.003200).  Saving model ...
# Epoch [174/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 1 out of 50
# Epoch [175/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 2 out of 50
# Epoch [176/1000], Train Loss: 0.0008, Val Loss: 0.0035
# EarlyStopping counter: 3 out of 50
# Epoch [177/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 4 out of 50
# Epoch [178/1000], Train Loss: 0.0010, Val Loss: 0.0042
# EarlyStopping counter: 5 out of 50
# Epoch [179/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 6 out of 50
# Epoch [180/1000], Train Loss: 0.0010, Val Loss: 0.0033
# EarlyStopping counter: 7 out of 50
# Epoch [181/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 8 out of 50
# Epoch [182/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 9 out of 50
# Epoch [183/1000], Train Loss: 0.0010, Val Loss: 0.0038
# EarlyStopping counter: 10 out of 50
# Epoch [184/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 11 out of 50
# Epoch [185/1000], Train Loss: 0.0009, Val Loss: 0.0038
# EarlyStopping counter: 12 out of 50
# Epoch [186/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 13 out of 50
# Epoch [187/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 14 out of 50
# Epoch [188/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 15 out of 50
# Epoch [189/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 16 out of 50
# Epoch [190/1000], Train Loss: 0.0010, Val Loss: 0.0035
# EarlyStopping counter: 17 out of 50
# Epoch [191/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 18 out of 50
# Epoch [192/1000], Train Loss: 0.0009, Val Loss: 0.0032
# EarlyStopping counter: 19 out of 50
# Epoch [193/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 20 out of 50
# Epoch [194/1000], Train Loss: 0.0009, Val Loss: 0.0040
# EarlyStopping counter: 21 out of 50
# Epoch [195/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 22 out of 50
# Epoch [196/1000], Train Loss: 0.0009, Val Loss: 0.0038
# EarlyStopping counter: 23 out of 50
# Epoch [197/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 24 out of 50
# Epoch [198/1000], Train Loss: 0.0008, Val Loss: 0.0043
# EarlyStopping counter: 25 out of 50
# Epoch [199/1000], Train Loss: 0.0009, Val Loss: 0.0038
# EarlyStopping counter: 26 out of 50
# Epoch [200/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 27 out of 50
# Epoch [201/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 28 out of 50
# Epoch [202/1000], Train Loss: 0.0009, Val Loss: 0.0032
# Validation loss decreased (0.003200 --> 0.003154).  Saving model ...
# Epoch [203/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 1 out of 50
# Epoch [204/1000], Train Loss: 0.0010, Val Loss: 0.0039
# EarlyStopping counter: 2 out of 50
# Epoch [205/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 3 out of 50
# Epoch [206/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 4 out of 50
# Epoch [207/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 5 out of 50
# Epoch [208/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 6 out of 50
# Epoch [209/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 7 out of 50
# Epoch [210/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 8 out of 50
# Epoch [211/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 9 out of 50
# Epoch [212/1000], Train Loss: 0.0009, Val Loss: 0.0032
# EarlyStopping counter: 10 out of 50
# Epoch [213/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 11 out of 50
# Epoch [214/1000], Train Loss: 0.0009, Val Loss: 0.0038
# EarlyStopping counter: 12 out of 50
# Epoch [215/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 13 out of 50
# Epoch [216/1000], Train Loss: 0.0009, Val Loss: 0.0031
# Validation loss decreased (0.003154 --> 0.003139).  Saving model ...
# Epoch [217/1000], Train Loss: 0.0008, Val Loss: 0.0039
# EarlyStopping counter: 1 out of 50
# Epoch [218/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 2 out of 50
# Epoch [219/1000], Train Loss: 0.0009, Val Loss: 0.0032
# EarlyStopping counter: 3 out of 50
# Epoch [220/1000], Train Loss: 0.0008, Val Loss: 0.0037
# EarlyStopping counter: 4 out of 50
# Epoch [221/1000], Train Loss: 0.0008, Val Loss: 0.0037
# EarlyStopping counter: 5 out of 50
# Epoch [222/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 6 out of 50
# Epoch [223/1000], Train Loss: 0.0009, Val Loss: 0.0031
# Validation loss decreased (0.003139 --> 0.003137).  Saving model ...
# Epoch [224/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 1 out of 50
# Epoch [225/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 2 out of 50
# Epoch [226/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 3 out of 50
# Epoch [227/1000], Train Loss: 0.0009, Val Loss: 0.0040
# EarlyStopping counter: 4 out of 50
# Epoch [228/1000], Train Loss: 0.0008, Val Loss: 0.0041
# EarlyStopping counter: 5 out of 50
# Epoch [229/1000], Train Loss: 0.0008, Val Loss: 0.0032
# EarlyStopping counter: 6 out of 50
# Epoch [230/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 7 out of 50
# Epoch [231/1000], Train Loss: 0.0008, Val Loss: 0.0038
# EarlyStopping counter: 8 out of 50
# Epoch [232/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 9 out of 50
# Epoch [233/1000], Train Loss: 0.0008, Val Loss: 0.0033
# EarlyStopping counter: 10 out of 50
# Epoch [234/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 11 out of 50
# Epoch [235/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 12 out of 50
# Epoch [236/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 13 out of 50
# Epoch [237/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 14 out of 50
# Epoch [238/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 15 out of 50
# Epoch [239/1000], Train Loss: 0.0009, Val Loss: 0.0031
# Validation loss decreased (0.003137 --> 0.003106).  Saving model ...
# Epoch [240/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 1 out of 50
# Epoch [241/1000], Train Loss: 0.0008, Val Loss: 0.0035
# EarlyStopping counter: 2 out of 50
# Epoch [242/1000], Train Loss: 0.0009, Val Loss: 0.0037
# EarlyStopping counter: 3 out of 50
# Epoch [243/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 4 out of 50
# Epoch [244/1000], Train Loss: 0.0008, Val Loss: 0.0034
# EarlyStopping counter: 5 out of 50
# Epoch [245/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 6 out of 50
# Epoch [246/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 7 out of 50
# Epoch [247/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 8 out of 50
# Epoch [248/1000], Train Loss: 0.0009, Val Loss: 0.0039
# EarlyStopping counter: 9 out of 50
# Epoch [249/1000], Train Loss: 0.0009, Val Loss: 0.0039
# EarlyStopping counter: 10 out of 50
# Epoch [250/1000], Train Loss: 0.0008, Val Loss: 0.0035
# EarlyStopping counter: 11 out of 50
# Epoch [251/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 12 out of 50
# Epoch [252/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 13 out of 50
# Epoch [253/1000], Train Loss: 0.0009, Val Loss: 0.0032
# EarlyStopping counter: 14 out of 50
# Epoch [254/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 15 out of 50
# Epoch [255/1000], Train Loss: 0.0008, Val Loss: 0.0032
# EarlyStopping counter: 16 out of 50
# Epoch [256/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 17 out of 50
# Epoch [257/1000], Train Loss: 0.0010, Val Loss: 0.0033
# EarlyStopping counter: 18 out of 50
# Epoch [258/1000], Train Loss: 0.0009, Val Loss: 0.0040
# EarlyStopping counter: 19 out of 50
# Epoch [259/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 20 out of 50
# Epoch [260/1000], Train Loss: 0.0008, Val Loss: 0.0037
# EarlyStopping counter: 21 out of 50
# Epoch [261/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 22 out of 50
# Epoch [262/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 23 out of 50
# Epoch [263/1000], Train Loss: 0.0008, Val Loss: 0.0034
# EarlyStopping counter: 24 out of 50
# Epoch [264/1000], Train Loss: 0.0008, Val Loss: 0.0033
# EarlyStopping counter: 25 out of 50
# Epoch [265/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 26 out of 50
# Epoch [266/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 27 out of 50
# Epoch [267/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 28 out of 50
# Epoch [268/1000], Train Loss: 0.0008, Val Loss: 0.0033
# EarlyStopping counter: 29 out of 50
# Epoch [269/1000], Train Loss: 0.0008, Val Loss: 0.0032
# EarlyStopping counter: 30 out of 50
# Epoch [270/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 31 out of 50
# Epoch [271/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 32 out of 50
# Epoch [272/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 33 out of 50
# Epoch [273/1000], Train Loss: 0.0009, Val Loss: 0.0035
# EarlyStopping counter: 34 out of 50
# Epoch [274/1000], Train Loss: 0.0009, Val Loss: 0.0032
# EarlyStopping counter: 35 out of 50
# Epoch [275/1000], Train Loss: 0.0008, Val Loss: 0.0033
# EarlyStopping counter: 36 out of 50
# Epoch [276/1000], Train Loss: 0.0009, Val Loss: 0.0033
# EarlyStopping counter: 37 out of 50
# Epoch [277/1000], Train Loss: 0.0009, Val Loss: 0.0036
# EarlyStopping counter: 38 out of 50
# Epoch [278/1000], Train Loss: 0.0008, Val Loss: 0.0035
# EarlyStopping counter: 39 out of 50
# Epoch [279/1000], Train Loss: 0.0008, Val Loss: 0.0033
# EarlyStopping counter: 40 out of 50
# Epoch [280/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 41 out of 50
# Epoch [281/1000], Train Loss: 0.0008, Val Loss: 0.0032
# EarlyStopping counter: 42 out of 50
# Epoch [282/1000], Train Loss: 0.0008, Val Loss: 0.0034
# EarlyStopping counter: 43 out of 50
# Epoch [283/1000], Train Loss: 0.0008, Val Loss: 0.0034
# EarlyStopping counter: 44 out of 50
# Epoch [284/1000], Train Loss: 0.0008, Val Loss: 0.0035
# EarlyStopping counter: 45 out of 50
# Epoch [285/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 46 out of 50
# Epoch [286/1000], Train Loss: 0.0008, Val Loss: 0.0035
# EarlyStopping counter: 47 out of 50
# Epoch [287/1000], Train Loss: 0.0009, Val Loss: 0.0034
# EarlyStopping counter: 48 out of 50
# Epoch [288/1000], Train Loss: 0.0008, Val Loss: 0.0034
# EarlyStopping counter: 49 out of 50
# Epoch [289/1000], Train Loss: 0.0009, Val Loss: 0.0041
# EarlyStopping counter: 50 out of 50
# Early Stop

# %%
with h5py.File('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/training_losses.h5', 'r') as f:
    train_losses_apple = np.array(f['train_losses_apple'])
    val_losses_apple = np.array(f['val_losses_apple'])
    train_losses_google = np.array(f['train_losses_google'])
    val_losses_google = np.array(f['val_losses_google'])
    train_losses_tesla = np.array(f['train_losses_tesla'])
    val_losses_tesla = np.array(f['val_losses_tesla'])

# %%
def plot_learning_curves(train_losses, val_losses, title):
    epochs = range(1, len(train_losses) + 1)
    plt.plot(epochs, train_losses, 'bo', label='Training loss')
    plt.plot(epochs, val_losses, 'b', label='Validation loss')
    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

plot_learning_curves(train_losses_apple, val_losses_apple, 'Learning Curve for Apple')
plot_learning_curves(train_losses_google, val_losses_google, 'Learning Curve for Google')
plot_learning_curves(train_losses_tesla, val_losses_tesla, 'Learning Curve for Tesla')

# %%
# Load model parameters
model_apple = StockPredictor(input_size, hidden_layer_size, num_layers, output_size)
model_google = StockPredictor(input_size, hidden_layer_size, num_layers, output_size)
model_tesla = StockPredictor(input_size, hidden_layer_size, num_layers, output_size)

model_apple.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/model_apple.pth'))
model_google.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/model_google.pth'))
model_tesla.load_state_dict(torch.load('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/model_tesla.pth'))
# Out:
# <All keys matched successfully>

# %%
def validate_model(model, X_test, y_test, stock_name):
    model.eval()
    with torch.no_grad():
        predictions, _ = model(X_test)
        predictions = predictions.numpy()

    # Reshape predicted and true values into two-dimensional arrays
    predictions_2d = predictions.reshape(-1, y_test.shape[-1])
    y_test_2d = y_test.numpy().reshape(-1, y_test.shape[-1])

    np.savetxt(f"/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/{stock_name}_predictions.csv", predictions_2d, delimiter=",", header="Predicted_Close,Predicted_Adj_Close", comments="")
    np.savetxt(f"/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/{stock_name}_true_values.csv", y_test_2d, delimiter=",", header="True_Close,True_Adj_Close", comments="")

    # Calculate RMSE, MAE, MAPE, and R2 for each feature
    rmses, maes, mapes, r2s = [], [], [], []
    for i in range(predictions_2d.shape[1]):
        mse = mean_squared_error(y_test_2d[:, i], predictions_2d[:, i])
        mae = mean_absolute_error(y_test_2d[:, i], predictions_2d[:, i])
        mape = np.mean(np.abs((y_test_2d[:, i] - predictions_2d[:, i]) / y_test_2d[:, i])) * 100
        r2 = r2_score(y_test_2d[:, i], predictions_2d[:, i])

        rmse = sqrt(mse)
        rmses.append(rmse)
        maes.append(mae)
        mapes.append(mape)
        r2s.append(r2)

    # Plotting of actual versus predicted values
    plt.figure(figsize=(15, 5))
    plt.plot(y_test_2d[:, 0], label='Actual')
    plt.plot(predictions_2d[:, 0], label='Predicted')
    plt.title('Actual vs Predicted')
    plt.legend()
    plt.show()

    # Error distribution analysis
    sns.histplot(y_test_2d[:, 0] - predictions_2d[:, 0], kde=True)
    plt.title('Error Distribution')
    plt.xlabel('Error')
    plt.ylabel('Frequency')
    plt.show()

    # Calculate total RMSE, MAE, MAPE and R2
    total_rmse = sqrt(mean_squared_error(y_test_2d, predictions_2d))
    total_mae = mean_absolute_error(y_test_2d, predictions_2d)
    total_mape = np.mean(np.abs((y_test_2d - predictions_2d) / y_test_2d)) * 100
    total_r2 = r2_score(y_test_2d, predictions_2d)

    return rmses, total_rmse, maes, total_mae, mapes, total_mape, r2s, total_r2

# Evaluate Apple's model
rmses_apple, total_rmse_apple, maes_apple, total_mae_apple, mapes_apple, total_mape_apple, r2s_apple, total_r2_apple = validate_model(model_apple, X_test_apple, y_test_apple, 'apple')

# Evaluate Google's models
rmses_google, total_rmse_google, maes_google, total_mae_google, mapes_google, total_mape_google, r2s_google, total_r2_google = validate_model(model_google, X_test_google, y_test_google, 'google')

# Evaluate Tesla's models
rmses_tesla, total_rmse_tesla, maes_tesla, total_mae_tesla, mapes_tesla, total_mape_tesla, r2s_tesla, total_r2_tesla = validate_model(model_tesla, X_test_tesla, y_test_tesla, 'tesla')

# %%
# Print Apple's evaluation results
print("Apple Stock:")
print("Feature-wise RMSE:", rmses_apple)
print("Total RMSE:", total_rmse_apple)
print("Feature-wise MAE:", maes_apple)
print("Total MAE:", total_mae_apple)
print("Feature-wise MAPE:", mapes_apple)
print("Total MAPE:", total_mape_apple)
print("Feature-wise R-squared:", r2s_apple)
print("Total R-squared:", total_r2_apple)
print("\n")

# Print Google's assessment results
print("Google Stock:")
print("Feature-wise RMSE:", rmses_google)
print("Total RMSE:", total_rmse_google)
print("Feature-wise MAE:", maes_google)
print("Total MAE:", total_mae_google)
print("Feature-wise MAPE:", mapes_google)
print("Total MAPE:", total_mape_google)
print("Feature-wise R-squared:", r2s_google)
print("Total R-squared:", total_r2_google)
print("\n")

# Print Tesla's evaluation results
print("Tesla Stock:")
print("Feature-wise RMSE:", rmses_tesla)
print("Total RMSE:", total_rmse_tesla)
print("Feature-wise MAE:", maes_tesla)
print("Total MAE:", total_mae_tesla)
print("Feature-wise MAPE:", mapes_tesla)
print("Total MAPE:", total_mape_tesla)
print("Feature-wise R-squared:", r2s_tesla)
print("Total R-squared:", total_r2_tesla)
# Out:
# Apple Stock:
# Feature-wise RMSE: [0.04637426158880751, 0.04782106683142671]
# Total RMSE: 0.04710321206573425
# Feature-wise MAE: [0.039528783, 0.040912043]
# Total MAE: 0.040220417
# Feature-wise MAPE: [5.072753503918648, 5.173840746283531]
# Total MAPE: 5.1232971251010895
# Feature-wise R-squared: [0.5862054004712319, 0.5521169137616904]
# Total R-squared: 0.5691611563016359
#
#
# Google Stock:
# Feature-wise RMSE: [0.049305045830602134, 0.05200173373467099]
# Total RMSE: 0.05067133470430142
# Feature-wise MAE: [0.04193426, 0.043369792]
# Total MAE: 0.042652022
# Feature-wise MAPE: [8.289586752653122, 8.735956996679306]
# Total MAPE: 8.512771874666214
# Feature-wise R-squared: [0.7502803295153875, 0.722216992637053]
# Total R-squared: 0.7362486610762202
#
#
# Tesla Stock:
# Feature-wise RMSE: [0.04569168395924744, 0.045300219881928554]
# Total RMSE: 0.04549636400069966
# Feature-wise MAE: [0.037548523, 0.037300177]
# Total MAE: 0.037424363
# Feature-wise MAPE: [7.55544975399971, 7.5094640254974365]
# Total MAPE: 7.5324565172195435
# Feature-wise R-squared: [0.8834881738844492, 0.8854760660494735]
# Total R-squared: 0.8844821202613167

# %%
# Load the CSV files
predictions4_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/tesla_predictions4.csv')
true_values_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/tesla_true_values.csv')
predictions5_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/DeepLearning/A3/model_3/Copy of tesla_predictions5.csv')

# Plotting the true values and predictions for the non-adjusted close price
plt.figure(figsize=(15, 5))
plt.plot(true_values_df['True_Close'], label='Actual Close Price', color='black')
plt.plot(predictions4_df['Predicted_Close'], label='Predicted Close Price (Model 4)')
plt.plot(predictions5_df['Predicted_Close'], label='Predicted Close Price (Model 5)')
plt.title('Actual vs Predicted Close Price')
plt.legend()
plt.show()

# %%
# Plotting the true values and predictions for the adjusted close price
plt.figure(figsize=(15, 5))
plt.plot(true_values_df['True_Adj_Close'], label='Actual Adjusted Close Price', color='black')
plt.plot(predictions4_df['Predicted_Adj_Close'], label='Predicted Adjusted Close Price (Model 4)')
plt.plot(predictions5_df['Predicted_Adj_Close'], label='Predicted Adjusted Close Price (Model 5)')
plt.title('Actual vs Predicted Adjusted Close Price')
plt.legend()
plt.show()

# %% [markdown]
# ### Apple Stock Model Comparison
#
# | Metric      | New Model Feature-wise | New Model Total | Old Model Feature-wise | Old Model Total |
# |-------------|------------------------|-----------------|------------------------|-----------------|
# | RMSE        | [0.0404, 0.0395]       | 0.0400          | [0.0464, 0.0478]       | 0.0471          |
# | MAE         | [0.0342, 0.0335]       | 0.0338          | [0.0395, 0.0409]       | 0.0402          |
# | MAPE        | [4.44, 4.28]           | 4.36            | [5.07, 5.17]           | 5.12            |
# | R-squared   | [0.686, 0.694]         | 0.690           | [0.586, 0.552]         | 0.569           |
#
# ### Google Stock Model Comparison
#
# | Metric      | New Model Feature-wise | New Model Total | Old Model Feature-wise | Old Model Total |
# |-------------|------------------------|-----------------|------------------------|-----------------|
# | RMSE        | [0.0487, 0.0484]       | 0.0485          | [0.0493, 0.052]        | 0.0507          |
# | MAE         | [0.0408, 0.0407]       | 0.0407          | [0.0419, 0.0434]       | 0.0427          |
# | MAPE        | [8.13, 8.1]            | 8.12            | [8.29, 8.73]           | 8.51            |
# | R-squared   | [0.757, 0.759]         | 0.758           | [0.750, 0.722]         | 0.736           |
#
# ### Tesla Stock Model Comparison
#
# | Metric      | New Model Feature-wise | New Model Total | Old Model Feature-wise | Old Model Total |
# |-------------|------------------------|-----------------|------------------------|-----------------|
# | RMSE        | [0.0472, 0.0475]       | 0.0473          | [0.0457, 0.0453]       | 0.0455          |
# | MAE         | [0.0381, 0.0384]       | 0.0382          | [0.0375, 0.0373]       | 0.0374          |
# | MAPE        | [7.64, 7.69]           | 7.67            | [7.56, 7.51]           | 7.53            |
# | R-squared   | [0.876, 0.874]         | 0.875           | [0.883, 0.885]         | 0.884           |
